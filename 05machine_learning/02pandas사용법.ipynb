# %% [markdown]
# # pandas

# %%
# pip install pandas
# conda install pandas

# %% [markdown]
# * numpy를 내부적으로 활용함
# * 데이터 분석에 특화된 데이터 구조 제공(테이블, dataframe)
# * 다양한 데이터 분석 함수 제공
# * 데이터베이스에 쉽게 연결 가능
# * json 데이터 html의 table요소를 dataframe으로 손쉽게 변형 가능

# %% [markdown]
# # pandas에서 다루는 데이터 타입 2가지
# ## 1) DataFrame: 2차원의 표형식 데이터
# * python의 dict와도 비슷 하나의 key에 list 형태의 value가 매칭되어 있는 형태
# * {key : [value1, value2, value3], key2 : [value1, value2, value3]}
# ## 2) Series: 1차원의 벡터형식 데이터
# * python의 list, tuple, ndarray의 1차원 상태와 비슷

# %%
import pandas as pd

# %% [markdown]
# # 데이터프레임 만들기
# pd.DataFrame({key1: [value1, value2] key2 : [value1, value2]})

# %%
df = pd.DataFrame(
        {'이름' : ['홍길동', '둘리', '또치', '도우너'],
         '주소' : ['서울', '의정부', '고양', '성남'],
         '취미' : ['음악감상', '놀기', '달리기', '바이올린']}
        )

# %%
df
# Out:
#     이름   주소    취미
# 0  홍길동   서울  음악감상
# 1   둘리  의정부    놀기
# 2   또치   고양   달리기
# 3  도우너   성남  바이올린

# %%
df.shape
# Out:
# (4, 3)

# %%
df.ndim
# Out:
# 2

# %%
df['이름']
# Out:
# 0    홍길동
# 1     둘리
# 2     또치
# 3    도우너
# Name: 이름, dtype: object

# %%
df['이름'].dtype
# Out:
# dtype('O')

# %%
print(df['이름'][:2])
# Out:
# 0    홍길동
# 1     둘리
# Name: 이름, dtype: object

# %% [markdown]
# # Series 만들기
# * pd.Series([리스트 자료/튜플], name="컬럼명")
# * 이름을 가지고 있는 list / 벡터
# * dataframe에서 컬럼 1개를 잘라온 형태

# %%
ages = pd.Series([22,53, 35], name="나이")

# %%
ages.dtype
# Out:
# dtype('int64')

# %%
ages
# Out:
# 0    22
# 1    53
# 2    35
# Name: 나이, dtype: int64

# %%
ages[0:2]
# Out:
# 0    22
# 1    53
# Name: 나이, dtype: int64

# %%
ages[::-1]
# Out:
# 2    35
# 1    53
# 0    22
# Name: 나이, dtype: int64

# %%
ages.min()
# Out:
# np.int64(22)

# %%
ages.max()
# Out:
# np.int64(53)

# %%
ages.sum()
# Out:
# np.int64(110)

# %%
ages.cumsum()
# Out:
# 0     22
# 1     75
# 2    110
# Name: 나이, dtype: int64

# %%
ages.mean()
# Out:
# np.float64(36.666666666666664)

# %%
ages.median()
# Out:
# np.float64(35.0)

# %% [markdown]
# # 판다스에서 자료 불러오기, 저장하기
# * csv, tsv, excel, json, html, sql
# * pd.read_확장자명(파일경로, 옵션)

# %% [markdown]
# excel 파일 불러오기

# %%
# %%time
df_excel = pd.read_excel("./data/Online Retail.xlsx")
df_excel
# Out:
# CPU times: total: 2min 29s
# Wall time: 2min 39s
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
# df_excel.to_csv("./data/Online Retail.csv", index=False, encoding="utf-8-sig")

# %%
# %%time
df_retail = pd.read_csv("./data/Online Retail.csv")
df_retail
# Out:
# CPU times: total: 1.17 s
# Wall time: 1.22 s
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 0       2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1       2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2       2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3       2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4       2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                     ...        ...         ...             ...
# 541904  2011-12-09 12:50:00       0.85     12680.0          France
# 541905  2011-12-09 12:50:00       2.10     12680.0          France
# 541906  2011-12-09 12:50:00       4.15     12680.0          France
# 541907  2011-12-09 12:50:00       4.15     12680.0          France
# 541908  2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
# %%time
df_excel2 = pd.read_excel("./data/아파트(매매)_실거래가_20240806113828.xlsx", header=12)
df_excel2
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# CPU times: total: 49.7 s
# Wall time: 53.5 s
#           NO                  시군구      번지    본번  부번                단지명  \
# 0          1     서울특별시 영등포구 당산동5가      42    42   0          당산삼성래미안4차
# 1          2  강원특별자치도 원주시 지정면 가곡리    1512  1512   0  원주롯데캐슬골드파크1차(5단지)
# 2          3    대구광역시 달성군 화원읍 구라리    1650  1650   0             대곡역래미안
# 3          4         광주광역시 남구 진월동   312-7   312   7                 광명
# 4          5         광주광역시 남구 진월동  331-93   331  93                 중흥
# ...      ...                  ...     ...   ...  ..                ...
# 37575  37576        서울특별시 송파구 장지동     849   849   0          송파파인타운3단지
# 37576  37577        부산광역시 사상구 모라동     552   552   0               백양그린
# 37577  37578        광주광역시 광산구 비아동   152-5   152   5                 호반
# 37578  37579        부산광역시 사상구 모라동     552   552   0               백양그린
# 37579  37580         대구광역시 북구 읍내동  1366-2  1366   2               칠곡보성
#
#         전용면적(㎡)    계약년월  계약일 거래금액(만원)  ...   층  매수자 매도자  건축년도            도로명  \
# 0      115.7800  202407   31  139,000  ...   4   개인  개인  2003        당산로 214
# 1       84.9644  202407   31   38,900  ...  10   개인  개인  2019       신지정로 250
# 2       84.5958  202407   31   29,500  ...  11   개인  개인  2007     비슬로539길 35
# 3       70.6250  202407   31   16,900  ...   1   개인  개인  1998       광복마을길 63
# 4       84.8400  202407   31   17,500  ...  13   개인  개인  1992  서문대로749번마길 30
# ...         ...     ...  ...      ...  ...  ..  ...  ..   ...            ...
# 37575   84.9800  202407    1  117,500  ...  14   개인  개인  2008        충민로 152
# 37576   41.3000  202407    1    7,000  ...   8   개인  개인  1992    모라로110번길 88
# 37577   59.8800  202407    1   15,400  ...   5   개인  개인  1998        비아로 185
# 37578   41.3000  202407    1    7,500  ...  10   개인  개인  1992    모라로110번길 88
# 37579   84.9800  202407    1   21,000  ...   9   개인  개인  1992      구암로21길 26
#
#         해제사유발생일  거래유형  중개사소재지      등기일자 주택유형
# 0             -   직거래       -         -  아파트
# 1      20240802  중개거래  강원 원주시         -  아파트
# 2             -  중개거래  대구 달성군         -  아파트
# 3             -  중개거래   광주 남구         -  아파트
# 4             -   직거래       -  24.07.31  아파트
# ...         ...   ...     ...       ...  ...
# 37575         -  중개거래  서울 송파구         -  아파트
# 37576         -  중개거래  부산 사상구  24.07.10  아파트
# 37577         -  중개거래  광주 광산구  24.07.26  아파트
# 37578         -  중개거래  부산 사상구  24.07.19  아파트
# 37579         -  중개거래   대구 북구         -  아파트
#
# [37580 rows x 21 columns]

# %%
# %%time
df_csv = pd.read_csv("./data/아파트(매매)_실거래가_20240806113828.csv", header=12)
df_csv
# Out:
# CPU times: total: 266 ms
# Wall time: 324 ms
#           NO                  시군구      번지    본번  부번                단지명  \
# 0          1     서울특별시 영등포구 당산동5가      42    42   0          당산삼성래미안4차
# 1          2  강원특별자치도 원주시 지정면 가곡리    1512  1512   0  원주롯데캐슬골드파크1차(5단지)
# 2          3    대구광역시 달성군 화원읍 구라리    1650  1650   0             대곡역래미안
# 3          4         광주광역시 남구 진월동   312-7   312   7                 광명
# 4          5         광주광역시 남구 진월동  331-93   331  93                 중흥
# ...      ...                  ...     ...   ...  ..                ...
# 37575  37576        서울특별시 송파구 장지동     849   849   0          송파파인타운3단지
# 37576  37577        부산광역시 사상구 모라동     552   552   0               백양그린
# 37577  37578        광주광역시 광산구 비아동   152-5   152   5                 호반
# 37578  37579        부산광역시 사상구 모라동     552   552   0               백양그린
# 37579  37580         대구광역시 북구 읍내동  1366-2  1366   2               칠곡보성
#
#         전용면적(㎡)    계약년월  계약일 거래금액(만원)  ...   층  매수자 매도자  건축년도            도로명  \
# 0      115.7800  202407   31  139,000  ...   4   개인  개인  2003        당산로 214
# 1       84.9644  202407   31   38,900  ...  10   개인  개인  2019       신지정로 250
# 2       84.5958  202407   31   29,500  ...  11   개인  개인  2007     비슬로539길 35
# 3       70.6250  202407   31   16,900  ...   1   개인  개인  1998       광복마을길 63
# 4       84.8400  202407   31   17,500  ...  13   개인  개인  1992  서문대로749번마길 30
# ...         ...     ...  ...      ...  ...  ..  ...  ..   ...            ...
# 37575   84.9800  202407    1  117,500  ...  14   개인  개인  2008        충민로 152
# 37576   41.3000  202407    1    7,000  ...   8   개인  개인  1992    모라로110번길 88
# 37577   59.8800  202407    1   15,400  ...   5   개인  개인  1998        비아로 185
# 37578   41.3000  202407    1    7,500  ...  10   개인  개인  1992    모라로110번길 88
# 37579   84.9800  202407    1   21,000  ...   9   개인  개인  1992      구암로21길 26
#
#         해제사유발생일  거래유형  중개사소재지      등기일자 주택유형
# 0             -   직거래       -         -  아파트
# 1      20240802  중개거래  강원 원주시         -  아파트
# 2             -  중개거래  대구 달성군         -  아파트
# 3             -  중개거래   광주 남구         -  아파트
# 4             -   직거래       -  24.07.31  아파트
# ...         ...   ...     ...       ...  ...
# 37575         -  중개거래  서울 송파구         -  아파트
# 37576         -  중개거래  부산 사상구  24.07.10  아파트
# 37577         -  중개거래  광주 광산구  24.07.26  아파트
# 37578         -  중개거래  부산 사상구  24.07.19  아파트
# 37579         -  중개거래   대구 북구         -  아파트
#
# [37580 rows x 21 columns]

# %%
df_json = pd.read_json("./data/서울특별시_관광지입장정보_2011_2016.json")
df_json
# Out:
#     ForNum  NatNum  addrCd gungu      resNm  rnum   sido  yyyymm
# 0    44722   75991    1111   종로구        창덕궁     1  서울특별시  201112
# 1        0   11017    1111   종로구        운현궁     2  서울특별시  201112
# 2   132399  237330    1111   종로구        경복궁     3  서울특별시  201112
# 3     3133   21267    1111   종로구        창경궁     4  서울특별시  201112
# 4    18226   24223    1111   종로구         종묘     5  서울특별시  201112
# ..     ...     ...     ...   ...        ...   ...    ...     ...
# 62    5588   44232    1141  서대문구  서대문형무소역사관     8  서울특별시  201512
# 63       0   22587    1141  서대문구  서대문자연사박물관     9  서울특별시  201512
# 64   29520    8822    1144   마포구    트릭아이미술관    10  서울특별시  201512
# 65       3    1647    1165   서초구      헌릉ㆍ인릉    11  서울특별시  201512
# 66     492   14454    1168   강남구      선릉·정릉    12  서울특별시  201512
#
# [67 rows x 8 columns]

# %%
df_html = pd.read_html("./data/corpList.htm")
df_html[0]
# Out:
#     Unnamed: 0                             Unnamed: 1  \
# 0     한국제15호스팩                             금융 지원 서비스업
# 1       에스오에스랩  측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 2   미래에셋비전스팩6호                             금융 지원 서비스업
# 3   에이치엠씨제7호스팩                             금융 지원 서비스업
# 4        파라다이스                     유원지 및 기타 오락관련 서비스업
# 5       한중엔시에스      전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 6     KB제29호스팩                             금융 지원 서비스업
# 7   미래에셋비전스팩5호                             금융 지원 서비스업
# 8     씨어스테크놀로지                             의료용 기기 제조업
# 9     한국제14호스팩                             금융 지원 서비스업
# 10   디비금융스팩12호                                 기타 금융업
# 11        라메디텍                             의료용 기기 제조업
# 12       그리드위즈                 그외 기타 전문, 과학 및 기술 서비스업
# 13       다원넥스뷰                        사진장비 및 광학기기 제조업
# 14  미래에셋비전스팩4호                             금융 지원 서비스업
#
#                                            Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0                                              기업인수합병  2024-06-26        12월
# 1                                산업용 및 차량용 라이다(LiDAR)  2024-06-25        12월
# 2                                              기업인수합병  2024-06-24        12월
# 3                                                기타금융  2024-06-24        12월
# 4                                      카지노, 호텔, 복합리조트  2024-06-24        12월
# 5   수냉식 냉각시스템 ESS Parts, 공랭식 ESS Module Parts, EV ...  2024-06-24        12월
# 6                                              기업인수합병  2024-06-21        12월
# 7                                              기업인수합병  2024-06-19        12월
# 8                                심전도검사솔루션 입원환자모니터링솔루션  2024-06-19        12월
# 9                                              기업인수합병  2024-06-19        12월
# 10                                          기업인수 및 합병  2024-06-18        12월
# 11                                초소형 레이저 의료기기 및 미용기기  2024-06-17        12월
# 12                             수요관리 서비스, 전기차 충전기 모뎀 등  2024-06-14        12월
# 13                   LSMB(Laser Micro Bonding System)  2024-06-11        12월
# 14                                  기업인수목적회사(기타금융서비스)  2024-05-29        12월
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0          유한        NaN      서울특별시
# 1         정지성    홈페이지 보기      광주광역시
# 2         정명훈        NaN      서울특별시
# 3         강신명        NaN      서울특별시
# 4       최종환..    홈페이지 보기      서울특별시
# 5         김환식    홈페이지 보기       경상북도
# 6         서영화        NaN      서울특별시
# 7         김대호        NaN      서울특별시
# 8         이영신    홈페이지 보기        경기도
# 9         변성환        NaN      서울특별시
# 10        김창희        NaN      서울특별시
# 11        최종석        NaN      서울특별시
# 12        김구환    홈페이지 보기        경기도
# 13        남기중    홈페이지 보기        경기도
# 14        김정수        NaN      서울특별시

# %% [markdown]
# DB에서 자료 읽어오기

# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/exchange_rate")
conn = engine.connect()
df_sql = pd.read_sql("exchange_rate", con=conn)
conn.close()
df_sql
# Out:
#              date            통화  현찰_사실_때_환율  현찰_사실_때_Spread  현찰_파실_때_환율  \
# 0      1995-01-03        미국 USD      800.53             1.5      776.87
# 1      1995-01-03  일본 JPY (100)      798.89             1.5      775.29
# 2      1995-01-03        유로 EUR        0.00             0.0        0.00
# 3      1995-01-03        중국 CNY        0.00             0.0        0.00
# 4      1995-01-03        홍콩 HKD      103.45             3.0      100.41
# ...           ...           ...         ...             ...         ...
# 127645 2025-04-15       리비아 LYD        0.00             0.0        0.00
# 127646 2025-04-15      루마니아 RON        0.00             0.0        0.00
# 127647 2025-04-15       미얀마 MMK        0.00             0.0        0.00
# 127648 2025-04-15     에티오피아 ETB        0.00             0.0        0.00
# 127649 2025-04-15    우즈베키스탄 UZS        0.00             0.0        0.00
#
#         현찰_파실_때_Spread  송금_보낼_때_보낼_때  송금_받을_때_받을_때  외화_수표_파실때  매매_기준율  환가_료율  \
# 0                  1.5        791.80        785.60       0.00  788.70   0.00
# 1                  1.5        791.81        782.37       0.00  787.09   0.00
# 2                  0.0        975.40        959.92     957.94  967.66   7.37
# 3                  0.0         94.12          0.00       0.00   93.38   1.00
# 4                  3.0        102.74        101.12       0.00  101.93   0.00
# ...                ...           ...           ...        ...     ...    ...
# 127645             0.0        260.07        254.93       0.00  257.50   0.00
# 127646             0.0        329.99        322.81       0.00  326.40   7.74
# 127647             0.0          0.00          0.00       0.00    0.68   0.00
# 127648             0.0          0.00          0.00       0.00   10.81   0.00
# 127649             0.0          0.00          0.00       0.00    0.11   0.00
#
#         미화_환산율
# 0       1.0000
# 1       0.9980
# 2       1.2269
# 3       0.1184
# 4       0.1292
# ...        ...
# 127645  0.1799
# 127646  0.2280
# 127647  0.0005
# 127648  0.0076
# 127649  0.0001
#
# [127650 rows x 12 columns]

# %%
engine = create_engine("mysql+pymysql://kict20:kict20@221.155.18.165:3306/titanic")
conn = engine.connect()
passenger = pd.read_sql("p_info", con=conn)
conn.close()
passenger
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch
# 0    22.0      1      0
# 1    38.0      1      0
# 2    26.0      0      0
# 3    35.0      1      0
# 4    35.0      0      0
# ..    ...    ...    ...
# 886  27.0      0      0
# 887  19.0      0      0
# 888   NaN      1      2
# 889  26.0      0      0
# 890  32.0      0      0
#
# [891 rows x 6 columns]

# %% [markdown]
# # 타이타닉 데이터셋으로 pandas 기능 익히기

# %%
df = pd.read_csv("./data/Titanic_train.csv")
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
display(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# * 데이터의 일부만 보기
# * 앞쪽 head(행개수), 뒷쪽 tail(행개수)
# * 기본 값은 5행

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(60)
# Out:
#      PassengerId  Survived  Pclass  \
# 831          832         1       2
# 832          833         0       3
# 833          834         0       3
# 834          835         0       3
# 835          836         1       1
# 836          837         0       3
# 837          838         0       3
# 838          839         1       3
# 839          840         1       1
# 840          841         0       3
# 841          842         0       2
# 842          843         1       1
# 843          844         0       3
# 844          845         0       3
# 845          846         0       3
# 846          847         0       3
# 847          848         0       3
# 848          849         0       2
# 849          850         1       1
# 850          851         0       3
# 851          852         0       3
# 852          853         0       3
# 853          854         1       1
# 854          855         0       2
# 855          856         1       3
# 856          857         1       1
# 857          858         1       1
# 858          859         1       3
# 859          860         0       3
# 860          861         0       3
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 831                    Richards, Master. George Sibley    male   0.83      1
# 832                                     Saad, Mr. Amin    male    NaN      0
# 833                             Augustsson, Mr. Albert    male  23.00      0
# 834                             Allum, Mr. Owen George    male  18.00      0
# 835                        Compton, Miss. Sara Rebecca  female  39.00      1
# 836                                   Pasic, Mr. Jakob    male  21.00      0
# 837                                Sirota, Mr. Maurice    male    NaN      0
# 838                                    Chip, Mr. Chang    male  32.00      0
# 839                               Marechal, Mr. Pierre    male    NaN      0
# 840                        Alhomaki, Mr. Ilmari Rudolf    male  20.00      0
# 841                           Mudd, Mr. Thomas Charles    male  16.00      0
# 842                            Serepeca, Miss. Augusta  female  30.00      0
# 843                         Lemberopolous, Mr. Peter L    male  34.50      0
# 844                                Culumovic, Mr. Jeso    male  17.00      0
# 845                                Abbing, Mr. Anthony    male  42.00      0
# 846                           Sage, Mr. Douglas Bullen    male    NaN      8
# 847                                 Markoff, Mr. Marin    male  35.00      0
# 848                                  Harper, Rev. John    male  28.00      0
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female    NaN      1
# 850            Andersson, Master. Sigvard Harald Elias    male   4.00      4
# 851                                Svensson, Mr. Johan    male  74.00      0
# 852                            Boulos, Miss. Nourelain  female   9.00      1
# 853                          Lines, Miss. Mary Conover  female  16.00      0
# 854      Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female  44.00      1
# 855                         Aks, Mrs. Sam (Leah Rosen)  female  18.00      0
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.00      1
# 857                             Daly, Mr. Peter Denis     male  51.00      0
# 858              Baclini, Mrs. Solomon (Latifa Qurban)  female  24.00      0
# 859                                   Razi, Mr. Raihed    male    NaN      0
# 860                            Hansen, Mr. Claus Peter    male  41.00      2
# 861                        Giles, Mr. Frederick Edward    male  21.00      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.00      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female    NaN      8
# 864                             Gill, Mr. John William    male  24.00      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.00      0
# 866                       Duran y More, Miss. Asuncion  female  27.00      1
# 867               Roebling, Mr. Washington Augustus II    male  31.00      0
# 868                        van Melkebeke, Mr. Philemon    male    NaN      0
# 869                    Johnson, Master. Harold Theodor    male   4.00      1
# 870                                  Balkic, Mr. Cerin    male  26.00      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.00      1
# 872                           Carlsson, Mr. Frans Olof    male  33.00      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.00      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.00      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.00      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.00      0
# 877                               Petroff, Mr. Nedelio    male  19.00      0
# 878                                 Laleff, Mr. Kristo    male    NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.00      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.00      0
# 881                                 Markun, Mr. Johann    male  33.00      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.00      0
# 883                      Banfield, Mr. Frederick James    male  28.00      0
# 884                             Sutehall, Mr. Henry Jr    male  25.00      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.00      0
# 886                              Montvila, Rev. Juozas    male  27.00      0
# 887                       Graham, Miss. Margaret Edith  female  19.00      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female    NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.00      0
# 890                                Dooley, Mr. Patrick    male  32.00      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 831      1             29106   18.7500          NaN        S
# 832      0              2671    7.2292          NaN        C
# 833      0            347468    7.8542          NaN        S
# 834      0              2223    8.3000          NaN        S
# 835      1          PC 17756   83.1583          E49        C
# 836      0            315097    8.6625          NaN        S
# 837      0            392092    8.0500          NaN        S
# 838      0              1601   56.4958          NaN        S
# 839      0             11774   29.7000          C47        C
# 840      0  SOTON/O2 3101287    7.9250          NaN        S
# 841      0       S.O./P.P. 3   10.5000          NaN        S
# 842      0            113798   31.0000          NaN        C
# 843      0              2683    6.4375          NaN        C
# 844      0            315090    8.6625          NaN        S
# 845      0         C.A. 5547    7.5500          NaN        S
# 846      2          CA. 2343   69.5500          NaN        S
# 847      0            349213    7.8958          NaN        C
# 848      1            248727   33.0000          NaN        S
# 849      0             17453   89.1042          C92        C
# 850      2            347082   31.2750          NaN        S
# 851      0            347060    7.7750          NaN        S
# 852      1              2678   15.2458          NaN        C
# 853      1          PC 17592   39.4000          D28        S
# 854      0            244252   26.0000          NaN        S
# 855      1            392091    9.3500          NaN        S
# 856      1             36928  164.8667          NaN        S
# 857      0            113055   26.5500          E17        S
# 858      3              2666   19.2583          NaN        C
# 859      0              2629    7.2292          NaN        C
# 860      0            350026   14.1083          NaN        S
# 861      0             28134   11.5000          NaN        S
# 862      0             17466   25.9292          D17        S
# 863      2          CA. 2343   69.5500          NaN        S
# 864      0            233866   13.0000          NaN        S
# 865      0            236852   13.0000          NaN        S
# 866      0     SC/PARIS 2149   13.8583          NaN        C
# 867      0          PC 17590   50.4958          A24        S
# 868      0            345777    9.5000          NaN        S
# 869      1            347742   11.1333          NaN        S
# 870      0            349248    7.8958          NaN        S
# 871      1             11751   52.5542          D35        S
# 872      0               695    5.0000  B51 B53 B55        S
# 873      0            345765    9.0000          NaN        S
# 874      0         P/PP 3381   24.0000          NaN        C
# 875      0              2667    7.2250          NaN        C
# 876      0              7534    9.8458          NaN        S
# 877      0            349212    7.8958          NaN        S
# 878      0            349217    7.8958          NaN        S
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000          NaN        S
# 881      0            349257    7.8958          NaN        S
# 882      0              7552   10.5167          NaN        S
# 883      0  C.A./SOTON 34068   10.5000          NaN        S
# 884      0   SOTON/OQ 392076    7.0500          NaN        S
# 885      5            382652   29.1250          NaN        Q
# 886      0            211536   13.0000          NaN        S
# 887      0            112053   30.0000          B42        S
# 888      2        W./C. 6607   23.4500          NaN        S
# 889      0            111369   30.0000         C148        C
# 890      0            370376    7.7500          NaN        Q

# %%
# 데이터 프레임 각 컬럼의 데이터타입
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # .info()
# * 컬럼명, null이 아닌 데이터 개수, 데이터타입을 동시에 출력

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # .describe()
# * 데이터 프레임의 숫자 데이터의 기초통계를 보여주는 함수
# * count, mean, std, min, 25%, 50%, 75%, max

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 판다스 데이터 프레임에서 일부 자료만 추출하기

# %% [markdown]
# * 데이터프레임에서 1개 컬럼만 가져오기

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df['Name'].ndim
# Out:
# 1

# %%
df['Name'].shape
# Out:
# (891,)

# %%
df[['Name']].ndim
# Out:
# 2

# %%
df[['Name']].shape
# Out:
# (891, 1)

# %%
df[['Name']]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
print(type(df[['Name']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(df['Name']))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# * 2개 이상의 컬럼을 가져오기

# %%
df[['Age', 'Name']]
# Out:
#       Age                                               Name
# 0    22.0                            Braund, Mr. Owen Harris
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    26.0                             Heikkinen, Miss. Laina
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    35.0                           Allen, Mr. William Henry
# ..    ...                                                ...
# 886  27.0                              Montvila, Rev. Juozas
# 887  19.0                       Graham, Miss. Margaret Edith
# 888   NaN           Johnston, Miss. Catherine Helen "Carrie"
# 889  26.0                              Behr, Mr. Karl Howell
# 890  32.0                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
df[['Age', 'Name', 'Pclass']]
# Out:
#       Age                                               Name  Pclass
# 0    22.0                            Braund, Mr. Owen Harris       3
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2    26.0                             Heikkinen, Miss. Laina       3
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4    35.0                           Allen, Mr. William Henry       3
# ..    ...                                                ...     ...
# 886  27.0                              Montvila, Rev. Juozas       2
# 887  19.0                       Graham, Miss. Margaret Edith       1
# 888   NaN           Johnston, Miss. Catherine Helen "Carrie"       3
# 889  26.0                              Behr, Mr. Karl Howell       1
# 890  32.0                                Dooley, Mr. Patrick       3
#
# [891 rows x 3 columns]

# %% [markdown]
# * 테이터프레임의 컬럼 순서 바꾸기

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2 = df[['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Embarked', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'PassengerId']]
df2
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age Embarked  SibSp  Parch            Ticket     Fare Cabin  \
# 0      male  22.0        S      1      0         A/5 21171   7.2500   NaN
# 1    female  38.0        C      1      0          PC 17599  71.2833   C85
# 2    female  26.0        S      0      0  STON/O2. 3101282   7.9250   NaN
# 3    female  35.0        S      1      0            113803  53.1000  C123
# 4      male  35.0        S      0      0            373450   8.0500   NaN
# ..      ...   ...      ...    ...    ...               ...      ...   ...
# 886    male  27.0        S      0      0            211536  13.0000   NaN
# 887  female  19.0        S      0      0            112053  30.0000   B42
# 888  female   NaN        S      1      2        W./C. 6607  23.4500   NaN
# 889    male  26.0        C      0      0            111369  30.0000  C148
# 890    male  32.0        Q      0      0            370376   7.7500   NaN
#
#      PassengerId
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ..           ...
# 886          887
# 887          888
# 888          889
# 889          890
# 890          891
#
# [891 rows x 12 columns]

# %% [markdown]
# # 데이터프레임에서 일부 컬럼만 가져오기2
# * loc: 인덱스 이름과 컬럼명으로 데이터의 일부를 추출해 가져옴
#   * df.loc[시작_row_인덱스이름 : 끝_row_인덱스이름, ['컬럼명1', '컬럼명2']
# * iloc: 인덱스를 이용해 슬라이싱으로 데이터의 일부를 가져옴
#   * df.iloc[시작_row_index : 끝_row_index, 시작_column_index : 끝_column_index]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### loc[시작_row_인덱스 : 끝_row_인덱스, ['컬럼명1', '컬럼명2']

# %%
df[['이름', '나이']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[197], line 1
# ----> 1 df[['이름', '나이']]
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['이름', '나이'], dtype='object')] are in the [columns]"

# %%
df.loc[109:130, ['이름', '나이']]

# %%
df.loc[109, ['나이']]

# %%
df.loc[109, ['나이']] = 29
df.loc[109, ['나이']]

# %%
print(df.loc[101:102, ['이름', '나이']])
display(df.loc[101:102, ['이름', '나이']])
# print(type(df.loc[101, ['Name', 'Age']]))

# %%
df.describe()

# %%
static = df.describe()
print(type(static))

# %%
static.loc['min': 'max', ['나이', '티켓가격']]

# %%
static

# %%
# 75% + ((75%-25%) * 1.5)
static.loc['75%'] + ((static.loc['75%'] - static.loc['25%'] * 1.5))

# %% [markdown]
# #### df.iloc[시작_row_index : 끝_row_index, 시작_column_index : 끝_column_index]

# %%
df

# %%
df.iloc[4:11, -5:]

# %%
df.iloc[4, 4] = 'female'

# %%
df.iloc[4, 4]

# %%
df.iloc[:10:3, ::3]

# %%
static

# %%
static.iloc[4:7, [1,2,5]]

# %% [markdown]
# * 특정 컬럼에서 유일값(중복되지 않은 고유한 값) 출력하기
# * .unique()

# %%
df.columns

# %%
print(df['목적지'].unique())

# %% [markdown]
# * .nunique()
# * 유일값의 개수를 출력
# * nan 값은 무시

# %%
df['목적지'].nunique()

# %% [markdown]
# * 카테고리 컬럼에서 유일값 별 개수를 세는 함수
# * value_counts()

# %%
df['Embarked'].value_counts()

# %%
# ascending 옵션 value의 개수에 따라서 오름차순, 내림차순 정렬
df['Pclass'].value_counts(ascending=True)

# %%
df['Age'].value_counts(sort=False)

# %% [markdown]
# * 데이터를 정렬하는 함수
# * sort_values(by="컬럼명")
# * order by

# %%
df.sort_values(by="Age", ascending=False)

# %% [markdown]
# * 기준컬럼 2개로 정렬할 때

# %%
df.sort_values(by=['Pclass', "Age"], ascending=False)

# %% [markdown]
# * 컬럼을 인덱스로 지정하기
# * set_index("컬럼명")

# %%
# df.reset_index(inplace=True)

# %%
df = df.set_index(["PassengerId", "Name"])
df

# %%
df.index

# %%
df.loc[(889, 'Johnston, Miss. Catherine Helen "Carrie"'): (891, 'Dooley, Mr. Patrick') , ['Pclass', 'Age'] ]

# %%
df.iloc[888:, [1,3]]

# %% [markdown]
# * 인덱스를 숫자로 초기화
# * reset_index(drop=True)

# %%
df

# %%
# df.reset_index(drop=True)
df = df.reset_index()
df

# %% [markdown]
# * 컬럼이름 출력하기, 바꾸기
# * df.columns

# %%
df.columns

# %% [markdown]
# * 컬럼 이름 변경하기
# * rename(columns={'원래이름':'새이름', '원래이름2':'새이름2'}):

# %%
df.rename(columns={'PassengerId': 'Pid', 'Survived':'surv'}, inplace=True)
df

# %%
df.rename(index={0: '영번', 1:'일번'}, inplace=True)
df

# %%
df

# %% [markdown]
# * df.columns 로 출력되는 리스트 길이와 같은 새로운 이름의 리스트로 덮어쓰기

# %%
df.columns

# %%
newName = ['승객번호', '이름', '생존여부', '선실등급', '성별', '나이',
           '형제자매수', '부모자식수', '티켓번호', '티켓가격', 
           '선실번호', '승선지']

# %%
df.columns = newName
df
# Out:
#      승객번호  이름  생존여부                                               선실등급  \
# 0       1   0     3                            Braund, Mr. Owen Harris
# 1       2   1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3   1     3                             Heikkinen, Miss. Laina
# 3       4   1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5   0     3                           Allen, Mr. William Henry
# ..    ...  ..   ...                                                ...
# 886   887   0     2                              Montvila, Rev. Juozas
# 887   888   1     1                       Graham, Miss. Margaret Edith
# 888   889   0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890   1     1                              Behr, Mr. Karl Howell
# 890   891   0     3                                Dooley, Mr. Patrick
#
#          성별    나이  형제자매수  부모자식수              티켓번호     티켓가격  선실번호 승선지
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN   S
# 1    female  38.0      1      0          PC 17599  71.2833   C85   C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN   S
# 3    female  35.0      1      0            113803  53.1000  C123   S
# 4      male  35.0      0      0            373450   8.0500   NaN   S
# ..      ...   ...    ...    ...               ...      ...   ...  ..
# 886    male  27.0      0      0            211536  13.0000   NaN   S
# 887  female  19.0      0      0            112053  30.0000   B42   S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN   S
# 889    male  26.0      0      0            111369  30.0000  C148   C
# 890    male  32.0      0      0            370376   7.7500   NaN   Q
#
# [891 rows x 12 columns]

# %% [markdown]
# * 컬럼 추가하기
# * 변수명['컬럼명'] = value

# %%
df['가족수'] = 0

# %%
df
# Out:
#      승객번호                                                 이름  생존여부  선실등급  \
# 영번      1                            Braund, Mr. Owen Harris     0     3
# 일번      2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 2       3                             Heikkinen, Miss. Laina     1     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1     1
# 4       5                           Allen, Mr. William Henry     0     3
# ..    ...                                                ...   ...   ...
# 886   887                              Montvila, Rev. Juozas     0     2
# 887   888                       Graham, Miss. Margaret Edith     1     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     0     3
# 889   890                              Behr, Mr. Karl Howell     1     1
# 890   891                                Dooley, Mr. Patrick     0     3
#
#          성별    나이  형제자매수  부모자식수              티켓번호     티켓가격  선실번호 목적지  가족수
# 영번     male  22.0      1      0         A/5 21171   7.2500   NaN   S    0
# 일번   female  38.0      1      0          PC 17599  71.2833   C85   C    0
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN   S    0
# 3    female  35.0      1      0            113803  53.1000  C123   S    0
# 4    female  35.0      0      0            373450   8.0500   NaN   S    0
# ..      ...   ...    ...    ...               ...      ...   ...  ..  ...
# 886    male  27.0      0      0            211536  13.0000   NaN   S    0
# 887  female  19.0      0      0            112053  30.0000   B42   S    0
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN   S    0
# 889    male  26.0      0      0            111369  30.0000  C148   C    0
# 890    male  32.0      0      0            370376   7.7500   NaN   Q    0
#
# [891 rows x 13 columns]

# %%
df['가족수'] = df['형제자매수'] + df['부모자식수']
df
# Out:
#      승객번호                                                 이름  생존여부  선실등급  \
# 영번      1                            Braund, Mr. Owen Harris     0     3
# 일번      2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 2       3                             Heikkinen, Miss. Laina     1     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1     1
# 4       5                           Allen, Mr. William Henry     0     3
# ..    ...                                                ...   ...   ...
# 886   887                              Montvila, Rev. Juozas     0     2
# 887   888                       Graham, Miss. Margaret Edith     1     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     0     3
# 889   890                              Behr, Mr. Karl Howell     1     1
# 890   891                                Dooley, Mr. Patrick     0     3
#
#          성별    나이  형제자매수  부모자식수              티켓번호     티켓가격  선실번호 목적지  가족수
# 영번     male  22.0      1      0         A/5 21171   7.2500   NaN   S    1
# 일번   female  38.0      1      0          PC 17599  71.2833   C85   C    1
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN   S    0
# 3    female  35.0      1      0            113803  53.1000  C123   S    1
# 4    female  35.0      0      0            373450   8.0500   NaN   S    0
# ..      ...   ...    ...    ...               ...      ...   ...  ..  ...
# 886    male  27.0      0      0            211536  13.0000   NaN   S    0
# 887  female  19.0      0      0            112053  30.0000   B42   S    0
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN   S    3
# 889    male  26.0      0      0            111369  30.0000  C148   C    0
# 890    male  32.0      0      0            370376   7.7500   NaN   Q    0
#
# [891 rows x 13 columns]

# %% [markdown]
# * 컬럼 삭제하기
# * del df['컬럼명']
# * df.drop('컬럼명', axis=1, inplace=True)

# %%
del df['형제자매수']
df
# Out:
#      승객번호                                                 이름  생존여부  선실등급  \
# 영번      1                            Braund, Mr. Owen Harris     0     3
# 일번      2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 2       3                             Heikkinen, Miss. Laina     1     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1     1
# 4       5                           Allen, Mr. William Henry     0     3
# ..    ...                                                ...   ...   ...
# 886   887                              Montvila, Rev. Juozas     0     2
# 887   888                       Graham, Miss. Margaret Edith     1     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     0     3
# 889   890                              Behr, Mr. Karl Howell     1     1
# 890   891                                Dooley, Mr. Patrick     0     3
#
#          성별    나이  부모자식수              티켓번호     티켓가격  선실번호 목적지  가족수
# 영번     male  22.0      0         A/5 21171   7.2500   NaN   S    1
# 일번   female  38.0      0          PC 17599  71.2833   C85   C    1
# 2    female  26.0      0  STON/O2. 3101282   7.9250   NaN   S    0
# 3    female  35.0      0            113803  53.1000  C123   S    1
# 4    female  35.0      0            373450   8.0500   NaN   S    0
# ..      ...   ...    ...               ...      ...   ...  ..  ...
# 886    male  27.0      0            211536  13.0000   NaN   S    0
# 887  female  19.0      0            112053  30.0000   B42   S    0
# 888  female   NaN      2        W./C. 6607  23.4500   NaN   S    3
# 889    male  26.0      0            111369  30.0000  C148   C    0
# 890    male  32.0      0            370376   7.7500   NaN   Q    0
#
# [891 rows x 12 columns]

# %%
df.pop('부모자식수')
df
# Out:
#      승객번호                                                 이름  생존여부  선실등급  \
# 영번      1                            Braund, Mr. Owen Harris     0     3
# 일번      2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 2       3                             Heikkinen, Miss. Laina     1     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1     1
# 4       5                           Allen, Mr. William Henry     0     3
# ..    ...                                                ...   ...   ...
# 886   887                              Montvila, Rev. Juozas     0     2
# 887   888                       Graham, Miss. Margaret Edith     1     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     0     3
# 889   890                              Behr, Mr. Karl Howell     1     1
# 890   891                                Dooley, Mr. Patrick     0     3
#
#          성별    나이              티켓번호     티켓가격  선실번호 목적지  가족수
# 영번     male  22.0         A/5 21171   7.2500   NaN   S    1
# 일번   female  38.0          PC 17599  71.2833   C85   C    1
# 2    female  26.0  STON/O2. 3101282   7.9250   NaN   S    0
# 3    female  35.0            113803  53.1000  C123   S    1
# 4    female  35.0            373450   8.0500   NaN   S    0
# ..      ...   ...               ...      ...   ...  ..  ...
# 886    male  27.0            211536  13.0000   NaN   S    0
# 887  female  19.0            112053  30.0000   B42   S    0
# 888  female   NaN        W./C. 6607  23.4500   NaN   S    3
# 889    male  26.0            111369  30.0000  C148   C    0
# 890    male  32.0            370376   7.7500   NaN   Q    0
#
# [891 rows x 11 columns]

# %%
df = df.drop('가족수', axis=1)
df
# Out:
#      승객번호                                                 이름  생존여부  선실등급  \
# 영번      1                            Braund, Mr. Owen Harris     0     3
# 일번      2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 2       3                             Heikkinen, Miss. Laina     1     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1     1
# 4       5                           Allen, Mr. William Henry     0     3
# ..    ...                                                ...   ...   ...
# 886   887                              Montvila, Rev. Juozas     0     2
# 887   888                       Graham, Miss. Margaret Edith     1     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     0     3
# 889   890                              Behr, Mr. Karl Howell     1     1
# 890   891                                Dooley, Mr. Patrick     0     3
#
#          성별    나이              티켓번호     티켓가격  선실번호 목적지
# 영번     male  22.0         A/5 21171   7.2500   NaN   S
# 일번   female  38.0          PC 17599  71.2833   C85   C
# 2    female  26.0  STON/O2. 3101282   7.9250   NaN   S
# 3    female  35.0            113803  53.1000  C123   S
# 4    female  35.0            373450   8.0500   NaN   S
# ..      ...   ...               ...      ...   ...  ..
# 886    male  27.0            211536  13.0000   NaN   S
# 887  female  19.0            112053  30.0000   B42   S
# 888  female   NaN        W./C. 6607  23.4500   NaN   S
# 889    male  26.0            111369  30.0000  C148   C
# 890    male  32.0            370376   7.7500   NaN   Q
#
# [891 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['승객번호', '이름', '생존여부', '선실등급', '성별', '나이', '티켓번호', '티켓가격', '선실번호',
#        '목적지'],
#       dtype='object')

# %%
drop_cols = ['승객번호', '이름', '티켓번호', '티켓가격', '선실번호', '목적지',
       ]

# %%
df.drop(drop_cols, axis=1)
# Out:
#      생존여부  선실등급      성별    나이
# 영번      0     3    male  22.0
# 일번      1     1  female  38.0
# 2       1     3  female  26.0
# 3       1     1  female  35.0
# 4       0     3  female  35.0
# ..    ...   ...     ...   ...
# 886     0     2    male  27.0
# 887     1     1  female  19.0
# 888     0     3  female   NaN
# 889     1     1    male  26.0
# 890     0     3    male  32.0
#
# [891 rows x 4 columns]

# %% [markdown]
# * 데이터 타입 바꾸기
# * astype(자료형)
# * apply(형변환함수)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 888 entries, 일번 to 889
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    888 non-null    int64
#  1   이름      888 non-null    object
#  2   생존여부    888 non-null    int64
#  3   선실등급    888 non-null    int64
#  4   성별      888 non-null    object
#  5   나이      711 non-null    float64
#  6   티켓번호    888 non-null    object
#  7   티켓가격    888 non-null    float64
#  8   선실번호    203 non-null    object
#  9   목적지     886 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 108.6+ KB

# %%
df['나이'] = df['나이'].astype('float16')
df['티켓가격'] = df['티켓가격'].astype('float16')
df['승객번호'] = df['승객번호'].astype('int8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    891 non-null    int8
#  1   이름      891 non-null    int64
#  2   생존여부    891 non-null    int64
#  3   선실등급    891 non-null    object
#  4   성별      891 non-null    object
#  5   나이      714 non-null    float16
#  6   형제자매수   891 non-null    int64
#  7   부모자식수   891 non-null    int64
#  8   티켓번호    891 non-null    object
#  9   티켓가격    891 non-null    float16
#  10  선실번호    204 non-null    object
#  11  승선지     889 non-null    object
# dtypes: float16(2), int64(4), int8(1), object(5)
# memory usage: 67.1+ KB

# %%
df['티켓가격'] = df['티켓가격'].apply(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 888 entries, 일번 to 889
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    888 non-null    object
#  1   이름      888 non-null    object
#  2   생존여부    888 non-null    int64
#  3   선실등급    888 non-null    int64
#  4   성별      888 non-null    object
#  5   나이      711 non-null    float16
#  6   티켓번호    888 non-null    object
#  7   티켓가격    888 non-null    float64
#  8   선실번호    203 non-null    object
#  9   목적지     886 non-null    object
# dtypes: float16(1), float64(1), int64(2), object(6)
# memory usage: 103.4+ KB

# %%
df['승객번호'] = df['승객번호'].apply(lambda x: "짝수" if float(x) % 2 == 0 else "홀수")
df.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[200], line 1
# ----> 1 df['승객번호'] = df['승객번호'].apply(lambda x: "짝수" if float(x) % 2 == 0 else "홀수")
#       2 df.info()
#       3 df
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[200], line 1, in <lambda>(x)
# ----> 1 df['승객번호'] = df['승객번호'].apply(lambda x: "짝수" if float(x) % 2 == 0 else "홀수")
#       2 df.info()
#       3 df
#
# ValueError: could not convert string to float: '홀수'

# %%
df
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#     승객번호                                                 이름  생존여부  선실등급  \
# 일번     2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 2      3                             Heikkinen, Miss. Laina     1     3
# 4      5                           Allen, Mr. William Henry     0     3
# 5      6                                   Moran, Mr. James     0     3
# 6      7                            McCarthy, Mr. Timothy J     0     1
# ..   ...                                                ...   ...   ...
# 885  118               Rice, Mrs. William (Margaret Norton)     0     3
# 886  119                              Montvila, Rev. Juozas     0     2
# 887  120                       Graham, Miss. Margaret Edith     1     1
# 888  121           Johnston, Miss. Catherine Helen "Carrie"     0     3
# 889  122                              Behr, Mr. Karl Howell     1     1
#
#          성별    나이              티켓번호     티켓가격  선실번호 목적지
# 일번   female  38.0          PC 17599  71.2833   C85   C
# 2    female  26.0  STON/O2. 3101282   7.9250   NaN   S
# 4    female  35.0            373450   8.0500   NaN   S
# 5      male   NaN            330877   8.4583   NaN   Q
# 6      male  54.0             17463  51.8625   E46   S
# ..      ...   ...               ...      ...   ...  ..
# 885  female  39.0            382652  29.1250   NaN   Q
# 886    male  27.0            211536  13.0000   NaN   S
# 887  female  19.0            112053  30.0000   B42   S
# 888  female   NaN        W./C. 6607  23.4500   NaN   S
# 889    male  26.0            111369  30.0000  C148   C
#
# [888 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 888 entries, 일번 to 889
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    888 non-null    object
#  1   이름      888 non-null    object
#  2   생존여부    888 non-null    int64
#  3   선실등급    888 non-null    int64
#  4   성별      888 non-null    object
#  5   나이      711 non-null    float16
#  6   티켓번호    888 non-null    object
#  7   티켓가격    888 non-null    float64
#  8   선실번호    203 non-null    object
#  9   목적지     886 non-null    object
# dtypes: float16(1), float64(1), int64(2), object(6)
# memory usage: 103.4+ KB

# %% [markdown]
# # 판다스 데이터프레임에서 조건에 맞는 행만 가져오기
# * df[df['컬럼명'] 조건식]
# * 조건식 연산자 <, <=, >, >=, ==, !=, &, |

# %%
df[df['승객번호'] == 3]
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#      승객번호  이름  생존여부                    선실등급      성별    나이  형제자매수  부모자식수  \
# 2       3   1     3  Heikkinen, Miss. Laina  female  26.0      0      0
# 258     3   1     1        Ward, Miss. Anna  female  35.0      0      0
# 514     3   0     3       Coleff, Mr. Satio    male  24.0      0      0
# 770     3   0     3  Lievens, Mr. Rene Aime    male  24.0      0      0
#
#                  티켓번호        티켓가격 선실번호 승선지
# 2    STON/O2. 3101282    7.925781  NaN   S
# 258          PC 17755  512.500000  NaN   C
# 514            349209    7.496094  NaN   S
# 770            345781    9.500000  NaN   S

# %%
df[df['승객번호'] == "3"]
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#     승객번호                      이름  생존여부  선실등급      성별    나이              티켓번호  \
# 2      3  Heikkinen, Miss. Laina     1     3  female  26.0  STON/O2. 3101282
# 258    3        Ward, Miss. Anna     1     1  female  35.0          PC 17755
# 514    3       Coleff, Mr. Satio     0     3    male  24.0            349209
# 770    3  Lievens, Mr. Rene Aime     0     3    male  24.0            345781
#
#          티켓가격 선실번호 목적지
# 2      7.9250  NaN   S
# 258  512.3292  NaN   C
# 514    7.4958  NaN   S
# 770    9.5000  NaN   S

# %%
df[df['승객번호'] == "홀수"]
# Out:
#     승객번호                                                 이름  생존여부  선실등급  \
# 0     홀수                            Braund, Mr. Owen Harris     0     3
# 2     홀수                             Heikkinen, Miss. Laina     1     3
# 4     홀수                           Allen, Mr. William Henry     0     3
# 6     홀수                            McCarthy, Mr. Timothy J     0     1
# 8     홀수  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     1     3
# ..   ...                                                ...   ...   ...
# 882   홀수                       Dahlberg, Miss. Gerda Ulrika     0     3
# 884   홀수                             Sutehall, Mr. Henry Jr     0     3
# 886   홀수                              Montvila, Rev. Juozas     0     2
# 888   홀수           Johnston, Miss. Catherine Helen "Carrie"     0     3
# 890   홀수                                Dooley, Mr. Patrick     0     3
#
#          성별    나이              티켓번호     티켓가격 선실번호 목적지  가족수
# 0      male  22.0         A/5 21171   7.2500  NaN   S    1
# 2    female  26.0  STON/O2. 3101282   7.9250  NaN   S    0
# 4      male  35.0            373450   8.0500  NaN   S    0
# 6      male  54.0             17463  51.8625  E46   S    0
# 8    female  27.0            347742  11.1333  NaN   S    2
# ..      ...   ...               ...      ...  ...  ..  ...
# 882  female  22.0              7552  10.5167  NaN   S    0
# 884    male  25.0   SOTON/OQ 392076   7.0500  NaN   S    0
# 886    male  27.0            211536  13.0000  NaN   S    0
# 888  female   NaN        W./C. 6607  23.4500  NaN   S    3
# 890    male  32.0            370376   7.7500  NaN   Q    0
#
# [446 rows x 11 columns]

# %%
# 나이가 35 초과인 사람만 필터링
df[df['나이'] > 35]
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#      승객번호  이름  생존여부                                               선실등급  \
# 1       2   1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6       7   0     1                            McCarthy, Mr. Timothy J
# 11     12   1     1                           Bonnell, Miss. Elizabeth
# 13     14   0     3                        Andersson, Mr. Anders Johan
# 15     16   1     2                   Hewlett, Mrs. (Mary D Kingcome)
# ..    ...  ..   ...                                                ...
# 865    98   1     2                           Bystrom, Mrs. (Karolina)
# 871   104   1     1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 873   106   0     3                        Vander Cruyssen, Mr. Victor
# 879   112   1     1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885   118   0     3               Rice, Mrs. William (Margaret Norton)
#
#          성별    나이  형제자매수  부모자식수      티켓번호       티켓가격  선실번호 승선지
# 1    female  38.0      1      0  PC 17599  71.312500   C85   C
# 6      male  54.0      0      0     17463  51.875000   E46   S
# 11   female  58.0      0      0    113783  26.546875  C103   S
# 13     male  39.0      1      5    347082  31.281250   NaN   S
# 15   female  55.0      0      0    248706  16.000000   NaN   S
# ..      ...   ...    ...    ...       ...        ...   ...  ..
# 865  female  42.0      0      0    236852  13.000000   NaN   S
# 871  female  47.0      1      1     11751  52.562500   D35   S
# 873    male  47.0      0      0    345765   9.000000   NaN   S
# 879  female  56.0      0      1     11767  83.187500   C50   C
# 885  female  39.0      0      5    382652  29.125000   NaN   Q
#
# [217 rows x 12 columns]

# %% [markdown]
# * 여성이면서 나이가 35세 초과인 행 찾기 and 조건

# %%
df[(df['성별'] == 'female') & (df['나이'] > 35)]
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#      승객번호  이름  생존여부                                               선실등급  \
# 1       2   1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 11     12   1     1                           Bonnell, Miss. Elizabeth
# 15     16   1     2                   Hewlett, Mrs. (Mary D Kingcome)
# 25     26   1     3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 40     41   0     3     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# ..    ...  ..   ...                                                ...
# 862    95   1     1  Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 865    98   1     2                           Bystrom, Mrs. (Karolina)
# 871   104   1     1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 879   112   1     1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885   118   0     3               Rice, Mrs. William (Margaret Norton)
#
#          성별    나이  형제자매수  부모자식수      티켓번호       티켓가격  선실번호 승선지
# 1    female  38.0      1      0  PC 17599  71.312500   C85   C
# 11   female  58.0      0      0    113783  26.546875  C103   S
# 15   female  55.0      0      0    248706  16.000000   NaN   S
# 25   female  38.0      1      5    347077  31.390625   NaN   S
# 40   female  40.0      1      0      7546   9.476562   NaN   S
# ..      ...   ...    ...    ...       ...        ...   ...  ..
# 862  female  48.0      0      0     17466  25.921875   D17   S
# 865  female  42.0      0      0    236852  13.000000   NaN   S
# 871  female  47.0      1      1     11751  52.562500   D35   S
# 879  female  56.0      0      1     11767  83.187500   C50   C
# 885  female  39.0      0      5    382652  29.125000   NaN   Q
#
# [73 rows x 12 columns]

# %% [markdown]
# * 성별이 male, 선실등급 1, 생존여부 1인 사람을 찾으세요.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    891 non-null    int8
#  1   이름      891 non-null    int64
#  2   생존여부    891 non-null    int64
#  3   선실등급    891 non-null    object
#  4   성별      891 non-null    object
#  5   나이      714 non-null    float16
#  6   형제자매수   891 non-null    int64
#  7   부모자식수   891 non-null    int64
#  8   티켓번호    891 non-null    object
#  9   티켓가격    891 non-null    float16
#  10  선실번호    204 non-null    object
#  11  승선지     889 non-null    object
# dtypes: float16(2), int64(4), int8(1), object(5)
# memory usage: 67.1+ KB

# %%
# df = df.rename(columns={'이름': '선실등급', '선실등급':'이름'})
df = df.rename(columns={'생존여부': '선실등급', '선실등급':'생존여부'})
df
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#      승객번호  생존여부  선실등급                                                 이름  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     0     3                           Allen, Mr. William Henry
# ..    ...   ...   ...                                                ...
# 886   119     0     2                              Montvila, Rev. Juozas
# 887   120     1     1                       Graham, Miss. Margaret Edith
# 888   121     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   122     1     1                              Behr, Mr. Karl Howell
# 890   123     0     3                                Dooley, Mr. Patrick
#
#          성별    나이  형제자매수  부모자식수              티켓번호       티켓가격  선실번호 승선지
# 0      male  22.0      1      0         A/5 21171   7.250000   NaN   S
# 1    female  38.0      1      0          PC 17599  71.312500   C85   C
# 2    female  26.0      0      0  STON/O2. 3101282   7.925781   NaN   S
# 3    female  35.0      1      0            113803  53.093750  C123   S
# 4      male  35.0      0      0            373450   8.046875   NaN   S
# ..      ...   ...    ...    ...               ...        ...   ...  ..
# 886    male  27.0      0      0            211536  13.000000   NaN   S
# 887  female  19.0      0      0            112053  30.000000   B42   S
# 888  female   NaN      1      2        W./C. 6607  23.453125   NaN   S
# 889    male  26.0      0      0            111369  30.000000  C148   C
# 890    male  32.0      0      0            370376   7.750000   NaN   Q
#
# [891 rows x 12 columns]

# %%
df[(df['성별'] == 'male') & (df['선실등급'] == 1) & (df['생존여부'] == 1)]
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#      승객번호  생존여부  선실등급                                             이름    성별  \
# 23     24     1     1                   Sloper, Mr. William Thompson  male
# 55     56     1     1                              Woolner, Mr. Hugh  male
# 97     98     1     1                Greenfield, Mr. William Bertram  male
# 187   -68     1     1  Romaine, Mr. Charles Hallace ("Mr C Rolmane")  male
# 209   -46     1     1                               Blank, Mr. Henry  male
# 224   -31     1     1                   Hoyt, Mr. Frederick Maxfield  male
# 248    -7     1     1                  Beckwith, Mr. Richard Leonard  male
# 298    43     1     1                          Saalfeld, Mr. Adolphe  male
# 305    50     1     1                 Allison, Master. Hudson Trevor  male
# 370   115     1     1                    Harder, Mr. George Achilles  male
# 390  -121     1     1                     Carter, Mr. William Ernest  male
# 430   -81     1     1      Bjornstrom-Steffansson, Mr. Mauritz Hakan  male
# 445   -66     1     1                      Dodge, Master. Washington  male
# 447   -64     1     1                    Seward, Mr. Frederic Kimber  male
# 449   -62     1     1                 Peuchen, Major. Arthur Godfrey  male
# 453   -58     1     1                       Goldenberg, Mr. Samuel L  male
# 460   -51     1     1                            Anderson, Mr. Harry  male
# 484   -27     1     1                        Bishop, Mr. Dickinson H  male
# 507    -4     1     1  Bradley, Mr. George ("George Arthur Brayton")  male
# 512     1     1     1                      McGough, Mr. James Robert  male
# 550    39     1     1                    Thayer, Mr. John Borland Jr  male
# 572    61     1     1               Flynn, Mr. John Irwin ("Irving")  male
# 587    76     1     1               Frolicher-Stehli, Mr. Maxmillian  male
# 599    88     1     1   Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")  male
# 604    93     1     1                Homer, Mr. Harry ("Mr E Haven")  male
# 607    96     1     1                    Daniel, Mr. Robert Williams  male
# 621   110     1     1                   Kimball, Mr. Edwin Nelson Jr  male
# 630   119     1     1           Barkworth, Mr. Algernon Henry Wilson  male
# 632   121     1     1                      Stahelin-Maeglin, Dr. Max  male
# 645  -122     1     1                      Harper, Mr. Henry Sleeper  male
# 647  -120     1     1            Simonius-Blumer, Col. Oberst Alfons  male
# 660  -107     1     1                  Frauenthal, Dr. Henry William  male
# 679   -88     1     1             Cardeza, Mr. Thomas Drake Martinez  male
# 681   -86     1     1                             Hassab, Mr. Hammad  male
# 690   -77     1     1                        Dick, Mr. Albert Adrian  male
# 701   -66     1     1               Silverthorne, Mr. Spencer Victor  male
# 707   -60     1     1              Calderhead, Mr. Edward Pennington  male
# 712   -55     1     1                       Taylor, Mr. Elmer Zebley  male
# 724   -43     1     1                  Chambers, Mr. Norman Campbell  male
# 737   -30     1     1                         Lesurer, Mr. Gustave J  male
# 740   -27     1     1                    Hawksford, Mr. Walter James  male
# 802    35     1     1            Carter, Master. William Thornton II  male
# 839    72     1     1                           Marechal, Mr. Pierre  male
# 857    90     1     1                         Daly, Mr. Peter Denis   male
# 889   122     1     1                          Behr, Mr. Karl Howell  male
#
#             나이  형제자매수  부모자식수      티켓번호        티켓가격         선실번호 승선지
# 23   28.000000      0      0    113788   35.500000           A6   S
# 55         NaN      0      0     19947   35.500000          C52   S
# 97   23.000000      0      1  PC 17759   63.343750      D10 D12   C
# 187  45.000000      0      0    111428   26.546875          NaN   S
# 209  40.000000      0      0    112277   31.000000          A31   C
# 224  38.000000      1      0     19943   90.000000          C93   S
# 248  37.000000      1      1     11751   52.562500          D35   S
# 298        NaN      0      0     19988   30.500000         C106   S
# 305   0.919922      1      2    113781  151.500000      C22 C26   S
# 370  25.000000      1      0     11765   55.437500          E50   C
# 390  36.000000      1      2    113760  120.000000      B96 B98   S
# 430  28.000000      0      0    110564   26.546875          C52   S
# 445   4.000000      0      2     33638   81.875000          A34   S
# 447  34.000000      0      0    113794   26.546875          NaN   S
# 449  52.000000      0      0    113786   30.500000         C104   S
# 453  49.000000      1      0     17453   89.125000          C92   C
# 460  48.000000      0      0     19952   26.546875          E12   S
# 484  25.000000      1      0     11967   91.062500          B49   C
# 507        NaN      0      0    111427   26.546875          NaN   S
# 512  36.000000      0      0  PC 17473   26.281250          E25   S
# 550  17.000000      0      2     17421  110.875000          C70   C
# 572  36.000000      0      0  PC 17474   26.390625          E25   S
# 587  60.000000      1      1     13567   79.187500          B41   C
# 599  49.000000      1      0  PC 17485   56.937500          A20   C
# 604  35.000000      0      0    111426   26.546875          NaN   C
# 607  27.000000      0      0    113804   30.500000          NaN   S
# 621  42.000000      1      0     11753   52.562500          D19   S
# 630  80.000000      0      0     27042   30.000000          A23   S
# 632  32.000000      0      0     13214   30.500000          B50   C
# 645  48.000000      1      0  PC 17572   76.750000          D33   C
# 647  56.000000      0      0     13213   35.500000          A26   C
# 660  50.000000      2      0  PC 17611  133.625000          NaN   S
# 679  36.000000      0      1  PC 17755  512.500000  B51 B53 B55   C
# 681  27.000000      0      0  PC 17572   76.750000          D49   C
# 690  31.000000      1      0     17474   57.000000          B20   S
# 701  35.000000      0      0  PC 17475   26.281250          E24   S
# 707  42.000000      0      0  PC 17476   26.281250          E24   S
# 712  48.000000      1      0     19996   52.000000         C126   S
# 724  27.000000      1      0    113806   53.093750           E8   S
# 737  35.000000      0      0  PC 17755  512.500000         B101   C
# 740        NaN      0      0     16988   30.000000          D45   S
# 802  11.000000      1      2    113760  120.000000      B96 B98   S
# 839        NaN      0      0     11774   29.703125          C47   C
# 857  51.000000      0      0    113055   26.546875          E17   S
# 889  26.000000      0      0    111369   30.000000         C148   C

# %% [markdown]
# * 선실 등급별 승차권 금액의 최소, 최대, 평균 등 4분위수를 보고싶다.

# %%
# 선실 등급이 1등석인 사람들의 승차권 금액 통계량을 보고 싶다.
# df[df['선실등급'] == 1, '티켓가격']
# df[df['선실등급'] == 1]['티켓가격'].describe()
df.loc[df['선실등급'] == 1, '티켓가격'].describe()
# Out:
# count    216.000000
# mean      84.125000
# std       78.375000
# min        0.000000
# 25%       30.925781
# 50%       60.296875
# 75%       93.500000
# max      512.500000
# Name: 티켓가격, dtype: float64

# %%
df[df['티켓가격'] > 512]
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#     승객번호                                  이름  생존여부  선실등급      성별    나이  \
# 258    3                    Ward, Miss. Anna     1     1  female  35.0
# 679  -88  Cardeza, Mr. Thomas Drake Martinez     1     1    male  36.0
# 737  -30              Lesurer, Mr. Gustave J     1     1    male  35.0
#
#          티켓번호      티켓가격         선실번호 목적지
# 258  PC 17755  512.3292          NaN   C
# 679  PC 17755  512.3292  B51 B53 B55   C
# 737  PC 17755  512.3292         B101   C

# %%
df[df['티켓가격'] == 0]
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#     승객번호                                이름  생존여부  선실등급    성별    나이    티켓번호  \
# 179  -76               Leonard, Mr. Lionel     0     3  male  36.0    LINE
# 263    8             Harrison, Mr. William     0     1  male  40.0  112059
# 271   16      Tornquist, Mr. William Henry     1     3  male  25.0    LINE
# 277   22       Parkes, Mr. Francis "Frank"     0     2  male   NaN  239853
# 302   47   Johnson, Mr. William Cahoone Jr     0     3  male  19.0    LINE
# 413  -98    Cunningham, Mr. Alfred Fleming     0     2  male   NaN  239853
# 466  -45             Campbell, Mr. William     0     2  male   NaN  239853
# 481  -30  Frost, Mr. Anthony Wood "Archie"     0     2  male   NaN  239854
# 597   86               Johnson, Mr. Alfred     0     3  male  49.0    LINE
# 633  122     Parr, Mr. William Henry Marsh     0     1  male   NaN  112052
# 674  -93        Watson, Mr. Ennis Hastings     0     2  male   NaN  239856
# 732  -35              Knight, Mr. Robert J     0     2  male   NaN  239855
# 806   39            Andrews, Mr. Thomas Jr     0     1  male  39.0  112050
# 815   48                  Fry, Mr. Richard     0     1  male   NaN  112058
# 822   55   Reuchlin, Jonkheer. John George     0     1  male  38.0   19972
#
#      티켓가격  선실번호 목적지
# 179   0.0   NaN   S
# 263   0.0   B94   S
# 271   0.0   NaN   S
# 277   0.0   NaN   S
# 302   0.0   NaN   S
# 413   0.0   NaN   S
# 466   0.0   NaN   S
# 481   0.0   NaN   S
# 597   0.0   NaN   S
# 633   0.0   NaN   S
# 674   0.0   NaN   S
# 732   0.0   NaN   S
# 806   0.0   A36   S
# 815   0.0  B102   S
# 822   0.0   NaN   S

# %% [markdown]
# #  조건에 맞는 행을 찾은 후 특정 컬럼만 조회하기

# %% [markdown]
# * 선실등급이 1이거나 2이면서 생존한 여성 중에서 이름 컬럼만 보고 싶을 때

# %%
df.columns
# Out:
# Index(['승객번호', '이름', '생존여부', '선실등급', '성별', '나이', '티켓번호', '티켓가격', '선실번호', '목적지',
#        '가족수'],
#       dtype='object')

# %%
df.loc[((df['선실등급'] == 1) | (df['선실등급'] == 2)) & (df['생존여부'] == 1) & (df['성별'] == 'female'), '이름']
# Out:
# 일번     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 11                              Bonnell, Miss. Elizabeth
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
#                              ...
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 874                Abelson, Mrs. Samuel (Hannah Wizosky)
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 887                         Graham, Miss. Margaret Edith
# Name: 이름, Length: 160, dtype: object

# %%
df[((df['선실등급'] == 1) | (df['선실등급'] == 2)) & (df['생존여부'] == 1) & (df['성별'] == 'female')]['이름']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 11                              Bonnell, Miss. Elizabeth
# 15                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 874                Abelson, Mrs. Samuel (Hannah Wizosky)
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 887                         Graham, Miss. Margaret Edith
# Name: 이름, Length: 161, dtype: object

# %% [markdown]
# * 나이가 25세 미만이면서 생존자의 이름

# %%
df.loc[(df['나이'] < 25) & (df['생존여부'] == 1), '이름']
# Out:
# 9           Nasser, Mrs. Nicholas (Adele Achem)
# 10              Sandstrom, Miss. Marguerite Rut
# 22                  McGowan, Miss. Anna "Annie"
# 39                  Nicola-Yarred, Miss. Jamila
# 43     Laroche, Miss. Simonne Marie Anne Andree
#                          ...
# 855                  Aks, Mrs. Sam (Leah Rosen)
# 858       Baclini, Mrs. Solomon (Latifa Qurban)
# 869             Johnson, Master. Harold Theodor
# 875            Najib, Miss. Adele Kiamie "Jane"
# 887                Graham, Miss. Margaret Edith
# Name: 이름, Length: 118, dtype: object

# %%
# 결과에서 이름과 나이를 같이 보고 싶다.
df.loc[(df['나이'] < 25) & (df['생존여부'] == 1), ['이름', '나이']]
# Out:
#                                            이름    나이
# 9         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10            Sandstrom, Miss. Marguerite Rut   4.0
# 22                McGowan, Miss. Anna "Annie"  15.0
# 39                Nicola-Yarred, Miss. Jamila  14.0
# 43   Laroche, Miss. Simonne Marie Anne Andree   3.0
# ..                                        ...   ...
# 855                Aks, Mrs. Sam (Leah Rosen)  18.0
# 858     Baclini, Mrs. Solomon (Latifa Qurban)  24.0
# 869           Johnson, Master. Harold Theodor   4.0
# 875          Najib, Miss. Adele Kiamie "Jane"  15.0
# 887              Graham, Miss. Margaret Edith  19.0
#
# [118 rows x 2 columns]

# %%
df[(df.나이 < 25) & (df.생존여부 == 1)][['이름', '나이']]
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#                                            이름    나이
# 9         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10            Sandstrom, Miss. Marguerite Rut   4.0
# 22                McGowan, Miss. Anna "Annie"  15.0
# 39                Nicola-Yarred, Miss. Jamila  14.0
# 43   Laroche, Miss. Simonne Marie Anne Andree   3.0
# ..                                        ...   ...
# 855                Aks, Mrs. Sam (Leah Rosen)  18.0
# 858     Baclini, Mrs. Solomon (Latifa Qurban)  24.0
# 869           Johnson, Master. Harold Theodor   4.0
# 875          Najib, Miss. Adele Kiamie "Jane"  15.0
# 887              Graham, Miss. Margaret Edith  19.0
#
# [118 rows x 2 columns]

# %%
df[(df.나이 < 25) & (df.생존여부 == 1)][['이름', '나이']]
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#                                            이름    나이
# 9         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10            Sandstrom, Miss. Marguerite Rut   4.0
# 22                McGowan, Miss. Anna "Annie"  15.0
# 39                Nicola-Yarred, Miss. Jamila  14.0
# 43   Laroche, Miss. Simonne Marie Anne Andree   3.0
# ..                                        ...   ...
# 855                Aks, Mrs. Sam (Leah Rosen)  18.0
# 858     Baclini, Mrs. Solomon (Latifa Qurban)  24.0
# 869           Johnson, Master. Harold Theodor   4.0
# 875          Najib, Miss. Adele Kiamie "Jane"  15.0
# 887              Graham, Miss. Margaret Edith  19.0
#
# [118 rows x 2 columns]

# %%
df2[["이름", "나이"]]
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#                                            이름    나이
# 9         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10            Sandstrom, Miss. Marguerite Rut   4.0
# 22                McGowan, Miss. Anna "Annie"  15.0
# 39                Nicola-Yarred, Miss. Jamila  14.0
# 43   Laroche, Miss. Simonne Marie Anne Andree   3.0
# ..                                        ...   ...
# 855                Aks, Mrs. Sam (Leah Rosen)  18.0
# 858     Baclini, Mrs. Solomon (Latifa Qurban)  24.0
# 869           Johnson, Master. Harold Theodor   4.0
# 875          Najib, Miss. Adele Kiamie "Jane"  15.0
# 887              Graham, Miss. Margaret Edith  19.0
#
# [118 rows x 2 columns]

# %%
df.나이
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: 나이, Length: 891, dtype: float64

# %% [markdown]
# .isin([조건1, 조건2]) or 조건을 여러 번 써야 할 때 간단히 표현

# %% [markdown]
# * 선실등급을 1, 2등인 사람을 추출

# %%
df[(df['선실등급'] == 1) | (df['선실등급'] == 2)]
# Out:
#     승객번호                                                 이름  생존여부  선실등급  \
# 1     짝수  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 3     짝수       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1     1
# 6     홀수                            McCarthy, Mr. Timothy J     0     1
# 9     짝수                Nasser, Mrs. Nicholas (Adele Achem)     1     2
# 11    짝수                           Bonnell, Miss. Elizabeth     1     1
# ..   ...                                                ...   ...   ...
# 880   홀수       Shelley, Mrs. William (Imanita Parrish Hall)     1     2
# 883   짝수                      Banfield, Mr. Frederick James     0     2
# 886   홀수                              Montvila, Rev. Juozas     0     2
# 887   짝수                       Graham, Miss. Margaret Edith     1     1
# 889   짝수                              Behr, Mr. Karl Howell     1     1
#
#          성별    나이              티켓번호     티켓가격  선실번호 목적지  가족수
# 1    female  38.0          PC 17599  71.2833   C85   C    1
# 3    female  35.0            113803  53.1000  C123   S    1
# 6      male  54.0             17463  51.8625   E46   S    0
# 9    female  14.0            237736  30.0708   NaN   C    1
# 11   female  58.0            113783  26.5500  C103   S    0
# ..      ...   ...               ...      ...   ...  ..  ...
# 880  female  25.0            230433  26.0000   NaN   S    1
# 883    male  28.0  C.A./SOTON 34068  10.5000   NaN   S    0
# 886    male  27.0            211536  13.0000   NaN   S    0
# 887  female  19.0            112053  30.0000   B42   S    0
# 889    male  26.0            111369  30.0000  C148   C    0
#
# [400 rows x 11 columns]

# %%
df[df['선실등급'].isin([1,2])]
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#     승객번호                                                 이름  생존여부  선실등급  \
# 일번     2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 6      7                            McCarthy, Mr. Timothy J     0     1
# 9     10                Nasser, Mrs. Nicholas (Adele Achem)     1     2
# 11    12                           Bonnell, Miss. Elizabeth     1     1
# 15    16                   Hewlett, Mrs. (Mary D Kingcome)      1     2
# ..   ...                                                ...   ...   ...
# 880  113       Shelley, Mrs. William (Imanita Parrish Hall)     1     2
# 883  116                      Banfield, Mr. Frederick James     0     2
# 886  119                              Montvila, Rev. Juozas     0     2
# 887  120                       Graham, Miss. Margaret Edith     1     1
# 889  122                              Behr, Mr. Karl Howell     1     1
#
#          성별    나이              티켓번호     티켓가격  선실번호 목적지
# 일번   female  38.0          PC 17599  71.2833   C85   C
# 6      male  54.0             17463  51.8625   E46   S
# 9    female  14.0            237736  30.0708   NaN   C
# 11   female  58.0            113783  26.5500  C103   S
# 15   female  55.0            248706  16.0000   NaN   S
# ..      ...   ...               ...      ...   ...  ..
# 880  female  25.0            230433  26.0000   NaN   S
# 883    male  28.0  C.A./SOTON 34068  10.5000   NaN   S
# 886    male  27.0            211536  13.0000   NaN   S
# 887  female  19.0            112053  30.0000   B42   S
# 889    male  26.0            111369  30.0000  C148   C
#
# [399 rows x 10 columns]

# %% [markdown]
# # 특정 단어를 포함한 행 찾기
# * 이름에 Joseph 가 들어간 사람 찾기
# * like %단어% - SQL
# * .str.contains("찾을 단어")

# %%
df[df['이름'] == "Joseph"]
# Out:
# Empty DataFrame
# Columns: [승객번호, 생존여부, 선실등급, 이름, 성별, 나이, 형제자매수, 부모자식수, 티켓번호, 티켓가격, 선실번호, 승선지]
# Index: []

# %%
df[df['이름'].str.contains("Joseph")]
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#      승객번호                                                 이름  생존여부  선실등급  \
# 20     21                               Fynney, Mr. Joseph J     0     2
# 34     35                            Meyer, Mr. Edgar Joseph     0     1
# 95     96                        Shorney, Mr. Charles Joseph     0     3
# 140  -115                      Boulos, Mrs. Joseph (Sultana)     0     3
# 145  -110                       Nicholls, Mr. Joseph Charles     0     2
# 194   -61          Brown, Mrs. James Joseph (Margaret Tobin)     1     1
# 375   120              Meyer, Mrs. Edgar Joseph (Leila Saks)     1     1
# 454   -57                                Peduzzi, Mr. Joseph     0     3
# 532    21                               Elias, Mr. Joseph Jr     0     3
# 559    48       de Messemaeker, Mrs. Guillaume Joseph (Emma)     1     3
# 578    67                   Caram, Mrs. Joseph (Maria Elias)     0     3
# 589    78                                Murdlin, Mr. Joseph     0     3
# 608    97  Laroche, Mrs. Joseph (Juliette Marie Louise La...     1     2
# 685   -82             Laroche, Mr. Joseph Philippe Lemercier     0     2
# 752   -15                   Vande Velde, Mr. Johannes Joseph     0     3
# 828    61                       McCormack, Mr. Thomas Joseph     1     3
#
#          성별    나이           티켓번호     티켓가격 선실번호 목적지
# 20     male  35.0         239865  26.0000  NaN   S
# 34     male  28.0       PC 17604  82.1708  NaN   C
# 95     male   NaN         374910   8.0500  NaN   S
# 140  female   NaN           2678  15.2458  NaN   C
# 145    male  19.0     C.A. 33112  36.7500  NaN   S
# 194  female  44.0       PC 17610  27.7208   B4   C
# 375  female   NaN       PC 17604  82.1708  NaN   C
# 454    male   NaN       A/5 2817   8.0500  NaN   S
# 532    male  17.0           2690   7.2292  NaN   C
# 559  female  36.0         345572  17.4000  NaN   S
# 578  female   NaN           2689  14.4583  NaN   C
# 589    male   NaN     A./5. 3235   8.0500  NaN   S
# 608  female  22.0  SC/Paris 2123  41.5792  NaN   C
# 685    male  25.0  SC/Paris 2123  41.5792  NaN   C
# 752    male  33.0         345780   9.5000  NaN   S
# 828    male   NaN         367228   7.7500  NaN   Q

# %%
# 티켓번호에 PC라는 문자가 포함된 티켓을 필터링
df[df['티켓번호'].str.contains("PC")]
# Out:
#     승객번호                                                 이름  생존여부  선실등급  \
# 1     짝수  Cumings, Mrs. John Bradley (Florence Briggs Th...     1     1
# 30    홀수                           Uruchurtu, Don. Manuel E     0     1
# 31    짝수     Spencer, Mrs. William Augustus (Marie Eugenie)     1     1
# 34    홀수                            Meyer, Mr. Edgar Joseph     0     1
# 52    홀수           Harper, Mrs. Henry Sleeper (Myna Haxtun)     1     1
# 64    홀수                              Stewart, Mr. Albert A     0     1
# 96    홀수                          Goldschmidt, Mr. George B     0     1
# 97    짝수                    Greenfield, Mr. William Bertram     1     1
# 118   홀수                           Baxter, Mr. Quigg Edmond     0     1
# 139   짝수                                 Giglio, Mr. Victor     0     1
# 155   짝수                        Williams, Mr. Charles Duane     0     1
# 168   홀수                                Baumann, Mr. John D     0     1
# 177   짝수                         Isham, Miss. Ann Elizabeth     0     1
# 194   홀수          Brown, Mrs. James Joseph (Margaret Tobin)     1     1
# 195   짝수                               Lurette, Miss. Elise     1     1
# 256   홀수                     Thorne, Mrs. Gertrude Maybelle     1     1
# 258   홀수                                   Ward, Miss. Anna     1     1
# 268   홀수      Graham, Mrs. William Thompson (Edith Junkins)     1     1
# 269   짝수                             Bissette, Miss. Amelia     1     1
# 273   짝수                              Natsch, Mr. Charles H     0     1
# 295   짝수                                  Lewy, Mr. Ervin G     0     1
# 299   짝수    Baxter, Mrs. James (Helene DeLaudeniere Chaput)     1     1
# 307   짝수  Penasco y Castellana, Mrs. Victor de Satode (M...     1     1
# 309   짝수                     Francatelli, Miss. Laura Mabel     1     1
# 311   짝수                         Ryerson, Miss. Emily Borie     1     1
# 325   짝수                           Young, Miss. Marie Grice     1     1
# 332   홀수                          Graham, Mr. George Edward     0     1
# 334   홀수  Frauenthal, Mrs. Henry William (Clara Heinshei...     1     1
# 369   짝수                      Aubart, Mme. Leontine Pauline     1     1
# 373   짝수                                Ringhini, Mr. Sante     0     1
# 375   짝수              Meyer, Mrs. Edgar Joseph (Leila Saks)     1     1
# 380   홀수                              Bidois, Miss. Rosalie     1     1
# 493   짝수                            Artagaveytia, Mr. Ramon     0     1
# 505   짝수         Penasco y Castellana, Mr. Victor de Satode     0     1
# 512   홀수                          McGough, Mr. James Robert     1     1
# 513   짝수     Rothschild, Mrs. Martin (Elizabeth L. Barrett)     1     1
# 527   짝수                                 Farthing, Mr. John     0     1
# 537   짝수                                LeRoy, Miss. Bertha     1     1
# 544   홀수                         Douglas, Mr. Walter Donald     0     1
# 557   짝수                                Robbins, Mr. Victor     0     1
# 572   홀수                   Flynn, Mr. John Irwin ("Irving")     1     1
# 599   짝수       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")     1     1
# 609   짝수                          Shutes, Miss. Elizabeth W     1     1
# 641   짝수                               Sagesser, Mlle. Emma     1     1
# 645   짝수                          Harper, Mr. Henry Sleeper     1     1
# 660   홀수                      Frauenthal, Dr. Henry William     1     1
# 679   짝수                 Cardeza, Mr. Thomas Drake Martinez     1     1
# 681   짝수                                 Hassab, Mr. Hammad     1     1
# 700   홀수  Astor, Mrs. John Jacob (Madeleine Talmadge Force)     1     1
# 701   짝수                   Silverthorne, Mr. Spencer Victor     1     1
# 707   짝수                  Calderhead, Mr. Edward Pennington     1     1
# 710   홀수   Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")     1     1
# 716   홀수                      Endres, Miss. Caroline Louise     1     1
# 737   짝수                             Lesurer, Mr. Gustave J     1     1
# 742   홀수              Ryerson, Miss. Susan Parker "Suzette"     1     1
# 789   짝수                           Guggenheim, Mr. Benjamin     0     1
# 793   짝수                           Hoyt, Mr. William Fisher     0     1
# 835   짝수                        Compton, Miss. Sara Rebecca     1     1
# 853   짝수                          Lines, Miss. Mary Conover     1     1
# 867   짝수               Roebling, Mr. Washington Augustus II     0     1
#
#          성별    나이      티켓번호      티켓가격             선실번호 목적지  가족수
# 1    female  38.0  PC 17599   71.2833              C85   C    1
# 30     male  40.0  PC 17601   27.7208              NaN   C    0
# 31   female   NaN  PC 17569  146.5208              B78   C    1
# 34     male  28.0  PC 17604   82.1708              NaN   C    1
# 52   female  49.0  PC 17572   76.7292              D33   C    1
# 64     male   NaN  PC 17605   27.7208              NaN   C    0
# 96     male  71.0  PC 17754   34.6542               A5   C    0
# 97     male  23.0  PC 17759   63.3583          D10 D12   C    1
# 118    male  24.0  PC 17558  247.5208          B58 B60   C    1
# 139    male  24.0  PC 17593   79.2000              B86   C    0
# 155    male  51.0  PC 17597   61.3792              NaN   C    1
# 168    male   NaN  PC 17318   25.9250              NaN   S    0
# 177  female  50.0  PC 17595   28.7125              C49   C    0
# 194  female  44.0  PC 17610   27.7208               B4   C    0
# 195  female  58.0  PC 17569  146.5208              B80   C    0
# 256  female   NaN  PC 17585   79.2000              NaN   C    0
# 258  female  35.0  PC 17755  512.3292              NaN   C    0
# 268  female  58.0  PC 17582  153.4625             C125   S    1
# 269  female  35.0  PC 17760  135.6333              C99   S    0
# 273    male  37.0  PC 17596   29.7000             C118   C    1
# 295    male   NaN  PC 17612   27.7208              NaN   C    0
# 299  female  50.0  PC 17558  247.5208          B58 B60   C    1
# 307  female  17.0  PC 17758  108.9000              C65   C    1
# 309  female  30.0  PC 17485   56.9292              E36   C    0
# 311  female  18.0  PC 17608  262.3750  B57 B59 B63 B66   C    4
# 325  female  36.0  PC 17760  135.6333              C32   C    0
# 332    male  38.0  PC 17582  153.4625              C91   S    1
# 334  female   NaN  PC 17611  133.6500              NaN   S    1
# 369  female  24.0  PC 17477   69.3000              B35   C    0
# 373    male  22.0  PC 17760  135.6333              NaN   C    0
# 375  female   NaN  PC 17604   82.1708              NaN   C    1
# 380  female  42.0  PC 17757  227.5250              NaN   C    0
# 493    male  71.0  PC 17609   49.5042              NaN   C    0
# 505    male  18.0  PC 17758  108.9000              C65   C    1
# 512    male  36.0  PC 17473   26.2875              E25   S    0
# 513  female  54.0  PC 17603   59.4000              NaN   C    1
# 527    male   NaN  PC 17483  221.7792              C95   S    0
# 537  female  30.0  PC 17761  106.4250              NaN   C    0
# 544    male  50.0  PC 17761  106.4250              C86   C    1
# 557    male   NaN  PC 17757  227.5250              NaN   C    0
# 572    male  36.0  PC 17474   26.3875              E25   S    0
# 599    male  49.0  PC 17485   56.9292              A20   C    1
# 609  female  40.0  PC 17582  153.4625             C125   S    0
# 641  female  24.0  PC 17477   69.3000              B35   C    0
# 645    male  48.0  PC 17572   76.7292              D33   C    1
# 660    male  50.0  PC 17611  133.6500              NaN   S    2
# 679    male  36.0  PC 17755  512.3292      B51 B53 B55   C    1
# 681    male  27.0  PC 17572   76.7292              D49   C    0
# 700  female  18.0  PC 17757  227.5250          C62 C64   C    1
# 701    male  35.0  PC 17475   26.2875              E24   S    0
# 707    male  42.0  PC 17476   26.2875              E24   S    0
# 710  female  24.0  PC 17482   49.5042              C90   C    0
# 716  female  38.0  PC 17757  227.5250              C45   C    0
# 737    male  35.0  PC 17755  512.3292             B101   C    0
# 742  female  21.0  PC 17608  262.3750  B57 B59 B63 B66   C    4
# 789    male  46.0  PC 17593   79.2000          B82 B84   C    0
# 793    male   NaN  PC 17600   30.6958              NaN   C    0
# 835  female  39.0  PC 17756   83.1583              E49   C    2
# 853  female  16.0  PC 17592   39.4000              D28   S    1
# 867    male  31.0  PC 17590   50.4958              A24   S    0

# %%
df[df['티켓번호'].str.contains("C.A")]
# Out:
#     승객번호                                                 이름  생존여부  선실등급  \
# 33    짝수                              Wheadon, Mr. Edward H     0     2
# 56    홀수                                  Rugg, Miss. Emily     1     2
# 58    홀수                       West, Miss. Constance Mirium     1     2
# 66    홀수                       Nye, Mrs. (Elizabeth Ramell)     1     2
# 70    홀수                         Jenkin, Mr. Stephen Curnow     0     2
# 93    짝수                            Dean, Mr. Bertram Frank     0     3
# 134   홀수                     Sobey, Mr. Samuel James Hayden     0     2
# 145   짝수                       Nicholls, Mr. Joseph Charles     0     2
# 161   짝수  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...     1     2
# 234   홀수                  Leyson, Mr. Robert William Norman     0     2
# 237   짝수                   Collyer, Miss. Marjorie "Lottie"     1     2
# 265   짝수                                  Reeves, Mr. David     0     2
# 279   짝수                   Abbott, Mrs. Stanton (Rosa Hunt)     1     3
# 348   홀수             Coutts, Master. William Loch "William"     1     3
# 432   홀수  Louch, Mrs. Charles Alexander (Alice Adelaide ...     1     2
# 439   짝수             Kvillner, Mr. Johan Henrik Johannesson     0     2
# 450   홀수                              West, Mr. Edwy Arthur     0     2
# 472   홀수            West, Mrs. Edwy Arthur (Ada Mary Worth)     1     2
# 473   짝수       Jerwan, Mrs. Amin S (Marie Marthe Thuillard)     1     2
# 489   짝수              Coutts, Master. Eden Leslie "Neville"     1     3
# 497   짝수                    Shellard, Mr. Frederick William     0     3
# 516   홀수                       Lemore, Mrs. (Amelia Milley)     1     2
# 549   짝수                     Davies, Master. John Morgan Jr     1     2
# 594   홀수                            Chapman, Mr. John Henry     0     2
# 637   짝수                                Collyer, Mr. Harvey     0     2
# 672   홀수                        Mitchell, Mr. Henry Michael     0     2
# 746   홀수                        Abbott, Mr. Rossmore Edward     0     3
# 788   홀수                         Dean, Master. Bertram Vere     1     3
# 801   짝수        Collyer, Mrs. Harvey (Charlotte Annie Tate)     1     2
# 845   짝수                                Abbing, Mr. Anthony     0     3
# 883   짝수                      Banfield, Mr. Frederick James     0     2
#
#          성별    나이              티켓번호     티켓가격 선실번호 목적지  가족수
# 33     male  66.0        C.A. 24579  10.5000  NaN   S    0
# 56   female  21.0        C.A. 31026  10.5000  NaN   S    0
# 58   female   5.0        C.A. 34651  27.7500  NaN   S    3
# 66   female  29.0        C.A. 29395  10.5000  F33   S    0
# 70     male  32.0        C.A. 33111  10.5000  NaN   S    0
# 93     male  26.0         C.A. 2315  20.5750  NaN   S    3
# 134    male  25.0        C.A. 29178  13.0000  NaN   S    0
# 145    male  19.0        C.A. 33112  36.7500  NaN   S    2
# 161  female  40.0        C.A. 33595  15.7500  NaN   S    0
# 234    male  24.0        C.A. 29566  10.5000  NaN   S    0
# 237  female   8.0        C.A. 31921  26.2500  NaN   S    2
# 265    male  36.0        C.A. 17248  10.5000  NaN   S    0
# 279  female  35.0         C.A. 2673  20.2500  NaN   S    2
# 348    male   3.0        C.A. 37671  15.9000  NaN   S    2
# 432  female  42.0        SC/AH 3085  26.0000  NaN   S    1
# 439    male  31.0        C.A. 18723  10.5000  NaN   S    0
# 450    male  36.0        C.A. 34651  27.7500  NaN   S    3
# 472  female  33.0        C.A. 34651  27.7500  NaN   S    3
# 473  female  23.0   SC/AH Basle 541  13.7917    D   C    0
# 489    male   9.0        C.A. 37671  15.9000  NaN   S    2
# 497    male   NaN         C.A. 6212  15.1000  NaN   S    0
# 516  female  34.0        C.A. 34260  10.5000  F33   S    0
# 549    male   8.0        C.A. 33112  36.7500  NaN   S    2
# 594    male  37.0       SC/AH 29037  26.0000  NaN   S    1
# 637    male  31.0        C.A. 31921  26.2500  NaN   S    2
# 672    male  70.0        C.A. 24580  10.5000  NaN   S    0
# 746    male  16.0         C.A. 2673  20.2500  NaN   S    2
# 788    male   1.0         C.A. 2315  20.5750  NaN   S    3
# 801  female  31.0        C.A. 31921  26.2500  NaN   S    2
# 845    male  42.0         C.A. 5547   7.5500  NaN   S    0
# 883    male  28.0  C.A./SOTON 34068  10.5000  NaN   S    0

# %% [markdown]
# * 승객이름에서 () 없애기
# * 반복문/리스표현식을 이용해 없애기
# * apply+ lambda 함수를 이용해 없애기
# * .str 메서드를 이용해서 없애기

# %% [markdown]
# * 반복문 이용하기

# %%
result = []
for name in df['이름']:
#     print(name, type(name))
    result.append(name.replace("(", "").replace(")", ""))
result
df['이름'] = result

# %%
# df

# %% [markdown]
# apply와 lambda 함수를 이용해 작업하기

# %%
df2 = df.copy()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# %%time
df['이름'].apply(lambda name: name.replace("(", "").replace(")", ""))
# Out:
# CPU times: total: 0 ns
# Wall time: 1 ms
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley Florence Briggs Thayer
# 2                                 Heikkinen, Miss. Laina
# 3             Futrelle, Mrs. Jacques Heath Lily May Peel
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: 이름, Length: 891, dtype: object

# %% [markdown]
# .str.replace를 활용해서 처리하기

# %%
# %%time
df['이름'].str.replace("(", "").str.replace(")", "")
# Out:
# CPU times: total: 0 ns
# Wall time: 1 ms
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley Florence Briggs Thayer
# 2                                 Heikkinen, Miss. Laina
# 3             Futrelle, Mrs. Jacques Heath Lily May Peel
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: 이름, Length: 891, dtype: object

# %% [markdown]
# .str.문자열함수 (upper, lower, split, join, strip)

# %%
print(type(df['Name']))
print(type(df['Name'][0]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'str'>

# %%
df['이름'] = df['이름'].str.split(", ")
df
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#      승객번호  생존여부  선실등급                                                 이름  \
# 0       1     0     3                          [Braund, Mr. Owen Harris]
# 1       2     1     1  [Cumings, Mrs. John Bradley (Florence Briggs T...
# 2       3     1     3                           [Heikkinen, Miss. Laina]
# 3       4     1     1     [Futrelle, Mrs. Jacques Heath (Lily May Peel)]
# 4       5     0     3                         [Allen, Mr. William Henry]
# ..    ...   ...   ...                                                ...
# 886   119     0     2                            [Montvila, Rev. Juozas]
# 887   120     1     1                     [Graham, Miss. Margaret Edith]
# 888   121     0     3         [Johnston, Miss. Catherine Helen "Carrie"]
# 889   122     1     1                            [Behr, Mr. Karl Howell]
# 890   123     0     3                              [Dooley, Mr. Patrick]
#
#          성별    나이  형제자매수  부모자식수              티켓번호       티켓가격  선실번호 승선지
# 0      male  22.0      1      0         A/5 21171   7.250000   NaN   S
# 1    female  38.0      1      0          PC 17599  71.312500   C85   C
# 2    female  26.0      0      0  STON/O2. 3101282   7.925781   NaN   S
# 3    female  35.0      1      0            113803  53.093750  C123   S
# 4      male  35.0      0      0            373450   8.046875   NaN   S
# ..      ...   ...    ...    ...               ...        ...   ...  ..
# 886    male  27.0      0      0            211536  13.000000   NaN   S
# 887  female  19.0      0      0            112053  30.000000   B42   S
# 888  female   NaN      1      2        W./C. 6607  23.453125   NaN   S
# 889    male  26.0      0      0            111369  30.000000  C148   C
# 890    male  32.0      0      0            370376   7.750000   NaN   Q
#
# [891 rows x 12 columns]

# %%
# " ".join(list)  // .str.join(" ") 
df['이름'] = df['이름'].str.join(", ")

# %%
df['이름']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: 이름, Length: 891, dtype: object

# %%
df['이름'] = df['이름'].str.split(", ")

# %%
df['first_name'] = df['이름'].apply(lambda x: x[0])
df['second_name'] = df['이름'].apply(lambda x: x[1])

# %%
df
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#      승객번호  생존여부  선실등급                                                 이름  \
# 0       1     0     3                          [Braund, Mr. Owen Harris]
# 1       2     1     1  [Cumings, Mrs. John Bradley (Florence Briggs T...
# 2       3     1     3                           [Heikkinen, Miss. Laina]
# 3       4     1     1     [Futrelle, Mrs. Jacques Heath (Lily May Peel)]
# 4       5     0     3                         [Allen, Mr. William Henry]
# ..    ...   ...   ...                                                ...
# 886   119     0     2                            [Montvila, Rev. Juozas]
# 887   120     1     1                     [Graham, Miss. Margaret Edith]
# 888   121     0     3         [Johnston, Miss. Catherine Helen "Carrie"]
# 889   122     1     1                            [Behr, Mr. Karl Howell]
# 890   123     0     3                              [Dooley, Mr. Patrick]
#
#          성별    나이  형제자매수  부모자식수              티켓번호       티켓가격  선실번호 승선지  \
# 0      male  22.0      1      0         A/5 21171   7.250000   NaN   S
# 1    female  38.0      1      0          PC 17599  71.312500   C85   C
# 2    female  26.0      0      0  STON/O2. 3101282   7.925781   NaN   S
# 3    female  35.0      1      0            113803  53.093750  C123   S
# 4      male  35.0      0      0            373450   8.046875   NaN   S
# ..      ...   ...    ...    ...               ...        ...   ...  ..
# 886    male  27.0      0      0            211536  13.000000   NaN   S
# 887  female  19.0      0      0            112053  30.000000   B42   S
# 888  female   NaN      1      2        W./C. 6607  23.453125   NaN   S
# 889    male  26.0      0      0            111369  30.000000  C148   C
# 890    male  32.0      0      0            370376   7.750000   NaN   Q
#
#     first_name                                 second_name
# 0       Braund                             Mr. Owen Harris
# 1      Cumings  Mrs. John Bradley (Florence Briggs Thayer)
# 2    Heikkinen                                 Miss. Laina
# 3     Futrelle          Mrs. Jacques Heath (Lily May Peel)
# 4        Allen                           Mr. William Henry
# ..         ...                                         ...
# 886   Montvila                                 Rev. Juozas
# 887     Graham                        Miss. Margaret Edith
# 888   Johnston              Miss. Catherine Helen "Carrie"
# 889       Behr                             Mr. Karl Howell
# 890     Dooley                                 Mr. Patrick
#
# [891 rows x 14 columns]

# %% [markdown]
# # groupby
# * 특정 기준 컬럼 지정해서 다른 컬럼의 통계량 (평균, 최소, 최대)
# * df[['보고싶은 컬럼1','보고싶은컬럼2']].groupby('기준컬럼').집합함수(mean, max, min, median, count, value_counts(sort=False))

# %%
df.columns
# Out:
# Index(['승객번호', '생존여부', '선실등급', '이름', '성별', '나이', '형제자매수', '부모자식수', '티켓번호',
#        '티켓가격', '선실번호', '승선지', 'first_name', 'second_name'],
#       dtype='object')

# %% [markdown]
# * 성별별 생존자 수

# %%
survbysex = df[['성별', '생존여부']].groupby(['성별']).value_counts(sort=False)
survbysex
# Out:
# 성별      생존여부
# female  0        81
#         1       233
# male    0       468
#         1       109
# Name: count, dtype: int64

# %%
print(type(survbysex))
# Out:
# <class 'pandas.core.series.Series'>

# %%
survbysex.index
# Out:
# MultiIndex([('female', 0),
#             ('female', 1),
#             (  'male', 0),
#             (  'male', 1)],
#            names=['Sex', 'Survived'])

# %%
df3 = pd.DataFrame(survbysex)
df3
# Out:
#              count
# 성별     생존여부
# female 0        81
#        1       233
# male   0       468
#        1       109

# %%
df3.index
# Out:
# MultiIndex([('female', 0),
#             ('female', 1),
#             (  'male', 0),
#             (  'male', 1)],
#            names=['성별', '생존여부'])

# %%
df3.loc[[('female', 0),(  'male', 0)] , 'count']
df3.loc[[('female', 1),(  'male', 1)] , 'count']
# Out:
# 성별      생존여부
# female  1       233
# male    1       109
# Name: count, dtype: int64

# %%
233 / (81+233) * 100
# Out:
# 74.20382165605095

# %%
109 / (109+468) * 100
# Out:
# 18.890814558058924

# %%
df[['성별', '생존여부']].groupby(['성별']).mean()
# Out:
#             생존여부
# 성별
# female  0.742038
# male    0.188908

# %% [markdown]
# 선실등급별 생존자 수

# %%
df[['Pclass', 'Survived']].groupby('Pclass').value_counts(sort=False)
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['승객번호', '생존여부', '선실등급', '이름', '성별', '나이', '형제자매수', '부모자식수', '티켓번호',
#        '티켓가격', '선실번호', '승선지', 'first_name', 'second_name'],
#       dtype='object')

# %%
df[['선실등급', '생존여부']].groupby('선실등급').mean()
# Out:
#           생존여부
# 선실등급
# 1     0.629630
# 2     0.472826
# 3     0.242363

# %% [markdown]
# 성별별, 선실등급 별 생존자수

# %%
df[['Sex', 'Pclass', 'Survived']].groupby(['Sex', 'Pclass']).value_counts(sort=False)
# Out:
# Sex     Pclass  Survived
# female  1       0             3
#                 1            91
#         2       0             6
#                 1            70
#         3       0            72
#                 1            72
# male    1       0            77
#                 1            45
#         2       0            91
#                 1            17
#         3       0           300
#                 1            47
# Name: count, dtype: int64

# %%
df[['성별', '선실등급', '생존여부']].groupby(['성별', '선실등급']).mean()
# Out:
#                  생존여부
# 성별     선실등급
# female 1     0.968085
#        2     0.921053
#        3     0.500000
# male   1     0.368852
#        2     0.157407
#        3     0.135447

# %% [markdown]
# 은행 고객 등급
# - 급여 통장 입금여부, 액수
# - 적금, 예금

# %% [markdown]
# * 성별에 따른 나이의 평균, 최소, 최대값

# %%
df[['성별', '나이']].groupby('성별').mean()
# Out:
#                나이
# 성별
# female  27.915709
# male    30.726645

# %%
df[['성별', '나이']].groupby('성별').min()
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#               나이
# 성별
# female  0.750000
# male    0.419922

# %%
df[['성별', '나이']].groupby('성별').max()
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#           나이
# 성별
# female  63.0
# male    80.0

# %%
df[['성별', '나이']].groupby('성별').describe()
# Out:
#            나이
#         count       mean        std       min   25%   50%   75%   max
# 성별
# female  261.0  27.921875  14.109375  0.750000  18.0  27.0  37.0  63.0
# male    453.0  30.734375  14.679688  0.419922  21.0  29.0  39.0  80.0

# %%
df[['성별', '나이']].groupby('성별').agg(['min', 'max', 'mean'])
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#               나이
#              min   max       mean
# 성별
# female  0.750000  63.0  27.915709
# male    0.419922  80.0  30.726645

# %% [markdown]
# * 피벗테이블 pivot

# %%
df.pivot_table(values="Survived", index='Sex', columns="Pclass")
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# # 결측값 찾기( 값이 없는 것)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  first_name   891 non-null    object
#  13  second_name  891 non-null    object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 97.6+ KB

# %%
len(df)
# Out:
# 891

# %% [markdown]
# isna() 결측값인지 아닌지 확인 -> True(1), Flase(0) -> sum(결측값의 개수)

# %%
df.isna().sum() / len(df) * 100
# Out:
# 승객번호            0.000000
# 생존여부            0.000000
# 선실등급            0.000000
# 이름              0.000000
# 성별              0.000000
# 나이             19.865320
# 형제자매수           0.000000
# 부모자식수           0.000000
# 티켓번호            0.000000
# 티켓가격            0.000000
# 선실번호           77.104377
# 승선지             0.224467
# first_name      0.000000
# second_name     0.000000
# dtype: float64

# %% [markdown]
# dropna() 결측값이 있는 행을 삭제

# %%
df.dropna()
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#      승객번호  생존여부  선실등급                                                 이름  \
# 1       2     1     1  [Cumings, Mrs. John Bradley (Florence Briggs T...
# 3       4     1     1     [Futrelle, Mrs. Jacques Heath (Lily May Peel)]
# 6       7     0     1                          [McCarthy, Mr. Timothy J]
# 10     11     1     3                  [Sandstrom, Miss. Marguerite Rut]
# 11     12     1     1                         [Bonnell, Miss. Elizabeth]
# ..    ...   ...   ...                                                ...
# 871   104     1     1  [Beckwith, Mrs. Richard Leonard (Sallie Monype...
# 872   105     0     1                         [Carlsson, Mr. Frans Olof]
# 879   112     1     1    [Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)]
# 887   120     1     1                     [Graham, Miss. Margaret Edith]
# 889   122     1     1                            [Behr, Mr. Karl Howell]
#
#          성별    나이  형제자매수  부모자식수      티켓번호       티켓가격         선실번호 승선지  \
# 1    female  38.0      1      0  PC 17599  71.312500          C85   C
# 3    female  35.0      1      0    113803  53.093750         C123   S
# 6      male  54.0      0      0     17463  51.875000          E46   S
# 10   female   4.0      1      1   PP 9549  16.703125           G6   S
# 11   female  58.0      0      0    113783  26.546875         C103   S
# ..      ...   ...    ...    ...       ...        ...          ...  ..
# 871  female  47.0      1      1     11751  52.562500          D35   S
# 872    male  33.0      0      0       695   5.000000  B51 B53 B55   S
# 879  female  56.0      0      1     11767  83.187500          C50   C
# 887  female  19.0      0      0    112053  30.000000          B42   S
# 889    male  26.0      0      0    111369  30.000000         C148   C
#
#     first_name                                 second_name
# 1      Cumings  Mrs. John Bradley (Florence Briggs Thayer)
# 3     Futrelle          Mrs. Jacques Heath (Lily May Peel)
# 6     McCarthy                               Mr. Timothy J
# 10   Sandstrom                        Miss. Marguerite Rut
# 11     Bonnell                             Miss. Elizabeth
# ..         ...                                         ...
# 871   Beckwith      Mrs. Richard Leonard (Sallie Monypeny)
# 872   Carlsson                              Mr. Frans Olof
# 879     Potter       Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887     Graham                        Miss. Margaret Edith
# 889       Behr                             Mr. Karl Howell
#
# [183 rows x 14 columns]

# %% [markdown]
# fillna() 결측값을 다른 값으로 채워주는 함수

# %%
round(df['나이'].mean())
# Out:
# 30

# %%
import numpy as np

# %%
df[df['나이'].isna() == True].index
# Out:
# Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#        ...
#        832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#       dtype='int64', length=177)

# %%
# NaN : Not a Number, NaN 의 데이터타입 = float
nan_index = df[df['나이'].isna() == True].index

# %%
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#      승객번호  생존여부  선실등급                                          이름      성별  나이  \
# 5       6     0     3                          [Moran, Mr. James]    male NaN
# 17     18     1     2              [Williams, Mr. Charles Eugene]    male NaN
# 19     20     1     3                   [Masselmani, Mrs. Fatima]  female NaN
# 26     27     0     3                   [Emir, Mr. Farred Chehab]    male NaN
# 28     29     1     3             [O'Dwyer, Miss. Ellen "Nellie"]  female NaN
# ..    ...   ...   ...                                         ...     ...  ..
# 859    92     0     3                          [Razi, Mr. Raihed]    male NaN
# 863    96     0     3         [Sage, Miss. Dorothy Edith "Dolly"]  female NaN
# 868   101     0     3               [van Melkebeke, Mr. Philemon]    male NaN
# 878   111     0     3                        [Laleff, Mr. Kristo]    male NaN
# 888   121     0     3  [Johnston, Miss. Catherine Helen "Carrie"]  female NaN
#
#      형제자매수  부모자식수        티켓번호       티켓가격 선실번호 승선지     first_name  \
# 5        0      0      330877   8.460938  NaN   Q          Moran
# 17       0      0      244373  13.000000  NaN   S       Williams
# 19       0      0        2649   7.226562  NaN   C     Masselmani
# 26       0      0        2631   7.226562  NaN   C           Emir
# 28       0      0      330959   7.878906  NaN   Q        O'Dwyer
# ..     ...    ...         ...        ...  ...  ..            ...
# 859      0      0        2629   7.230469  NaN   C           Razi
# 863      8      2    CA. 2343  69.562500  NaN   S           Sage
# 868      0      0      345777   9.500000  NaN   S  van Melkebeke
# 878      0      0      349217   7.894531  NaN   S         Laleff
# 888      1      2  W./C. 6607  23.453125  NaN   S       Johnston
#
#                         second_name
# 5                         Mr. James
# 17               Mr. Charles Eugene
# 19                      Mrs. Fatima
# 26                Mr. Farred Chehab
# 28             Miss. Ellen "Nellie"
# ..                              ...
# 859                      Mr. Raihed
# 863     Miss. Dorothy Edith "Dolly"
# 868                    Mr. Philemon
# 878                      Mr. Kristo
# 888  Miss. Catherine Helen "Carrie"
#
# [177 rows x 14 columns]

# %%
df['나이'] = df['나이'].fillna(round(df['나이'].mean()))

# %%
df.loc[nan_index]
# Out:
# C:\Users\haram\miniforge3\envs\fintech\lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#      승객번호  생존여부  선실등급                                          이름      성별  \
# 5       6     0     3                          [Moran, Mr. James]    male
# 17     18     1     2              [Williams, Mr. Charles Eugene]    male
# 19     20     1     3                   [Masselmani, Mrs. Fatima]  female
# 26     27     0     3                   [Emir, Mr. Farred Chehab]    male
# 28     29     1     3             [O'Dwyer, Miss. Ellen "Nellie"]  female
# ..    ...   ...   ...                                         ...     ...
# 859    92     0     3                          [Razi, Mr. Raihed]    male
# 863    96     0     3         [Sage, Miss. Dorothy Edith "Dolly"]  female
# 868   101     0     3               [van Melkebeke, Mr. Philemon]    male
# 878   111     0     3                        [Laleff, Mr. Kristo]    male
# 888   121     0     3  [Johnston, Miss. Catherine Helen "Carrie"]  female
#
#        나이  형제자매수  부모자식수        티켓번호       티켓가격 선실번호 승선지     first_name  \
# 5    30.0      0      0      330877   8.460938  NaN   Q          Moran
# 17   30.0      0      0      244373  13.000000  NaN   S       Williams
# 19   30.0      0      0        2649   7.226562  NaN   C     Masselmani
# 26   30.0      0      0        2631   7.226562  NaN   C           Emir
# 28   30.0      0      0      330959   7.878906  NaN   Q        O'Dwyer
# ..    ...    ...    ...         ...        ...  ...  ..            ...
# 859  30.0      0      0        2629   7.230469  NaN   C           Razi
# 863  30.0      8      2    CA. 2343  69.562500  NaN   S           Sage
# 868  30.0      0      0      345777   9.500000  NaN   S  van Melkebeke
# 878  30.0      0      0      349217   7.894531  NaN   S         Laleff
# 888  30.0      1      2  W./C. 6607  23.453125  NaN   S       Johnston
#
#                         second_name
# 5                         Mr. James
# 17               Mr. Charles Eugene
# 19                      Mrs. Fatima
# 26                Mr. Farred Chehab
# 28             Miss. Ellen "Nellie"
# ..                              ...
# 859                      Mr. Raihed
# 863     Miss. Dorothy Edith "Dolly"
# 868                    Mr. Philemon
# 878                      Mr. Kristo
# 888  Miss. Catherine Helen "Carrie"
#
# [177 rows x 14 columns]

# %%
df['나이'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 여러개의 데이터프레임 합치기
# * concat: 두 개의 데이터 프레임을 1개로 합침
# * merge: sql join과 같은 역할 공통된 기준 컬럼 매칭해서 합침
# * join: sql join과 같은 역할 index가 같은 것 끼리 합침

# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb
# Out:
# <function pymysql.install_as_MySQLdb()>

# %%
engine = create_engine("mysql+pymysql://kict20:kict20@221.155.18.165:3306/titanic")
conn = engine.connect()

# %%
passenger = pd.read_sql("p_info", con=conn)
ticket = pd.read_sql("t_info", con=conn)
survived = pd.read_sql("survived", con=conn)
conn.close()

# %%
passenger.head(1)
# Out:
#    PassengerId                     Name   Sex   Age  SibSp  Parch
# 0            1  Braund, Mr. Owen Harris  male  22.0      1      0

# %%
ticket.head(1)
# Out:
#    PassengerId     Ticket  Pclass  Fare Cabin Embarked
# 0            1  A/5 21171       3  7.25  None        S

# %%
survived.head(1)
# Out:
#    PassengerId  Survived
# 0            1         0

# %% [markdown]
# ## concat  axis=0 행 추가, axis=1 열 추가
# * 기준 컬럼 없이 무조건 합침
# * 기본값은 행방향으로 합쳐줌
# * 옆으로 붙이고 싶으면 axis=1

# %%
print("passenger", passenger.shape)
print("ticket", ticket.shape)
print("survived", survived.shape)
# Out:
# passenger (891, 6)
# ticket (891, 6)
# survived (891, 2)

# %%
df_0 = pd.concat([passenger, ticket, survived], axis=0)
df_0.iloc[890:893, :]
df_0
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                                                NaN     NaN
# 887          888                                                NaN     NaN
# 888          889                                                NaN     NaN
# 889          890                                                NaN     NaN
# 890          891                                                NaN     NaN
#
#       Age  SibSp  Parch Ticket  Pclass  Fare Cabin Embarked  Survived
# 0    22.0    1.0    0.0    NaN     NaN   NaN   NaN      NaN       NaN
# 1    38.0    1.0    0.0    NaN     NaN   NaN   NaN      NaN       NaN
# 2    26.0    0.0    0.0    NaN     NaN   NaN   NaN      NaN       NaN
# 3    35.0    1.0    0.0    NaN     NaN   NaN   NaN      NaN       NaN
# 4    35.0    0.0    0.0    NaN     NaN   NaN   NaN      NaN       NaN
# ..    ...    ...    ...    ...     ...   ...   ...      ...       ...
# 886   NaN    NaN    NaN    NaN     NaN   NaN   NaN      NaN       0.0
# 887   NaN    NaN    NaN    NaN     NaN   NaN   NaN      NaN       1.0
# 888   NaN    NaN    NaN    NaN     NaN   NaN   NaN      NaN       0.0
# 889   NaN    NaN    NaN    NaN     NaN   NaN   NaN      NaN       1.0
# 890   NaN    NaN    NaN    NaN     NaN   NaN   NaN      NaN       0.0
#
# [2673 rows x 12 columns]

# %%
df1 = pd.concat([passenger, ticket, survived], axis=1)
df1
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch  PassengerId            Ticket  Pclass     Fare Cabin  \
# 0    22.0      1      0            1         A/5 21171       3   7.2500  None
# 1    38.0      1      0            2          PC 17599       1  71.2833   C85
# 2    26.0      0      0            3  STON/O2. 3101282       3   7.9250  None
# 3    35.0      1      0            4            113803       1  53.1000  C123
# 4    35.0      0      0            5            373450       3   8.0500  None
# ..    ...    ...    ...          ...               ...     ...      ...   ...
# 886  27.0      0      0          887            211536       2  13.0000  None
# 887  19.0      0      0          888            112053       1  30.0000   B42
# 888   NaN      1      2          889        W./C. 6607       3  23.4500  None
# 889  26.0      0      0          890            111369       1  30.0000  C148
# 890  32.0      0      0          891            370376       3   7.7500  None
#
#     Embarked  PassengerId  Survived
# 0          S            1         0
# 1          C            2         1
# 2          S            3         1
# 3          S            4         1
# 4          S            5         0
# ..       ...          ...       ...
# 886        S          887         0
# 887        S          888         1
# 888        S          889         0
# 889        C          890         1
# 890        Q          891         0
#
# [891 rows x 14 columns]

# %%
passenger.head(1)
# Out:
#    PassengerId                     Name   Sex   Age  SibSp  Parch
# 0            1  Braund, Mr. Owen Harris  male  22.0      1      0

# %%
ticket.head(1)
# Out:
#    PassengerId     Ticket  Pclass  Fare Cabin Embarked
# 0            1  A/5 21171       3  7.25  None        S

# %% [markdown]
# # merge: sql의 join문과 같음

# %%
# select * from passenger left join ticket on passenger.PassengerId = ticket.PassengerId
joined_df = pd.merge(passenger, ticket, how="inner", on="PassengerId")

# %%
joined_df = pd.merge(joined_df, survived, how='inner', on='PassengerId')
joined_df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket  Pclass     Fare Cabin Embarked  \
# 0    22.0      1      0         A/5 21171       3   7.2500  None        S
# 1    38.0      1      0          PC 17599       1  71.2833   C85        C
# 2    26.0      0      0  STON/O2. 3101282       3   7.9250  None        S
# 3    35.0      1      0            113803       1  53.1000  C123        S
# 4    35.0      0      0            373450       3   8.0500  None        S
# ..    ...    ...    ...               ...     ...      ...   ...      ...
# 886  27.0      0      0            211536       2  13.0000  None        S
# 887  19.0      0      0            112053       1  30.0000   B42        S
# 888   NaN      1      2        W./C. 6607       3  23.4500  None        S
# 889  26.0      0      0            111369       1  30.0000  C148        C
# 890  32.0      0      0            370376       3   7.7500  None        Q
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 12 columns]

# %%
passenger2 = passenger.copy()
passenger2
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch
# 0    22.0      1      0
# 1    38.0      1      0
# 2    26.0      0      0
# 3    35.0      1      0
# 4    35.0      0      0
# ..    ...    ...    ...
# 886  27.0      0      0
# 887  19.0      0      0
# 888   NaN      1      2
# 889  26.0      0      0
# 890  32.0      0      0
#
# [891 rows x 6 columns]

# %%
passenger2 = passenger2.rename(columns={"PassengerId" : "pid"})
passenger2
# Out:
#      pid                                               Name     Sex   Age  \
# 0      1                            Braund, Mr. Owen Harris    male  22.0
# 1      2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2      3                             Heikkinen, Miss. Laina  female  26.0
# 3      4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4      5                           Allen, Mr. William Henry    male  35.0
# ..   ...                                                ...     ...   ...
# 886  887                              Montvila, Rev. Juozas    male  27.0
# 887  888                       Graham, Miss. Margaret Edith  female  19.0
# 888  889           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889  890                              Behr, Mr. Karl Howell    male  26.0
# 890  891                                Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch
# 0        1      0
# 1        1      0
# 2        0      0
# 3        1      0
# 4        0      0
# ..     ...    ...
# 886      0      0
# 887      0      0
# 888      1      2
# 889      0      0
# 890      0      0
#
# [891 rows x 6 columns]

# %%
passenger2.columns
# Out:
# Index(['pid', 'Name', 'Sex', 'Age', 'SibSp', 'Parch'], dtype='object')

# %%
ticket.columns
# Out:
# Index(['PassengerId', 'Ticket', 'Pclass', 'Fare', 'Cabin', 'Embarked'], dtype='object')

# %%
pd.merge(passenger2, ticket, how='inner', left_on="pid", right_on="PassengerId")
# Out:
#      pid                                               Name     Sex   Age  \
# 0      1                            Braund, Mr. Owen Harris    male  22.0
# 1      2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2      3                             Heikkinen, Miss. Laina  female  26.0
# 3      4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4      5                           Allen, Mr. William Henry    male  35.0
# ..   ...                                                ...     ...   ...
# 886  887                              Montvila, Rev. Juozas    male  27.0
# 887  888                       Graham, Miss. Margaret Edith  female  19.0
# 888  889           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889  890                              Behr, Mr. Karl Howell    male  26.0
# 890  891                                Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch  PassengerId            Ticket  Pclass     Fare Cabin  \
# 0        1      0            1         A/5 21171       3   7.2500  None
# 1        1      0            2          PC 17599       1  71.2833   C85
# 2        0      0            3  STON/O2. 3101282       3   7.9250  None
# 3        1      0            4            113803       1  53.1000  C123
# 4        0      0            5            373450       3   8.0500  None
# ..     ...    ...          ...               ...     ...      ...   ...
# 886      0      0          887            211536       2  13.0000  None
# 887      0      0          888            112053       1  30.0000   B42
# 888      1      2          889        W./C. 6607       3  23.4500  None
# 889      0      0          890            111369       1  30.0000  C148
# 890      0      0          891            370376       3   7.7500  None
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # join: sql의 join과 같음, index명을 기준으로 합침

# %%
passenger = passenger.set_index("PassengerId")

# %%
passenger
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch
# PassengerId
# 1                1      0
# 2                1      0
# 3                0      0
# 4                1      0
# 5                0      0
# ...            ...    ...
# 887              0      0
# 888              0      0
# 889              1      2
# 890              0      0
# 891              0      0
#
# [891 rows x 5 columns]

# %%
ticket = ticket.set_index("PassengerId")
ticket
# Out:
#                        Ticket  Pclass     Fare Cabin Embarked
# PassengerId
# 1                   A/5 21171       3   7.2500  None        S
# 2                    PC 17599       1  71.2833   C85        C
# 3            STON/O2. 3101282       3   7.9250  None        S
# 4                      113803       1  53.1000  C123        S
# 5                      373450       3   8.0500  None        S
# ...                       ...     ...      ...   ...      ...
# 887                    211536       2  13.0000  None        S
# 888                    112053       1  30.0000   B42        S
# 889                W./C. 6607       3  23.4500  None        S
# 890                    111369       1  30.0000  C148        C
# 891                    370376       3   7.7500  None        Q
#
# [891 rows x 5 columns]

# %%
joined_df2 = passenger.join(ticket, how='inner')
joined_df2
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket  Pclass     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171       3   7.2500  None        S
# 2                1      0          PC 17599       1  71.2833   C85        C
# 3                0      0  STON/O2. 3101282       3   7.9250  None        S
# 4                1      0            113803       1  53.1000  C123        S
# 5                0      0            373450       3   8.0500  None        S
# ...            ...    ...               ...     ...      ...   ...      ...
# 887              0      0            211536       2  13.0000  None        S
# 888              0      0            112053       1  30.0000   B42        S
# 889              1      2        W./C. 6607       3  23.4500  None        S
# 890              0      0            111369       1  30.0000  C148        C
# 891              0      0            370376       3   7.7500  None        Q
#
# [891 rows x 10 columns]

# %%
survived = survived.set_index("PassengerId")
survived
# Out:
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0
# ...               ...
# 887                 0
# 888                 1
# 889                 0
# 890                 1
# 891                 0
#
# [891 rows x 1 columns]

# %%
joined_df2 = joined_df2.join(survived)
joined_df2
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket  Pclass     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171       3   7.2500  None        S
# 2                1      0          PC 17599       1  71.2833   C85        C
# 3                0      0  STON/O2. 3101282       3   7.9250  None        S
# 4                1      0            113803       1  53.1000  C123        S
# 5                0      0            373450       3   8.0500  None        S
# ...            ...    ...               ...     ...      ...   ...      ...
# 887              0      0            211536       2  13.0000  None        S
# 888              0      0            112053       1  30.0000   B42        S
# 889              1      2        W./C. 6607       3  23.4500  None        S
# 890              0      0            111369       1  30.0000  C148        C
# 891              0      0            370376       3   7.7500  None        Q
#
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0
# ...               ...
# 887                 0
# 888                 1
# 889                 0
# 890                 1
# 891                 0
#
# [891 rows x 11 columns]

# %%
joined_df2 = joined_df2.reset_index()
joined_df2
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket  Pclass     Fare Cabin Embarked  \
# 0    22.0      1      0         A/5 21171       3   7.2500  None        S
# 1    38.0      1      0          PC 17599       1  71.2833   C85        C
# 2    26.0      0      0  STON/O2. 3101282       3   7.9250  None        S
# 3    35.0      1      0            113803       1  53.1000  C123        S
# 4    35.0      0      0            373450       3   8.0500  None        S
# ..    ...    ...    ...               ...     ...      ...   ...      ...
# 886  27.0      0      0            211536       2  13.0000  None        S
# 887  19.0      0      0            112053       1  30.0000   B42        S
# 888   NaN      1      2        W./C. 6607       3  23.4500  None        S
# 889  26.0      0      0            111369       1  30.0000  C148        C
# 890  32.0      0      0            370376       3   7.7500  None        Q
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 12 columns]

# %% [markdown]
# # 인덱스가 섞여 있는 데이터를 불러와서 join 하기

# %%
engine = create_engine("mysql+pymysql://kict20:kict20@221.155.18.165:3306/titanic")
conn = engine.connect()
passenger3 = pd.read_sql("passenger", con=conn)
ticket3 = pd.read_sql("ticket", con=conn)
surv3 = pd.read_sql("surv", con=conn)

# %%
print(len(passenger3))
print(len(ticket3))
# Out:
# 623
# 445

# %%
# merge의 기본 조인법: inner
pd.merge(pd.merge(passenger3, ticket3, on="PassengerId"), ticket3, on="PassengerId")
# Out:
#      PassengerId                                            Name     Sex  \
# 0            192                           Carbines, Mr. William    male
# 1            715                           Greenberg, Mr. Samuel    male
# 2            533                            Elias, Mr. Joseph Jr    male
# 3            133  Robins, Mrs. Alexander A (Grace Charity Laury)  female
# 4            597                      Leitch, Miss. Jessie Wills  female
# ..           ...                                             ...     ...
# 312          349          Coutts, Master. William Loch "William"    male
# 313          616                             Herman, Miss. Alice  female
# 314          580                             Jussila, Mr. Eiriik    male
# 315          503                  O'Sullivan, Miss. Bridget Mary  female
# 316          176                          Klasen, Mr. Klas Albin    male
#
#       Age  SibSp  Parch           Ticket_x  Pclass_x   Fare_x Cabin_x  \
# 0    19.0      0      0              28424         2  13.0000    None
# 1    52.0      0      0             250647         2  13.0000    None
# 2    17.0      1      1               2690         3   7.2292    None
# 3    47.0      1      0          A/5. 3337         3  14.5000    None
# 4     NaN      0      0             248727         2  33.0000    None
# ..    ...    ...    ...                ...       ...      ...     ...
# 312   3.0      1      1         C.A. 37671         3  15.9000    None
# 313  24.0      1      2             220845         2  65.0000    None
# 314  32.0      0      0  STON/O 2. 3101286         3   7.9250    None
# 315   NaN      0      0             330909         3   7.6292    None
# 316  18.0      1      1             350404         3   7.8542    None
#
#     Embarked_x           Ticket_y  Pclass_y   Fare_y Cabin_y Embarked_y
# 0            S              28424         2  13.0000    None          S
# 1            S             250647         2  13.0000    None          S
# 2            C               2690         3   7.2292    None          C
# 3            S          A/5. 3337         3  14.5000    None          S
# 4            S             248727         2  33.0000    None          S
# ..         ...                ...       ...      ...     ...        ...
# 312          S         C.A. 37671         3  15.9000    None          S
# 313          S             220845         2  65.0000    None          S
# 314          S  STON/O 2. 3101286         3   7.9250    None          S
# 315          Q             330909         3   7.6292    None          Q
# 316          S             350404         3   7.8542    None          S
#
# [317 rows x 16 columns]

# %%
passenger4 = passenger3.set_index("PassengerId")
ticket4 = ticket3.set_index("PassengerId")

# %%
# join은 기본값이 left join
passenger4.join(ticket4, how='inner')
# Out:
#                                                        Name     Sex   Age  \
# PassengerId
# 192                                   Carbines, Mr. William    male  19.0
# 715                                   Greenberg, Mr. Samuel    male  52.0
# 533                                    Elias, Mr. Joseph Jr    male  17.0
# 133          Robins, Mrs. Alexander A (Grace Charity Laury)  female  47.0
# 597                              Leitch, Miss. Jessie Wills  female   NaN
# ...                                                     ...     ...   ...
# 349                  Coutts, Master. William Loch "William"    male   3.0
# 616                                     Herman, Miss. Alice  female  24.0
# 580                                     Jussila, Mr. Eiriik    male  32.0
# 503                          O'Sullivan, Miss. Bridget Mary  female   NaN
# 176                                  Klasen, Mr. Klas Albin    male  18.0
#
#              SibSp  Parch             Ticket  Pclass     Fare Cabin Embarked
# PassengerId
# 192              0      0              28424       2  13.0000  None        S
# 715              0      0             250647       2  13.0000  None        S
# 533              1      1               2690       3   7.2292  None        C
# 133              1      0          A/5. 3337       3  14.5000  None        S
# 597              0      0             248727       2  33.0000  None        S
# ...            ...    ...                ...     ...      ...   ...      ...
# 349              1      1         C.A. 37671       3  15.9000  None        S
# 616              1      2             220845       2  65.0000  None        S
# 580              0      0  STON/O 2. 3101286       3   7.9250  None        S
# 503              0      0             330909       3   7.6292  None        Q
# 176              1      1             350404       3   7.8542  None        S
#
# [317 rows x 10 columns]

# %% [markdown]
# # 중복여부 확인 및 제거하기

# %%
toss = pd.read_csv("./data/toss_reviews.csv", index_col=0)
toss
# Out:
#             사용자  별점                                                 리뷰  \
# 0      Won Choi   5  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 1           최유연   5  증권부분이 너무 빈약해요. 이평선, 분봉, 틱봉 자유롭게 수치를 설정할 수 있었음 ...
# 2       EXPRESS   5  주식 UI에서 홈과 관심 종목을 나눈 것도 불편한데 이번 자주 사용하는 계좌 업데이...
# 3          JS P   5  언제 한 번 대대적으로 앱 퍼포먼스 최적화를 했으면 좋겠습니다. 예전엔 이러지 않았...
# 4      AndPeter   5  앱 최적화 좀 해주세요! 무슨 메모리를 1GB나 잡아먹고 패킷전송이 하루에 80만건...
# ...         ...  ..                                                ...
# 57223        김민   5  아니 업데이트 방금하니까, 주문수정하는게 가격 바꾸는게 안되네요? 무조건 취소하고 ...
# 57224       최고운   5  업데이트 후 동영상 재생광고를 선택권없이 무조건 시청해야 하군요. wi-fi 환경이...
# 57225        블리   5  라이브쇼핑보고,포인트받기 시스템 변경후,어찌 주구장창 1포인트만 나오는지.........
# 57226       조명현   5       구석구석 숨어있던 버그를 잡다가 업데이트 설치가 안 되는 버그가 생긴 듯 합니다
# 57227       이예진   5         홈화면에 계좌 순서 설정한게 반영 안되게 바뀌었는지 이해가 안감 너무 불편함
#
#                   날짜                                             개발자 응답
# 0      2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 1       2025년 1월 18일  안녕하세요. 최유연 님, 토스팀입니다. 토스증권 사용하시면서 주신 소중한 의견 너무...
# 2       2025년 2월 25일  안녕하세요. EXPRESS 님, 토스팀입니다. 우선 토스증권 이용에 불편을 드려 죄...
# 3       2025년 2월 28일  안녕하세요. JS P 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였...
# 4        2025년 3월 1일  안녕하세요. AndPeter 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# ...              ...                                                ...
# 57223  2024년 11월 11일  안녕하세요 김민님, 토스팀입니다. 우선 토스증권 서비스 이용에 불편을 드려 정말 죄...
# 57224    2023년 6월 3일  안녕하세요. 최고운님. 토스 고객센터입니다. 먼저, 이용에 불편을 드려 죄송합니다....
# 57225   2024년 4월 11일  안녕하세요. 블리님, 토스 고객센터입니다. 먼저 서비스 이용에 불편을 드렸다면 대단...
# 57226   2025년 2월 25일  안녕하세요. 조명현 님, 토스팀입니다. 사용에 불편을 드린것 같아 마음이 무겁습니다...
# 57227   2025년 2월 27일  안녕하세요. 이예진 님, 토스팀입니다. 토스를 이용하시면서 느끼신 소중한 의견을 주...
#
# [57228 rows x 5 columns]

# %%
toss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57228 entries, 0 to 57227
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용자     57185 non-null  object
#  1   별점      57228 non-null  int64
#  2   리뷰      57228 non-null  object
#  3   날짜      57228 non-null  object
#  4   개발자 응답  54031 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 2.6+ MB

# %%
toss[toss["사용자"] == "Won Choi"]
# Out:
#             사용자  별점                                                 리뷰  \
# 0      Won Choi   5  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 20     Won Choi   5  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 40     Won Choi   5  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 60     Won Choi   5  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 80     Won Choi   5  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# ...         ...  ..                                                ...
# 54642  Won Choi   5  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 55156  Won Choi   5  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 55670  Won Choi   5  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 56184  Won Choi   5  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 56698  Won Choi   5  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
#
#                   날짜                                             개발자 응답
# 0      2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 20     2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 40     2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 60     2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 80     2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# ...              ...                                                ...
# 54642  2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 55156  2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 55670  2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 56184  2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 56698  2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
#
# [212 rows x 5 columns]

# %%
toss.duplicated().sum()
# Out:
# np.int64(56698)

# %% [markdown]
# 중복 컬럼 삭제하기 drop_duplicates()

# %%
toss = toss.drop_duplicates()
toss
# Out:
#             사용자  별점                                                 리뷰  \
# 0      Won Choi   5  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 1           최유연   5  증권부분이 너무 빈약해요. 이평선, 분봉, 틱봉 자유롭게 수치를 설정할 수 있었음 ...
# 2       EXPRESS   5  주식 UI에서 홈과 관심 종목을 나눈 것도 불편한데 이번 자주 사용하는 계좌 업데이...
# 3          JS P   5  언제 한 번 대대적으로 앱 퍼포먼스 최적화를 했으면 좋겠습니다. 예전엔 이러지 않았...
# 4      AndPeter   5  앱 최적화 좀 해주세요! 무슨 메모리를 1GB나 잡아먹고 패킷전송이 하루에 80만건...
# ...         ...  ..                                                ...
# 57223        김민   5  아니 업데이트 방금하니까, 주문수정하는게 가격 바꾸는게 안되네요? 무조건 취소하고 ...
# 57224       최고운   5  업데이트 후 동영상 재생광고를 선택권없이 무조건 시청해야 하군요. wi-fi 환경이...
# 57225        블리   5  라이브쇼핑보고,포인트받기 시스템 변경후,어찌 주구장창 1포인트만 나오는지.........
# 57226       조명현   5       구석구석 숨어있던 버그를 잡다가 업데이트 설치가 안 되는 버그가 생긴 듯 합니다
# 57227       이예진   5         홈화면에 계좌 순서 설정한게 반영 안되게 바뀌었는지 이해가 안감 너무 불편함
#
#                   날짜                                             개발자 응답
# 0      2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 1       2025년 1월 18일  안녕하세요. 최유연 님, 토스팀입니다. 토스증권 사용하시면서 주신 소중한 의견 너무...
# 2       2025년 2월 25일  안녕하세요. EXPRESS 님, 토스팀입니다. 우선 토스증권 이용에 불편을 드려 죄...
# 3       2025년 2월 28일  안녕하세요. JS P 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였...
# 4        2025년 3월 1일  안녕하세요. AndPeter 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# ...              ...                                                ...
# 57223  2024년 11월 11일  안녕하세요 김민님, 토스팀입니다. 우선 토스증권 서비스 이용에 불편을 드려 정말 죄...
# 57224    2023년 6월 3일  안녕하세요. 최고운님. 토스 고객센터입니다. 먼저, 이용에 불편을 드려 죄송합니다....
# 57225   2024년 4월 11일  안녕하세요. 블리님, 토스 고객센터입니다. 먼저 서비스 이용에 불편을 드렸다면 대단...
# 57226   2025년 2월 25일  안녕하세요. 조명현 님, 토스팀입니다. 사용에 불편을 드린것 같아 마음이 무겁습니다...
# 57227   2025년 2월 27일  안녕하세요. 이예진 님, 토스팀입니다. 토스를 이용하시면서 느끼신 소중한 의견을 주...
#
# [530 rows x 5 columns]

# %%
toss.iloc[400:500]
# Out:
#                    사용자  별점                                                 리뷰  \
# 34040              김효영   5     좋긴한데 뭐 안되는 게 생각보다 많음. 지원 안되는 곳도 있고 뭣보다 유스 개불편함
# 34041              루이드   5  요즘 따라 토스 앱 렉 엄청납니다 먹통될때도 있고 휴대폰은 s24라서 제 폰이 문제...
# 34042              윤소정   5              토스가 갑자기 접속이 안되요ㅠ 와이파이 연결도 잘되어있는데도 그래요
# 34043              이채현   5  [월 내역보기] 가 예전보다 보기 안좋게 나오는데요. 업데이트도 안했었는데 왜 바뀐...
# 34044              이상기   5  극찬받아도 과하지 않은 앱이네요 더 좋은 프로그램을 접속해서 많은 이들을 이롭게 하...
# ...                ...  ..                                                ...
# 48575        Asqu Ptus   5  토스뱅크 체크카드의 후불교통카드 이용내역을 보기위해 해탕탭을 누르면 검정배경을 제외...
# 48576              권영국   5  다른 앱에 비해 업데이트를 자주 하는 편인데ㅡ 지난번에 업뎃할때 비밀의 샘물 없어진...
# 48577              메아리   5  개같은 고양이 알림좀 지워주세요. 고양이 카테고리 선택하고 상단 설정에 조치할 수있...
# 48578              김혜원   5  포인트 덜 주려는 건 괜찮은데 수수료를 왜 이렇게 많이 떼가나요ㅠㅠ 예전에는 200...
# 52571  jung hyun hwang   5  몇일전부터 업데이트 안되서 삭제후 재설치시 설치 안됨. 고객센터 문의 했는데 구글스...
#
#                   날짜                                             개발자 응답
# 34040   2025년 1월 14일  안녕하세요. 김효영 님, 토스팀입니다. 남겨주신 내용만으로는 정확한 확인이 어려운 ...
# 34041   2025년 1월 21일                                                NaN
# 34042   2025년 1월 19일  안녕하세요. 윤소정님, 토스팀입니다. 서비스 이용에 불편을 드려 죄송합니다. 다음 ...
# 34043    2025년 2월 5일  안녕하세요. 이채현 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였으...
# 34044   2025년 1월 13일                                                NaN
# ...              ...                                                ...
# 48575  2024년 10월 13일  안녕하세요, 고객님. 토스뱅크 고객센터입니다. 고객님 토스뱅크를 이용해주셔서 감사합...
# 48576  2024년 10월 25일  안녕하세요. 권영국님, 토스팀입니다. 우선, 토스 이용에 불편함이 있으셨던 것 같아...
# 48577  2024년 11월 21일  안녕하세요. 메아리님, 토스팀입니다.이용에 불편드려 정말 죄송하며 알림의 경우 아래...
# 48578   2025년 2월 14일  안녕하세요.김혜원 님, 토스팀입니다. 토스 앱에서 보다 다양한 혜택과 서비스를 제공...
# 52571  2024년 10월 15일  안녕하세요. jung hyun hwang님, 토스팀입니다. 우선, 토스 이용에 불편...
#
# [100 rows x 5 columns]

# %%
toss = toss.reset_index(drop=True)
toss
# Out:
#           사용자  별점                                                 리뷰  \
# 0    Won Choi   5  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 1         최유연   5  증권부분이 너무 빈약해요. 이평선, 분봉, 틱봉 자유롭게 수치를 설정할 수 있었음 ...
# 2     EXPRESS   5  주식 UI에서 홈과 관심 종목을 나눈 것도 불편한데 이번 자주 사용하는 계좌 업데이...
# 3        JS P   5  언제 한 번 대대적으로 앱 퍼포먼스 최적화를 했으면 좋겠습니다. 예전엔 이러지 않았...
# 4    AndPeter   5  앱 최적화 좀 해주세요! 무슨 메모리를 1GB나 잡아먹고 패킷전송이 하루에 80만건...
# ..        ...  ..                                                ...
# 525        김민   5  아니 업데이트 방금하니까, 주문수정하는게 가격 바꾸는게 안되네요? 무조건 취소하고 ...
# 526       최고운   5  업데이트 후 동영상 재생광고를 선택권없이 무조건 시청해야 하군요. wi-fi 환경이...
# 527        블리   5  라이브쇼핑보고,포인트받기 시스템 변경후,어찌 주구장창 1포인트만 나오는지.........
# 528       조명현   5       구석구석 숨어있던 버그를 잡다가 업데이트 설치가 안 되는 버그가 생긴 듯 합니다
# 529       이예진   5         홈화면에 계좌 순서 설정한게 반영 안되게 바뀌었는지 이해가 안감 너무 불편함
#
#                 날짜                                             개발자 응답
# 0    2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# 1     2025년 1월 18일  안녕하세요. 최유연 님, 토스팀입니다. 토스증권 사용하시면서 주신 소중한 의견 너무...
# 2     2025년 2월 25일  안녕하세요. EXPRESS 님, 토스팀입니다. 우선 토스증권 이용에 불편을 드려 죄...
# 3     2025년 2월 28일  안녕하세요. JS P 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였...
# 4      2025년 3월 1일  안녕하세요. AndPeter 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...
# ..             ...                                                ...
# 525  2024년 11월 11일  안녕하세요 김민님, 토스팀입니다. 우선 토스증권 서비스 이용에 불편을 드려 정말 죄...
# 526    2023년 6월 3일  안녕하세요. 최고운님. 토스 고객센터입니다. 먼저, 이용에 불편을 드려 죄송합니다....
# 527   2024년 4월 11일  안녕하세요. 블리님, 토스 고객센터입니다. 먼저 서비스 이용에 불편을 드렸다면 대단...
# 528   2025년 2월 25일  안녕하세요. 조명현 님, 토스팀입니다. 사용에 불편을 드린것 같아 마음이 무겁습니다...
# 529   2025년 2월 27일  안녕하세요. 이예진 님, 토스팀입니다. 토스를 이용하시면서 느끼신 소중한 의견을 주...
#
# [530 rows x 5 columns]
