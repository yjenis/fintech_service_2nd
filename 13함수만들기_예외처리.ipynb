# %% [markdown]
# - 자주 사용하는 기능을 미리 만들어 **반복 재사용** 할 수 있게 하기

# %% [markdown]
# # 함수 만드는 법
# def 함수이름(변수명)

# %% [markdown]
# * 간단한 함수를 작성하거나 다르 함수의 인수로 함수를 넣을 때 사용
# * 사용 후 메모리에서 삭제
# * lambda 매개변수: return할 값, 계산
# * (lambda x: x+10)(5)
# * plus_five=lambda:x+10
# * plus_five(5)

# %%
(lambda x: "짝수" if x%2==0 else "홀수")(6)
# Out:
# '짝수'

# %%
# 숫자를 넣어서 홀수 짝수 구분하는 람다함수
(lambda x:"짝수" if x%2==0 else "홀수")(4)
# Out:
# '짝수'
