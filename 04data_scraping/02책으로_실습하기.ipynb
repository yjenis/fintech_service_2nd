# %%
print('a')
# Out:
# a

# %%
import json
import pandas as pd
import requests

# %%
def json_unpack(data):
    result={}
    for item in data['items']:
        for key,value in item.items():
            result.setdefault(key,[]).append(value)
    return result

# %%
url='https://openapi.naver.com/v1/search/book.json'
word=input()
payload={'query':word, 'distplay':20, 'start':11, 'sort':'date'}
headers={'X-Naver-Client-Id': 'YhDZdPHyjsCZJxZAEDAt','X-Naver-Client-Secret':'4qRCp_G_Eq'}
# Out:
# 자바

# %%
r=requests.get(url, params=payload, headers=headers)
# print(r.url)
# print(r.status_code)
data=r.json()
result_df=json_unpack(data)
# Out:
# 200

# %%
data
# Out:
# {'lastBuildDate': 'Mon, 31 Mar 2025 16:20:31 +0900',
#  'total': 587,
#  'start': 11,
#  'display': 10,
#  'items': [{'title': '헬로 Bun (차세대 자바스크립트 런타임+올인원 개발 키트를 만나다)',
#    'link': 'https://search.shopping.naver.com/book/catalog/50639934625',
#    'image': 'https://shopping-phinf.pstatic.net/main_5063993/50639934625.20241003091154.jpg',
#    'author': '서대영',
#    'discount': '19800',
#    'publisher': '제이펍',
#    'pubdate': '20241022',
#    'isbn': '9791193926710',
#    'description': '타입스크립트와 JSX를 아우르는 런타임 Bun으로 만나는 차세대 웹 개발\n\n느리고 복잡한 노드 생태계의 판도를 바꾸기 위해, 차세대 자바스크립트 런타임이자 올인원 개발 키트인 Bun이 탄생했다. 자바스크립트/타입스크립트/JSX 코드를 바로 실행할 수 있고, 패키지 매니저, 모듈 시스템, 테스트 러너, 번들러, DB 등 다양한 기능을 내장했는데도 성능은 노드나 디노를 압도한다. 이 책은 Bun을 본격적으로 살펴보는 최초의 책으로서 Bun 기초부터 시나리오별 활용법과 예제 프로젝트까지, 웹 개발이 얼마나 우아할 수 있는지 보여준다.'},
#   {'title': '방구석 부트캠프 자바 (기본으로 돌아가 체계적으로 시작하는 견고한 개발자 되기)',
#    'link': 'https://search.shopping.naver.com/book/catalog/50737873628',
#    'image': 'https://shopping-phinf.pstatic.net/main_5073787/50737873628.20241010071030.jpg',
#    'author': '김경록',
#    'discount': '28800',
#    'publisher': '리코멘드',
#    'pubdate': '20241021',
#    'isbn': '9791194084051',
#    'description': '여러분의 방구석을 실리콘밸리로 만들어 줄 58일간의 자바 부트캠프\n\n『방구석 부트캠프 자바』는 자바를 실용적이고 체계적으로 학습하기 위한 입문서다. 코딩은 AI가 더 잘하는 시대가 맞지만, AI 시대에 필요한 종합적인 개발자 역량은 단순한 코딩 기술을 넘어, 복잡한 문제를 창의적으로 해결하는 능력, 프로젝트 전체를 조망하고 효과적으로 협업할 수 있는 의사소통 능력, 그리고 빠르게 변화하는 기술 환경에 적응하며 지속적으로 학습할 수 있는 자기 주도적 학습 능력이 요구된다. 무엇보다 AI 도구를 효과적으로 활용하여 업무 효율성을 높이는 것은 AI 시대를 살아가는 개발자의 필수 역량이다. 이 책은 그러한 흐름에 발맞춰 단순히 자바 언어의 문법, 명령어 등과 같은 기술 습득에 그치지 않고 만들고자 하는 것을 논리적 사고 단계에 따라 하나씩 업그레이드하면서 상황에 맞게, 예측할 수 있게, 읽기 편하게 코딩하는 방법을 알려주는 것에 초점을 맞추고 있다.\n자바의 모든 것을 알려주고 있다고 할 순 없지만 적어도 이 책으로 자바를 시작한 독자가 포기하지 않고 끝까지 학습한 후, 이 책에서 이해한 것을 바탕으로 프로그래밍에 흥미를 느끼고 더 공부해 보고 싶다고 느끼도록 하는 것을 목표로 한다. 프로그래밍을 처음 시작한다면, 자바를 처음 시작한다면 더도 덜도 말고 딱 58일 과정으로 구성된 체계적인 학습 구조를 통해 프로그래밍에 입문할 수 있기를 바란다.'},
#   {'title': '도망가자, 바다면 더 좋고 (이도훈 에세이)',
#    'link': 'https://search.shopping.naver.com/book/catalog/50488152618',
#    'image': 'https://shopping-phinf.pstatic.net/main_5048815/50488152618.20240927070943.jpg',
#    'author': '맺음',
#    'discount': '15300',
#    'publisher': '일단',
#    'pubdate': '20241009',
#    'isbn': '9791198869609',
#    'description': '"답답하고 들끓는 마음이 더울지는 몰라도\n우리, 더 울지는 말기로 해요."\n\n5년이란 오랜 시간 동안 위로를 건네준\n‘이도훈 (맺음)’ 작가의 신작이 2년 만에 출간되었다.\n\n그간 농축된 감성이 그대의 메마른 감정에\n긍정적인 영향을 가져다줄 것이다.\n\n총 4장으로 이뤄진 이번 책에서는\n사계절에 어우러지는 이야기가 가득 담겨 있으며,\n이도훈 작가만의 독보적인 문체의 다정함을\n힘껏 끌어안을 수 있을 것이다.\n\n평소 ‘가독성이 좋은 글’로 \n수만 독자에게 사랑받은 청년 작가의 진심.\n\n이번 『도망가자, 바다면 더 좋고』를 통해\n우리에게 어떤 길을 안내할지 \n함께 문장을 누비길 바란다.'},
#   {'title': '코믹 실격문장의 최강 현자 13 (세계 최강의 현자가 더욱 강해지기 위해 환생했습니다, 노엔 코믹스)',
#    'link': 'https://search.shopping.naver.com/book/catalog/50259598621',
#    'image': 'https://shopping-phinf.pstatic.net/main_5025959/50259598621.20240910175427.jpg',
#    'author': '칸쇼&효코(Friendly Land) 지음, 카자바나 후우카 그림, 박소현 옮김, 신코 쇼',
#    'discount': '4950',
#    'publisher': '데이즈엔터',
#    'pubdate': '20240926',
#    'isbn': '9791138051415',
#    'description': '일찍이 [현자]라 불렸던 마법사가 마법 전투에 최적화된 문장을 얻기 위해 미래로 환생한다. 그러나 마법 이론이 퇴화한 미래에선 그 문장은 「실격문장」이라 불리며 멸시당하고 있었다.\n문장의 정보를 뒤틀어 마법 이론을 퇴화시킨 건 마족이었다.\n마티아스는 인간을 멸망시키려는 마족과의 싸움을 펼쳐 나간다!\n마족들을 이용해 다양한 음모를 전개하던 강대한 적.\n그 마족의 이름은 자리디아스. 전에 없던 강대한 마력과 전투력을 가진 마족으로, 마티아스는 “지금의 우리들은 당해낼 수 없다.”고 단언하는데….\n\n대인기 이세계 「문장」 판타지 제13탄!\n원작자의 번외편도 수록!'},
#   {'title': '파이썬과 자바스크립트로 배우는 OpenAI 프로그래밍 (OpenAI API 기본 개념부터 프롬프트 작성, 이미지 생성, 노코드 툴 사용, 나만의 AI 모델 제작까지)',
#    'link': 'https://search.shopping.naver.com/book/catalog/49255961633',
#    'image': 'https://shopping-phinf.pstatic.net/main_4925596/49255961633.20240720092118.jpg',
#    'author': '쇼다 쓰야노',
#    'discount': '28800',
#    'publisher': '제이펍',
#    'pubdate': '20240816',
#    'isbn': '9791193926284',
#    'description': '실용적이고 효율적인 OpenAI API 활용법\n\nOpenAI API를 활용하면 AI와 상호작용을 하면서 원하는 용도에 특화된 AI 봇을 만들 수 있으며 이미지 생성과 제품 정보를 학습시킨 AI 모델을 제작할 수도 있다. 이 책에서는 OpenAI API 개념을 알아본 후 원하는 결과를 도출하는 프롬프트 작성법, DALL-E를 통한 이미지 생성법, 제품 데이터를 활용한 AI 모델 제작 방법 등을 파이썬과 자바스크립트로 나누어 살펴본다. 파워 플랫폼 및 노코드 툴 사용법은 물론 다양한 개발 환경에서 API를 사용하는 방법도 알려준다. AI가 필수인 시대에서 최강의 무기인 OpenAI API를 제대로 활용해보자.'},
#   {'title': '기본기가 탄탄한 자바 개발자 (모던 자바의 새로운 기능을 배우고 자바 전문가가 되는 법)',
#    'link': 'https://search.shopping.naver.com/book/catalog/49379976618',
#    'image': 'https://shopping-phinf.pstatic.net/main_4937997/49379976618.20240727071259.jpg',
#    'author': '벤저민 J. 에번스^Clark, Jason^마르테인 페르뷔르흐',
#    'discount': '40500',
#    'publisher': '제이펍',
#    'pubdate': '20240814',
#    'isbn': '9791193926277',
#    'description': 'JVM부터 성능, 동시성, 컨테이너화 등 고급 기술까지\n\n자바는 엔터프라이즈 소프트웨어 엔지니어링의 핵심이다. 훌륭한 자바 개발자가 되기 위해선 기본기를 갖춰야 한다. 이 책은 자바 8 이후 자바 생태계와 릴리스 주기가 어떻게 변화했는지 살펴보며, 특히 자바 11 및 17에 추가된 새로운 기능을 설명한다. 자바 모듈 및 동시성 모델, 클래스 로딩과 같은 강력한 기능부터 성능 최적화와 바이트코드를 위한 고급 기술 그리고 테스트 중심 개발과 컨테이너 기반 배포와 같은 필수 최신 기술까지 알아본다. 코틀린 및 클로저 등 다른 JVM 언어까지 다뤄 자바 기술을 한층 더 업그레이드하고 탄탄한 기반을 다질 수 있도록 도와준다.'},
#   {'title': '자바를 이용한 영상처리 프로그래밍',
#    'link': 'https://search.shopping.naver.com/book/catalog/49815969652',
#    'image': 'https://shopping-phinf.pstatic.net/main_4981596/49815969652.20240816201524.jpg',
#    'author': '류석원',
#    'discount': '21800',
#    'publisher': '부크크(bookk)',
#    'pubdate': '20240812',
#    'isbn': '9791141099473',
#    'description': '4차 산업시대에 각광을 받고 있는 인공지능은 오늘날 인간의 능력과 비슷하게 발전하고 있으며, 그 한계를 넘기 위해 인간은 인공지능 분야에 무한한 투자를 하고 있습니다.  이러한 인공지능 개발에 있어서 영상처리는 입력장치 개발에 중요한 부분을 담당합니다. 이 책은 현재 많은 개발자들이 사용하는 자바 프로그래밍 언어를 사용하여 디지털 형태의 이미지 효과를 구현하는 영상처리 프로그래밍 기법에 대해 설명합니다.'},
#   {'title': '쉽게 설명한 자바스크립트 알고리즘 (쉬운 설명과 실용적 예제로 배우는 알고리즘)',
#    'link': 'https://search.shopping.naver.com/book/catalog/49800298622',
#    'image': 'https://shopping-phinf.pstatic.net/main_4980029/49800298622.20240816071140.jpg',
#    'author': '한상훈',
#    'discount': '15300',
#    'publisher': '영진닷컴',
#    'pubdate': '20240809',
#    'isbn': '9788931477252',
#    'description': "초급 웹 개발자를 위한 가장 쉬운 알고리즘 교재\n\n자바스크립트는 이제 웹 개발의 중심에 서 있는 필수 언어입니다. 하지만 많은 개발자들이 '알고리즘'이라는 단어만 들어도 두려움을 느끼곤 합니다. 이 책은 초보 개발자들이 쉽게 이해할 수 있도록 알고리즘의 기초부터 실용적인 예제까지 다룹니다. 특정 코드가 최고의 성능을 내지 않더라도 다양한 해결책을 통해 더 나은 코드를 작성하는 방법을 안내합니다. 학문적인 내용은 최소화하고, 실무에서 유용한 알고리즘을 재미있게 배울 수 있도록 구성되었습니다.\n\n【 대상 독자층 】\n- 알고리즘 공부가 필요한 자바스크립트 개발자\n- 자바스크립트 개발자 취업 준비생"},
#   {'title': '자바스크립트 + 리액트 디자인 패턴 (자바스크립트와 리액트의 최신 패턴과 렌더링, 성능 패턴까지)',
#    'link': 'https://search.shopping.naver.com/book/catalog/49335174628',
#    'image': 'https://shopping-phinf.pstatic.net/main_4933517/49335174628.20240725071120.jpg',
#    'author': '애디 오스마니',
#    'discount': '25200',
#    'publisher': '한빛미디어',
#    'pubdate': '20240801',
#    'isbn': '9791169212571',
#    'description': '20가지 이상의 디자인 패턴으로 배우는 최신 웹 개발\n\n유지보수가 쉬운 구조적인 코드를 만들고 싶은가요? 최신 웹 개발 모범 사례를 참고하고 싶은가요? 그렇다면 『자바스크립트 + 리액트 디자인 패턴』이 해답입니다. 이 책은 모듈, 믹스인, 관찰자, 중재자 패턴을 포함한 최신 디자인 패턴을 자바스크립트와 리액트에 적용하는 방법을 소개합니다. 그리고 코드 스플리팅, 서버 사이드 렌더링 등 실무에 필요한 성능과 렌더링 관련 내용을 실용적인 예제와 함께 설명합니다. 또한, 여러 안티 패턴도 함께 다루고 있어 웹 개발을 할 때 흔하게 발생하는 실수를 줄이는 노하우까지 배울 수 있습니다. 이 책에 담긴 20가지 이상의 디자인 패턴을 익혀 더 나은 웹 개발자에 한 걸음 더 다가가세요.'},
#   {'title': 'Do it! HTML+CSS+자바스크립트 웹 표준의 정석 (한 권으로 끝내는 웹 기본 교과서)',
#    'link': 'https://search.shopping.naver.com/book/catalog/49248761620',
#    'image': 'https://shopping-phinf.pstatic.net/main_4924876/49248761620.20240720092111.jpg',
#    'author': '고경희',
#    'discount': '28800',
#    'publisher': '이지스퍼블리싱',
#    'pubdate': '20240730',
#    'isbn': '9791163036227',
#    'description': '‘웹 표준의 정석’ 시리즈의 최신 개정판과 함께\n웹 개발의 3대 기술을 끝낸다!\n\n웹 분야 도서 《Do it! HTML+CSS+자바스크립트 웹 표준의 정석》이 전면 개정판으로 돌아왔다. 이번 개정판에서는 최신 웹 표준부터 반응형 웹, ES6+까지 초판 출간 후 3년이 넘는 시간 동안 변해 온 웹 개발의 기술과 트렌드를 적극 반영했다. 절반이 넘게 고치고 다시 쓰면서 지금 실무에 가장 가까운 기본서로 새롭게 태어났다.\n친절한 설명은 기본! 실습할 때 사용하는 예제 소스 파일을 모두 제공한다. 독자는 실습에서 요구하는 부분만 코딩하면 되므로 학습할 때 막힘이 없다. 또한 1번 읽더라도 마치 3번 읽은 것과 같은 효과를 볼 수 있도록 다양한 학습 장치를 배치했다. 마지막으로 PDF 책 〈넷플릭스 사이트 따라 만들기〉를 무료로 제공해 책에서 배운 내용으로 실제 서비스와 비슷한 웹 사이트를 만들어 본다. 태그와 속성, 문법을 한눈에 볼 수 있는 ‘웹 치트 시트’도 부록으로 제공한다.'}]}

# %%
data['items']
# Out:
# [{'title': '자바 스크립트 웹 프로그래밍 (다양한 예제로 설명하는)',
#   'link': 'https://search.shopping.naver.com/book/catalog/51259188635',
#   'image': 'https://shopping-phinf.pstatic.net/main_5125918/51259188635.20250225071032.jpg',
#   'author': '조동영^이완권',
#   'discount': '25000',
#   'publisher': '북스홀릭퍼블리싱',
#   'pubdate': '20241031',
#   'isbn': '9791162891247',
#   'description': '이 책은 자바스크립트 웹 프로그래밍을 다룬다. 이 책의 구성은 크게 자바스크립트 기본 문법을 다루는 부분(1장~5장)과 자바스크립트를 이용하는 웹 클라이언트 프로그래밍을 다루는 부분(6장~11장)으로 구성된다. 1장은 웹에서 자바스크립트의 역할을, 2장부터 5장까지는 자바스크립트의 기본 문법을 설명하고, Node.js 실행환경에서 자바스크립트를 실행한다. 그리고 6장부터 11장은 웹 클라이언트 프로그래밍으로 자바스크립트를 이용한 HTML DOM 프로그래밍 방법으로 설명하고, 웹브라우저 환경에서 자바스크립트를 실행한다. 자바스크립트 웹 프로그래밍을 위해서는 각 장의 모든 내용들을 이해해야 하지만 특히 7장의 HTML DOM 프로그래밍이 중요하며, 9장은 jQuery 라이브러리를 이용해서 좀더 간결하게 프로그래밍하는 방법을 다룬다.'},
#  {'title': '헬로 Bun (차세대 자바스크립트 런타임+올인원 개발 키트를 만나다)',
#   'link': 'https://search.shopping.naver.com/book/catalog/50639934625',
#   'image': 'https://shopping-phinf.pstatic.net/main_5063993/50639934625.20241003091154.jpg',
#   'author': '서대영',
#   'discount': '19800',
#   'publisher': '제이펍',
#   'pubdate': '20241022',
#   'isbn': '9791193926710',
#   'description': '타입스크립트와 JSX를 아우르는 런타임 Bun으로 만나는 차세대 웹 개발\n\n느리고 복잡한 노드 생태계의 판도를 바꾸기 위해, 차세대 자바스크립트 런타임이자 올인원 개발 키트인 Bun이 탄생했다. 자바스크립트/타입스크립트/JSX 코드를 바로 실행할 수 있고, 패키지 매니저, 모듈 시스템, 테스트 러너, 번들러, DB 등 다양한 기능을 내장했는데도 성능은 노드나 디노를 압도한다. 이 책은 Bun을 본격적으로 살펴보는 최초의 책으로서 Bun 기초부터 시나리오별 활용법과 예제 프로젝트까지, 웹 개발이 얼마나 우아할 수 있는지 보여준다.'},
#  {'title': '방구석 부트캠프 자바 (기본으로 돌아가 체계적으로 시작하는 견고한 개발자 되기)',
#   'link': 'https://search.shopping.naver.com/book/catalog/50737873628',
#   'image': 'https://shopping-phinf.pstatic.net/main_5073787/50737873628.20241010071030.jpg',
#   'author': '김경록',
#   'discount': '28800',
#   'publisher': '리코멘드',
#   'pubdate': '20241021',
#   'isbn': '9791194084051',
#   'description': '여러분의 방구석을 실리콘밸리로 만들어 줄 58일간의 자바 부트캠프\n\n『방구석 부트캠프 자바』는 자바를 실용적이고 체계적으로 학습하기 위한 입문서다. 코딩은 AI가 더 잘하는 시대가 맞지만, AI 시대에 필요한 종합적인 개발자 역량은 단순한 코딩 기술을 넘어, 복잡한 문제를 창의적으로 해결하는 능력, 프로젝트 전체를 조망하고 효과적으로 협업할 수 있는 의사소통 능력, 그리고 빠르게 변화하는 기술 환경에 적응하며 지속적으로 학습할 수 있는 자기 주도적 학습 능력이 요구된다. 무엇보다 AI 도구를 효과적으로 활용하여 업무 효율성을 높이는 것은 AI 시대를 살아가는 개발자의 필수 역량이다. 이 책은 그러한 흐름에 발맞춰 단순히 자바 언어의 문법, 명령어 등과 같은 기술 습득에 그치지 않고 만들고자 하는 것을 논리적 사고 단계에 따라 하나씩 업그레이드하면서 상황에 맞게, 예측할 수 있게, 읽기 편하게 코딩하는 방법을 알려주는 것에 초점을 맞추고 있다.\n자바의 모든 것을 알려주고 있다고 할 순 없지만 적어도 이 책으로 자바를 시작한 독자가 포기하지 않고 끝까지 학습한 후, 이 책에서 이해한 것을 바탕으로 프로그래밍에 흥미를 느끼고 더 공부해 보고 싶다고 느끼도록 하는 것을 목표로 한다. 프로그래밍을 처음 시작한다면, 자바를 처음 시작한다면 더도 덜도 말고 딱 58일 과정으로 구성된 체계적인 학습 구조를 통해 프로그래밍에 입문할 수 있기를 바란다.'},
#  {'title': '도망가자, 바다면 더 좋고 (이도훈 에세이)',
#   'link': 'https://search.shopping.naver.com/book/catalog/50488152618',
#   'image': 'https://shopping-phinf.pstatic.net/main_5048815/50488152618.20240927070943.jpg',
#   'author': '맺음',
#   'discount': '15300',
#   'publisher': '일단',
#   'pubdate': '20241009',
#   'isbn': '9791198869609',
#   'description': '"답답하고 들끓는 마음이 더울지는 몰라도\n우리, 더 울지는 말기로 해요."\n\n5년이란 오랜 시간 동안 위로를 건네준\n‘이도훈 (맺음)’ 작가의 신작이 2년 만에 출간되었다.\n\n그간 농축된 감성이 그대의 메마른 감정에\n긍정적인 영향을 가져다줄 것이다.\n\n총 4장으로 이뤄진 이번 책에서는\n사계절에 어우러지는 이야기가 가득 담겨 있으며,\n이도훈 작가만의 독보적인 문체의 다정함을\n힘껏 끌어안을 수 있을 것이다.\n\n평소 ‘가독성이 좋은 글’로 \n수만 독자에게 사랑받은 청년 작가의 진심.\n\n이번 『도망가자, 바다면 더 좋고』를 통해\n우리에게 어떤 길을 안내할지 \n함께 문장을 누비길 바란다.'},
#  {'title': '코믹 실격문장의 최강 현자 13 (세계 최강의 현자가 더욱 강해지기 위해 환생했습니다, 노엔 코믹스)',
#   'link': 'https://search.shopping.naver.com/book/catalog/50259598621',
#   'image': 'https://shopping-phinf.pstatic.net/main_5025959/50259598621.20240910175427.jpg',
#   'author': '칸쇼&효코(Friendly Land) 지음, 카자바나 후우카 그림, 박소현 옮김, 신코 쇼',
#   'discount': '4950',
#   'publisher': '데이즈엔터',
#   'pubdate': '20240926',
#   'isbn': '9791138051415',
#   'description': '일찍이 [현자]라 불렸던 마법사가 마법 전투에 최적화된 문장을 얻기 위해 미래로 환생한다. 그러나 마법 이론이 퇴화한 미래에선 그 문장은 「실격문장」이라 불리며 멸시당하고 있었다.\n문장의 정보를 뒤틀어 마법 이론을 퇴화시킨 건 마족이었다.\n마티아스는 인간을 멸망시키려는 마족과의 싸움을 펼쳐 나간다!\n마족들을 이용해 다양한 음모를 전개하던 강대한 적.\n그 마족의 이름은 자리디아스. 전에 없던 강대한 마력과 전투력을 가진 마족으로, 마티아스는 “지금의 우리들은 당해낼 수 없다.”고 단언하는데….\n\n대인기 이세계 「문장」 판타지 제13탄!\n원작자의 번외편도 수록!'},
#  {'title': '파이썬과 자바스크립트로 배우는 OpenAI 프로그래밍 (OpenAI API 기본 개념부터 프롬프트 작성, 이미지 생성, 노코드 툴 사용, 나만의 AI 모델 제작까지)',
#   'link': 'https://search.shopping.naver.com/book/catalog/49255961633',
#   'image': 'https://shopping-phinf.pstatic.net/main_4925596/49255961633.20240720092118.jpg',
#   'author': '쇼다 쓰야노',
#   'discount': '28800',
#   'publisher': '제이펍',
#   'pubdate': '20240816',
#   'isbn': '9791193926284',
#   'description': '실용적이고 효율적인 OpenAI API 활용법\n\nOpenAI API를 활용하면 AI와 상호작용을 하면서 원하는 용도에 특화된 AI 봇을 만들 수 있으며 이미지 생성과 제품 정보를 학습시킨 AI 모델을 제작할 수도 있다. 이 책에서는 OpenAI API 개념을 알아본 후 원하는 결과를 도출하는 프롬프트 작성법, DALL-E를 통한 이미지 생성법, 제품 데이터를 활용한 AI 모델 제작 방법 등을 파이썬과 자바스크립트로 나누어 살펴본다. 파워 플랫폼 및 노코드 툴 사용법은 물론 다양한 개발 환경에서 API를 사용하는 방법도 알려준다. AI가 필수인 시대에서 최강의 무기인 OpenAI API를 제대로 활용해보자.'},
#  {'title': '기본기가 탄탄한 자바 개발자 (모던 자바의 새로운 기능을 배우고 자바 전문가가 되는 법)',
#   'link': 'https://search.shopping.naver.com/book/catalog/49379976618',
#   'image': 'https://shopping-phinf.pstatic.net/main_4937997/49379976618.20240727071259.jpg',
#   'author': '벤저민 J. 에번스^Clark, Jason^마르테인 페르뷔르흐',
#   'discount': '40500',
#   'publisher': '제이펍',
#   'pubdate': '20240814',
#   'isbn': '9791193926277',
#   'description': 'JVM부터 성능, 동시성, 컨테이너화 등 고급 기술까지\n\n자바는 엔터프라이즈 소프트웨어 엔지니어링의 핵심이다. 훌륭한 자바 개발자가 되기 위해선 기본기를 갖춰야 한다. 이 책은 자바 8 이후 자바 생태계와 릴리스 주기가 어떻게 변화했는지 살펴보며, 특히 자바 11 및 17에 추가된 새로운 기능을 설명한다. 자바 모듈 및 동시성 모델, 클래스 로딩과 같은 강력한 기능부터 성능 최적화와 바이트코드를 위한 고급 기술 그리고 테스트 중심 개발과 컨테이너 기반 배포와 같은 필수 최신 기술까지 알아본다. 코틀린 및 클로저 등 다른 JVM 언어까지 다뤄 자바 기술을 한층 더 업그레이드하고 탄탄한 기반을 다질 수 있도록 도와준다.'},
#  {'title': '자바를 이용한 영상처리 프로그래밍',
#   'link': 'https://search.shopping.naver.com/book/catalog/49815969652',
#   'image': 'https://shopping-phinf.pstatic.net/main_4981596/49815969652.20240816201524.jpg',
#   'author': '류석원',
#   'discount': '21800',
#   'publisher': '부크크(bookk)',
#   'pubdate': '20240812',
#   'isbn': '9791141099473',
#   'description': '4차 산업시대에 각광을 받고 있는 인공지능은 오늘날 인간의 능력과 비슷하게 발전하고 있으며, 그 한계를 넘기 위해 인간은 인공지능 분야에 무한한 투자를 하고 있습니다.  이러한 인공지능 개발에 있어서 영상처리는 입력장치 개발에 중요한 부분을 담당합니다. 이 책은 현재 많은 개발자들이 사용하는 자바 프로그래밍 언어를 사용하여 디지털 형태의 이미지 효과를 구현하는 영상처리 프로그래밍 기법에 대해 설명합니다.'},
#  {'title': '쉽게 설명한 자바스크립트 알고리즘 (쉬운 설명과 실용적 예제로 배우는 알고리즘)',
#   'link': 'https://search.shopping.naver.com/book/catalog/49800298622',
#   'image': 'https://shopping-phinf.pstatic.net/main_4980029/49800298622.20240816071140.jpg',
#   'author': '한상훈',
#   'discount': '15300',
#   'publisher': '영진닷컴',
#   'pubdate': '20240809',
#   'isbn': '9788931477252',
#   'description': "초급 웹 개발자를 위한 가장 쉬운 알고리즘 교재\n\n자바스크립트는 이제 웹 개발의 중심에 서 있는 필수 언어입니다. 하지만 많은 개발자들이 '알고리즘'이라는 단어만 들어도 두려움을 느끼곤 합니다. 이 책은 초보 개발자들이 쉽게 이해할 수 있도록 알고리즘의 기초부터 실용적인 예제까지 다룹니다. 특정 코드가 최고의 성능을 내지 않더라도 다양한 해결책을 통해 더 나은 코드를 작성하는 방법을 안내합니다. 학문적인 내용은 최소화하고, 실무에서 유용한 알고리즘을 재미있게 배울 수 있도록 구성되었습니다.\n\n【 대상 독자층 】\n- 알고리즘 공부가 필요한 자바스크립트 개발자\n- 자바스크립트 개발자 취업 준비생"},
#  {'title': '자바스크립트 + 리액트 디자인 패턴 (자바스크립트와 리액트의 최신 패턴과 렌더링, 성능 패턴까지)',
#   'link': 'https://search.shopping.naver.com/book/catalog/49335174628',
#   'image': 'https://shopping-phinf.pstatic.net/main_4933517/49335174628.20240725071120.jpg',
#   'author': '애디 오스마니',
#   'discount': '25200',
#   'publisher': '한빛미디어',
#   'pubdate': '20240801',
#   'isbn': '9791169212571',
#   'description': '20가지 이상의 디자인 패턴으로 배우는 최신 웹 개발\n\n유지보수가 쉬운 구조적인 코드를 만들고 싶은가요? 최신 웹 개발 모범 사례를 참고하고 싶은가요? 그렇다면 『자바스크립트 + 리액트 디자인 패턴』이 해답입니다. 이 책은 모듈, 믹스인, 관찰자, 중재자 패턴을 포함한 최신 디자인 패턴을 자바스크립트와 리액트에 적용하는 방법을 소개합니다. 그리고 코드 스플리팅, 서버 사이드 렌더링 등 실무에 필요한 성능과 렌더링 관련 내용을 실용적인 예제와 함께 설명합니다. 또한, 여러 안티 패턴도 함께 다루고 있어 웹 개발을 할 때 흔하게 발생하는 실수를 줄이는 노하우까지 배울 수 있습니다. 이 책에 담긴 20가지 이상의 디자인 패턴을 익혀 더 나은 웹 개발자에 한 걸음 더 다가가세요.'}]

# %%
result_df
# Out:
# {'title': ['자바 스크립트 웹 프로그래밍 (다양한 예제로 설명하는)',
#   '헬로 Bun (차세대 자바스크립트 런타임+올인원 개발 키트를 만나다)',
#   '방구석 부트캠프 자바 (기본으로 돌아가 체계적으로 시작하는 견고한 개발자 되기)',
#   '도망가자, 바다면 더 좋고 (이도훈 에세이)',
#   '코믹 실격문장의 최강 현자 13 (세계 최강의 현자가 더욱 강해지기 위해 환생했습니다, 노엔 코믹스)',
#   '파이썬과 자바스크립트로 배우는 OpenAI 프로그래밍 (OpenAI API 기본 개념부터 프롬프트 작성, 이미지 생성, 노코드 툴 사용, 나만의 AI 모델 제작까지)',
#   '기본기가 탄탄한 자바 개발자 (모던 자바의 새로운 기능을 배우고 자바 전문가가 되는 법)',
#   '자바를 이용한 영상처리 프로그래밍',
#   '쉽게 설명한 자바스크립트 알고리즘 (쉬운 설명과 실용적 예제로 배우는 알고리즘)',
#   '자바스크립트 + 리액트 디자인 패턴 (자바스크립트와 리액트의 최신 패턴과 렌더링, 성능 패턴까지)'],
#  'link': ['https://search.shopping.naver.com/book/catalog/51259188635',
#   'https://search.shopping.naver.com/book/catalog/50639934625',
#   'https://search.shopping.naver.com/book/catalog/50737873628',
#   'https://search.shopping.naver.com/book/catalog/50488152618',
#   'https://search.shopping.naver.com/book/catalog/50259598621',
#   'https://search.shopping.naver.com/book/catalog/49255961633',
#   'https://search.shopping.naver.com/book/catalog/49379976618',
#   'https://search.shopping.naver.com/book/catalog/49815969652',
#   'https://search.shopping.naver.com/book/catalog/49800298622',
#   'https://search.shopping.naver.com/book/catalog/49335174628'],
#  'image': ['https://shopping-phinf.pstatic.net/main_5125918/51259188635.20250225071032.jpg',
#   'https://shopping-phinf.pstatic.net/main_5063993/50639934625.20241003091154.jpg',
#   'https://shopping-phinf.pstatic.net/main_5073787/50737873628.20241010071030.jpg',
#   'https://shopping-phinf.pstatic.net/main_5048815/50488152618.20240927070943.jpg',
#   'https://shopping-phinf.pstatic.net/main_5025959/50259598621.20240910175427.jpg',
#   'https://shopping-phinf.pstatic.net/main_4925596/49255961633.20240720092118.jpg',
#   'https://shopping-phinf.pstatic.net/main_4937997/49379976618.20240727071259.jpg',
#   'https://shopping-phinf.pstatic.net/main_4981596/49815969652.20240816201524.jpg',
#   'https://shopping-phinf.pstatic.net/main_4980029/49800298622.20240816071140.jpg',
#   'https://shopping-phinf.pstatic.net/main_4933517/49335174628.20240725071120.jpg'],
#  'author': ['조동영^이완권',
#   '서대영',
#   '김경록',
#   '맺음',
#   '칸쇼&효코(Friendly Land) 지음, 카자바나 후우카 그림, 박소현 옮김, 신코 쇼',
#   '쇼다 쓰야노',
#   '벤저민 J. 에번스^Clark, Jason^마르테인 페르뷔르흐',
#   '류석원',
#   '한상훈',
#   '애디 오스마니'],
#  'discount': ['25000',
#   '19800',
#   '28800',
#   '15300',
#   '4950',
#   '28800',
#   '40500',
#   '21800',
#   '15300',
#   '25200'],
#  'publisher': ['북스홀릭퍼블리싱',
#   '제이펍',
#   '리코멘드',
#   '일단',
#   '데이즈엔터',
#   '제이펍',
#   '제이펍',
#   '부크크(bookk)',
#   '영진닷컴',
#   '한빛미디어'],
#  'pubdate': ['20241031',
#   '20241022',
#   '20241021',
#   '20241009',
#   '20240926',
#   '20240816',
#   '20240814',
#   '20240812',
#   '20240809',
#   '20240801'],
#  'isbn': ['9791162891247',
#   '9791193926710',
#   '9791194084051',
#   '9791198869609',
#   '9791138051415',
#   '9791193926284',
#   '9791193926277',
#   '9791141099473',
#   '9788931477252',
#   '9791169212571'],
#  'description': ['이 책은 자바스크립트 웹 프로그래밍을 다룬다. 이 책의 구성은 크게 자바스크립트 기본 문법을 다루는 부분(1장~5장)과 자바스크립트를 이용하는 웹 클라이언트 프로그래밍을 다루는 부분(6장~11장)으로 구성된다. 1장은 웹에서 자바스크립트의 역할을, 2장부터 5장까지는 자바스크립트의 기본 문법을 설명하고, Node.js 실행환경에서 자바스크립트를 실행한다. 그리고 6장부터 11장은 웹 클라이언트 프로그래밍으로 자바스크립트를 이용한 HTML DOM 프로그래밍 방법으로 설명하고, 웹브라우저 환경에서 자바스크립트를 실행한다. 자바스크립트 웹 프로그래밍을 위해서는 각 장의 모든 내용들을 이해해야 하지만 특히 7장의 HTML DOM 프로그래밍이 중요하며, 9장은 jQuery 라이브러리를 이용해서 좀더 간결하게 프로그래밍하는 방법을 다룬다.',
#   '타입스크립트와 JSX를 아우르는 런타임 Bun으로 만나는 차세대 웹 개발\n\n느리고 복잡한 노드 생태계의 판도를 바꾸기 위해, 차세대 자바스크립트 런타임이자 올인원 개발 키트인 Bun이 탄생했다. 자바스크립트/타입스크립트/JSX 코드를 바로 실행할 수 있고, 패키지 매니저, 모듈 시스템, 테스트 러너, 번들러, DB 등 다양한 기능을 내장했는데도 성능은 노드나 디노를 압도한다. 이 책은 Bun을 본격적으로 살펴보는 최초의 책으로서 Bun 기초부터 시나리오별 활용법과 예제 프로젝트까지, 웹 개발이 얼마나 우아할 수 있는지 보여준다.',
#   '여러분의 방구석을 실리콘밸리로 만들어 줄 58일간의 자바 부트캠프\n\n『방구석 부트캠프 자바』는 자바를 실용적이고 체계적으로 학습하기 위한 입문서다. 코딩은 AI가 더 잘하는 시대가 맞지만, AI 시대에 필요한 종합적인 개발자 역량은 단순한 코딩 기술을 넘어, 복잡한 문제를 창의적으로 해결하는 능력, 프로젝트 전체를 조망하고 효과적으로 협업할 수 있는 의사소통 능력, 그리고 빠르게 변화하는 기술 환경에 적응하며 지속적으로 학습할 수 있는 자기 주도적 학습 능력이 요구된다. 무엇보다 AI 도구를 효과적으로 활용하여 업무 효율성을 높이는 것은 AI 시대를 살아가는 개발자의 필수 역량이다. 이 책은 그러한 흐름에 발맞춰 단순히 자바 언어의 문법, 명령어 등과 같은 기술 습득에 그치지 않고 만들고자 하는 것을 논리적 사고 단계에 따라 하나씩 업그레이드하면서 상황에 맞게, 예측할 수 있게, 읽기 편하게 코딩하는 방법을 알려주는 것에 초점을 맞추고 있다.\n자바의 모든 것을 알려주고 있다고 할 순 없지만 적어도 이 책으로 자바를 시작한 독자가 포기하지 않고 끝까지 학습한 후, 이 책에서 이해한 것을 바탕으로 프로그래밍에 흥미를 느끼고 더 공부해 보고 싶다고 느끼도록 하는 것을 목표로 한다. 프로그래밍을 처음 시작한다면, 자바를 처음 시작한다면 더도 덜도 말고 딱 58일 과정으로 구성된 체계적인 학습 구조를 통해 프로그래밍에 입문할 수 있기를 바란다.',
#   '"답답하고 들끓는 마음이 더울지는 몰라도\n우리, 더 울지는 말기로 해요."\n\n5년이란 오랜 시간 동안 위로를 건네준\n‘이도훈 (맺음)’ 작가의 신작이 2년 만에 출간되었다.\n\n그간 농축된 감성이 그대의 메마른 감정에\n긍정적인 영향을 가져다줄 것이다.\n\n총 4장으로 이뤄진 이번 책에서는\n사계절에 어우러지는 이야기가 가득 담겨 있으며,\n이도훈 작가만의 독보적인 문체의 다정함을\n힘껏 끌어안을 수 있을 것이다.\n\n평소 ‘가독성이 좋은 글’로 \n수만 독자에게 사랑받은 청년 작가의 진심.\n\n이번 『도망가자, 바다면 더 좋고』를 통해\n우리에게 어떤 길을 안내할지 \n함께 문장을 누비길 바란다.',
#   '일찍이 [현자]라 불렸던 마법사가 마법 전투에 최적화된 문장을 얻기 위해 미래로 환생한다. 그러나 마법 이론이 퇴화한 미래에선 그 문장은 「실격문장」이라 불리며 멸시당하고 있었다.\n문장의 정보를 뒤틀어 마법 이론을 퇴화시킨 건 마족이었다.\n마티아스는 인간을 멸망시키려는 마족과의 싸움을 펼쳐 나간다!\n마족들을 이용해 다양한 음모를 전개하던 강대한 적.\n그 마족의 이름은 자리디아스. 전에 없던 강대한 마력과 전투력을 가진 마족으로, 마티아스는 “지금의 우리들은 당해낼 수 없다.”고 단언하는데….\n\n대인기 이세계 「문장」 판타지 제13탄!\n원작자의 번외편도 수록!',
#   '실용적이고 효율적인 OpenAI API 활용법\n\nOpenAI API를 활용하면 AI와 상호작용을 하면서 원하는 용도에 특화된 AI 봇을 만들 수 있으며 이미지 생성과 제품 정보를 학습시킨 AI 모델을 제작할 수도 있다. 이 책에서는 OpenAI API 개념을 알아본 후 원하는 결과를 도출하는 프롬프트 작성법, DALL-E를 통한 이미지 생성법, 제품 데이터를 활용한 AI 모델 제작 방법 등을 파이썬과 자바스크립트로 나누어 살펴본다. 파워 플랫폼 및 노코드 툴 사용법은 물론 다양한 개발 환경에서 API를 사용하는 방법도 알려준다. AI가 필수인 시대에서 최강의 무기인 OpenAI API를 제대로 활용해보자.',
#   'JVM부터 성능, 동시성, 컨테이너화 등 고급 기술까지\n\n자바는 엔터프라이즈 소프트웨어 엔지니어링의 핵심이다. 훌륭한 자바 개발자가 되기 위해선 기본기를 갖춰야 한다. 이 책은 자바 8 이후 자바 생태계와 릴리스 주기가 어떻게 변화했는지 살펴보며, 특히 자바 11 및 17에 추가된 새로운 기능을 설명한다. 자바 모듈 및 동시성 모델, 클래스 로딩과 같은 강력한 기능부터 성능 최적화와 바이트코드를 위한 고급 기술 그리고 테스트 중심 개발과 컨테이너 기반 배포와 같은 필수 최신 기술까지 알아본다. 코틀린 및 클로저 등 다른 JVM 언어까지 다뤄 자바 기술을 한층 더 업그레이드하고 탄탄한 기반을 다질 수 있도록 도와준다.',
#   '4차 산업시대에 각광을 받고 있는 인공지능은 오늘날 인간의 능력과 비슷하게 발전하고 있으며, 그 한계를 넘기 위해 인간은 인공지능 분야에 무한한 투자를 하고 있습니다.  이러한 인공지능 개발에 있어서 영상처리는 입력장치 개발에 중요한 부분을 담당합니다. 이 책은 현재 많은 개발자들이 사용하는 자바 프로그래밍 언어를 사용하여 디지털 형태의 이미지 효과를 구현하는 영상처리 프로그래밍 기법에 대해 설명합니다.',
#   "초급 웹 개발자를 위한 가장 쉬운 알고리즘 교재\n\n자바스크립트는 이제 웹 개발의 중심에 서 있는 필수 언어입니다. 하지만 많은 개발자들이 '알고리즘'이라는 단어만 들어도 두려움을 느끼곤 합니다. 이 책은 초보 개발자들이 쉽게 이해할 수 있도록 알고리즘의 기초부터 실용적인 예제까지 다룹니다. 특정 코드가 최고의 성능을 내지 않더라도 다양한 해결책을 통해 더 나은 코드를 작성하는 방법을 안내합니다. 학문적인 내용은 최소화하고, 실무에서 유용한 알고리즘을 재미있게 배울 수 있도록 구성되었습니다.\n\n【 대상 독자층 】\n- 알고리즘 공부가 필요한 자바스크립트 개발자\n- 자바스크립트 개발자 취업 준비생",
#   '20가지 이상의 디자인 패턴으로 배우는 최신 웹 개발\n\n유지보수가 쉬운 구조적인 코드를 만들고 싶은가요? 최신 웹 개발 모범 사례를 참고하고 싶은가요? 그렇다면 『자바스크립트 + 리액트 디자인 패턴』이 해답입니다. 이 책은 모듈, 믹스인, 관찰자, 중재자 패턴을 포함한 최신 디자인 패턴을 자바스크립트와 리액트에 적용하는 방법을 소개합니다. 그리고 코드 스플리팅, 서버 사이드 렌더링 등 실무에 필요한 성능과 렌더링 관련 내용을 실용적인 예제와 함께 설명합니다. 또한, 여러 안티 패턴도 함께 다루고 있어 웹 개발을 할 때 흔하게 발생하는 실수를 줄이는 노하우까지 배울 수 있습니다. 이 책에 담긴 20가지 이상의 디자인 패턴을 익혀 더 나은 웹 개발자에 한 걸음 더 다가가세요.']}

# %%
df=pd.DataFrame(result_df)
df
# Out:
#                                                title  \
# 0                           [큰글자책] 긴데요,의 김대호 씨 (짧은글)
# 1                                [큰글자책] 박치기 사랑 (짧은글)
# 2            [큰글자책] 아슬아슬했던 시절, 목단꽃 이불 밑에 숨은 사연 (짧은글)
# 3  양귀자: 원미동 시인(The Poet of Wonmi-dong) (The Poet ...
# 4                      바이링궐 에디션 한국 대표 소설 110-2 (산업화)
# 5                            길모퉁이에서 만난 사람 (양귀자 인물소설)
# 6                                 누리야 누리야 (양귀자 장편동화)
# 7                                슬픔도 힘이 된다 (양귀자 소설집)
# 8                                   부엌신 (또 다른 인생이야기)
# 9                                  천년의 사랑 (양귀자 장편소설)
#
#                                                 link  \
# 0  https://search.shopping.naver.com/book/catalog...
# 1  https://search.shopping.naver.com/book/catalog...
# 2  https://search.shopping.naver.com/book/catalog...
# 3  https://search.shopping.naver.com/book/catalog...
# 4  https://search.shopping.naver.com/book/catalog...
# 5  https://search.shopping.naver.com/book/catalog...
# 6  https://search.shopping.naver.com/book/catalog...
# 7  https://search.shopping.naver.com/book/catalog...
# 8  https://search.shopping.naver.com/book/catalog...
# 9  https://search.shopping.naver.com/book/catalog...
#
#                                                image               author  \
# 0  https://shopping-phinf.pstatic.net/main_324927...                  양귀자
# 1  https://shopping-phinf.pstatic.net/main_324936...                  양귀자
# 2  https://shopping-phinf.pstatic.net/main_324977...                  양귀자
# 3  https://shopping-phinf.pstatic.net/main_324972...                  양귀자
# 4  https://shopping-phinf.pstatic.net/main_325437...  김승옥^황석영^윤흥길^신상웅^양귀자
# 5  https://shopping-phinf.pstatic.net/main_324877...                  양귀자
# 6  https://shopping-phinf.pstatic.net/main_324871...                  양귀자
# 7  https://shopping-phinf.pstatic.net/main_324363...                  양귀자
# 8  https://shopping-phinf.pstatic.net/main_324902...                  양귀자
# 9  https://shopping-phinf.pstatic.net/main_324903...                  양귀자
#
#   discount publisher   pubdate           isbn  \
# 0     9000       지성사  20180309  9788978893541
# 1     9000       지성사  20180309  9788978893503
# 2     9000       지성사  20180309  9788978893572
# 3     7650       아시아  20150417  9788994006291
# 4    41850       아시아  20150415  9791156620907
# 5    10800        쓰다  20150201  9788998441067
# 6     9000        쓰다  20150120  9788998441050
# 7    10800        쓰다  20141115  9788998441043
# 8     9000        쓰다  20130620  9788998441036
# 9    13500        쓰다  20130420  9788998441029
#
#                                          description
# 0  어르신의 책읽기 권리를 찾아드리기 위한 국내 최초의 기획 '어르신 이야기책'. '어...
# 1  어르신의 책읽기 권리를 찾아드리기 위한 국내 최초의 기획 '어르신 이야기책'. '어...
# 2  어르신의 책읽기 권리를 찾아드리기 위한 국내 최초의 기획 '어르신 이야기책'. '어...
# 3  “문학 한류” 향하는 코리안 모던 픽션 시리즈 - 『원미동 시인』\n\n「원미동 시...
# 4  산업화 Industrialization\n\n전쟁이 남긴 폐허를 딛고 한국은 근대화...
# 5  개인 하나하나가 간직한 암호들을 해독하는 과정!\n\n양귀자의 인물소설 『길모퉁이에...
# 6  양귀자 장편동화 『누리야 누리야』. 이 책은 힘들고 지쳐 쓰러질 것만 같은 시간 속...
# 7  이 책은 작가 양귀자가 1987년부터 1993년에 쓴 중·단편 다섯 편을 모아 펴낸...
# 8  ‘어머니가 차려주는 식탁’에서 벌어진 5년 동안의 울고 울었던 장사의 기록!\n\n...
# 9  그 사랑은 천년 전에 예정된 것이었다!\n\n‘천년’과 ‘환생’이라는 문화코드를 일...

# %%
print('전체 검색 페이지: ', data['total'])
# Out:
# 전체 검색 페이지:  1722

# %%
print('검색할 페이지수: ', data['total']//100)

# %% [markdown]
# # 네이버 API로 검색한 결과 최대한 가져오기
# * 1회 네이버 서버에 요청
# * 응답에서 total을 찾아서 display로 나누어 총 반복할 페이지 산출
# * 반복문 작성 및 종료 조건 설정
# * 1페이지 결과를 데이터 프레임으로 만들고 리스트에 append
# * 반복이 끝난 후 리스트에 append된 데이터 프레임을 1개로 합침

# %%
cnt=0
last=data['total']//100+1

url='https://openapi.naver.com/v1/search/book.json'
word='자바'
headers={'X-Naver-Client-Id': 'YhDZdPHyjsCZJxZAEDAt','X-Naver-Client-Secret':'4qRCp_G_Eq'}

resut={}
while cnt!=last:
    
        cnt+=1
        print(cnt)
        
        payload['start']=cnt*10+1
        
        r=requests.get(url, params=payload, headers=headers)
        data=r.json()
        
        for item in data['items']:
            for key,value in item.items():
                result.setdefault(key,[]).append(value)
df=pd.DataFrame(result_df)
df

# %%
df
