# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
import pandas as pd
import requests
import time
from datetime import datetime
from bs4 import BeautifulSoup as bs

# %%
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/stock_info")
conn = engine.connect()
data = pd.read_sql("stock_company_info_2025_04_04", con=conn)
data
# Out:
#       주식종목       회사명   종목코드                        업종  \
# 0      코스닥    한국피아이엠  44890             자동차 신품 부품 제조업
# 1      코스닥    에이유브랜즈  48107     섬유, 의복, 신발 및 가죽제품 소매업
# 2      코스닥    우양에이치씨  10197  구조용 금속제품, 탱크 및 증기발생기 제조업
# 3      코스닥        더즌  46286                    전기 통신업
# 4      코스닥      심플랫폼  44453            소프트웨어 개발 및 공급업
# ...    ...       ...    ...                       ...
# 2756  유가증권      유한양행  00010                   의약품 제조업
# 2757  유가증권    CJ대한통운  00012                 도로 화물 운송업
# 2758  유가증권        경방  00005                    종합 소매업
# 2759  유가증권     유수홀딩스  00070       회사 본부 및 경영 컨설팅 서비스업
# 2760  유가증권  한진중공업홀딩스  00348         연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0     내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행...  2025-04-04  12월
# 1                               레인부츠, 스니커즈, 겨울화, 패션잡화 등  2025-04-03  12월
# 2                                       화공 플랜트, 에너지 플랜트  2025-03-28  12월
# ...

# %%
data = pd.read_sql('stock_company_info_2025_04_04', con=conn)
conn.close()

# %%
stock_code = data['종목코드'].apply(lambda x: x+"0")
stock_code
# Out:
# 0       448900
# 1       481070
# 2       101970
# 3       462860
# 4       444530
#          ...
# 2756    000100
# 2757    000120
# 2758    000050
# 2759    000700
# 2760    003480
# Name: 종목코드, Length: 2761, dtype: object

# %%
url = "https://finance.naver.com/item/main.naver?code=000120"
r = requests.get(url)
print(r.status_code)
soup = bs(r.content, 'lxml')
# Out:
# 200

# %%
soup
# Out:
# <html lang="ko">
# <head>
# <title>CJ대한통운 : 네이버페이 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="네이버페이 증권" name="apple-mobile-web-app-title"/>
# <meta content="https://finance.naver.com/item/main.naver?code=000120" property="og:url"/>
# <meta content="CJ대한통운 - 네이버페이 증권 : 네이버페이 증권" property="og:title"/>
# <meta content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳" property="og:description"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버페이 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# ...

# %%
def remove_comma(x):
    return x.replace(",", "")

# %%
# 종목명
stock_name = soup.select_one(".wrap_company > h2 > a").text
# 현재가
price = soup.select_one("#rate_info_krx .no_today span.blind").text.replace(",", "")
# 변동금액
soup.select_one("#rate_info_krx")
# Out:
# <div class="rate_info" id="rate_info_krx" style="display: none;">
# <dl class="blind">
# <dt><strong>CJ대한통운</strong></dt>
# <dd>오늘의시세 85,700 포인트</dd>
# <dd>0 포인트 보합</dd>
# <dd>0.00% </dd>
# </dl>
# <div class="today">
# <p class="no_today">
# <em class="X">
# <span class="blind">85,700</span>
# <span class="no8">8</span><span class="no5">5</span><span class="shim">,</span><span class="no7">7</span><span class="no0">0</span><span class="no0">0</span>
# </em>
# </p>
# <p class="no_exday">
# <span class="sptxt sp_txt1">전일대비</span>
# <em class="X">
# <span class="ico sam">보합</span>
# <span class="blind">0</span>
# <span class="no0">0</span>
# </em>
# <span class="bar">l</span>
# <em class="X">
# <span class="blind">0.00</span>
# <span class="no0">0</span><span class="jum">.</span><span class="no0">0</span><span class="no0">0</span>
# <span class="per">%</span>
# </em>
# </p>
# </div>
# <table class="no_info" summary="주요 시세(전일종가, 시고저가, 거래량, 거래대금)을 제공합니다.">
# <caption>주요 시세</caption>
# ...

# %%
# 종목명
# print(soup.select_one("#middle > dl > dd:nth-child(3)").text[4:])

# 현재가
print(soup.select_one("#middle > dl > dd:nth-child(5)").text.split(" ")[1].replace(",", ""))
# 변동금액
change = " ".join(soup.select_one("#middle > dl > dd:nth-child(5)").text.split(" ")[3:5])
change = change.replace("하락", "-").replace(",", "").replace("\n", "").replace(" ", "")
print(change)
# 변화율
change_percent = " ".join(soup.select_one("#middle > dl > dd:nth-child(5)").text.split(" ")[16:])
change_percent = change_percent.replace(" ", "").replace("마이너스", "-").replace("퍼센트", "%").replace("\n", "")
print(change_percent)
# 전일가
print(soup.select_one("#middle > dl > dd:nth-child(6)").text[4:].replace(",", ""))
# 고가
print(soup.select_one("#middle > dl > dd:nth-child(8)").text[3:].replace(",", ""))
# 상한가
print(soup.select_one("#middle > dl > dd:nth-child(9)").text[3:].replace(",", ""))
# 저가
print(soup.select_one("#middle > dl > dd:nth-child(10)").text[3:].replace(",", ""))
# 하한가
print(soup.select_one("#middle > dl > dd:nth-child(11)").text[4:].replace(",", ""))
# 거래량
print(soup.select_one("#middle > dl > dd:nth-child(12)").text[4:].replace(",", ""))
# Out:
# 에이유브랜즈
# 15430
# -1530
# -9.02%
# 16960
# 16130
#  22000
# 15320
# 11880
# 503389

# %%
from io import StringIO

# %%
pd.read_table(StringIO(soup.select_one("table.no_info").text))
# Out:
#            주요 시세
# 0             전일
# 1         16,960
# 2         16,960
# 3             고가
# 4   16,13016,130
# 5           (상한가
# 6   22,00022,000
# 7              )
# 8            거래량
# 9        503,389
# 10       503,389
# 11            시가
# 12  15,95015,950
# 13            저가
# 14  15,32015,320
# 15          (하한가
# 16        11,880
# 17             )
# 18          거래대금
# 19         7,888
# 20         7,888
# 21            백만

# %%
import requests

url = "http://data.krx.co.kr/comm/fileDn/download_csv/download.cmd"

headers = {
    "User-Agent": "Mozilla/5.0",
    "Content-Type": "application/x-www-form-urlencoded",
}

data = {
    "bld": "dbms/MDC/STAT/standard/MDCSTAT01501",
    "locale": "ko_KR",
    "mktId": "ALL",
    "trdDd": "20250407",
    "share": "1",
    "money": "1",
    "csvxls_isNo": "false"
}

response = requests.post(url, headers=headers, data=data)

# 저장
filename = "krx_시세_20250407.csv"
with open(filename, "wb") as f:
    f.write(response.content)

print(f"{filename} 저장 완료!")
# Out:
# krx_시세_20250407.csv 저장 완료!
