# %% [markdown]
# # DB에 저장된 상장기업 정보 불러오기

# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
import pandas as pd

# %%
engine=create_engine("mysql+pymysql://root:1234@localhost:3306/stock_info")
conn = engine.connect()

# %%
data=pd.read_sql('stock_company_info_2025_04_07',con=conn)
conn.close()

# %%
data
# Out:
#       주식종목       회사명   종목코드                        업종  \
# 0      코스닥    한국피아이엠  44890             자동차 신품 부품 제조업
# 1      코스닥    에이유브랜즈  48107     섬유, 의복, 신발 및 가죽제품 소매업
# 2      코스닥    우양에이치씨  10197  구조용 금속제품, 탱크 및 증기발생기 제조업
# 3      코스닥        더즌  46286                    전기 통신업
# 4      코스닥      심플랫폼  44453            소프트웨어 개발 및 공급업
# ...    ...       ...    ...                       ...
# 2756  유가증권      유한양행  00010                   의약품 제조업
# 2757  유가증권    CJ대한통운  00012                 도로 화물 운송업
# 2758  유가증권        경방  00005                    종합 소매업
# 2759  유가증권     유수홀딩스  00070       회사 본부 및 경영 컨설팅 서비스업
# 2760  유가증권  한진중공업홀딩스  00348         연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0     내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행...  2025-04-04  12월
# 1                               레인부츠, 스니커즈, 겨울화, 패션잡화 등  2025-04-03  12월
# 2                                       화공 플랜트, 에너지 플랜트  2025-03-28  12월
# 3                                 디지털뱅킹 솔루션(B2B 금융 서비스)  2025-03-24  12월
# 4                NUBISON AIoT(산업용 데이터 수집과 산업용 AI서비스 운영)  2025-03-21  12월
# ...                                                 ...         ...  ...
# 2756  의약품(삐콤씨, 안티푸라민, 렉라자, 로수바미브, 코푸시럽 등), 생활용품(유한락스...  1962-11-01  12월
# 2757  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월
# 2758          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월
# 2759                                               지주사업  1956-03-03  12월
# 2760                                               지주회사  1956-03-03  12월
#
#        대표자명                          홈페이지     지역
# 0       송준호       http://www.pimkorea.com  대구광역시
# 1       김지훈  http://aubrandz.irpage.co.kr  서울특별시
# 2       김진태      http://www.wooyang.co.kr    경기도
# 3       조철한        http://www.dozn.co.kr/  서울특별시
# 4     임대근..       http://simplatform.com/  서울특별시
# ...     ...                           ...    ...
# 2756  대표이..        http://www.yuhan.co.kr  서울특별시
# 2757  신영수..    http://www.cjlogistics.com  서울특별시
# 2758  김준,..    http://www.kyungbang.co.kr  서울특별시
# 2759    송영규  http://www.eusu-holdings.com  서울특별시
# 2760    조원국  http://www.hhic-holdings.com    경기도
#
# [2761 rows x 10 columns]

# %% [markdown]
# # Npay증권에서 종목코드로 주가 조회 후 수집하기

# %%
stock_code=data['종목코드'].apply(lambda x:x+'0')

# %%
stock_code
# Out:
# 0       448900
# 1       481070
# 2       101970
# 3       462860
# 4       444530
#          ...
# 2756    000100
# 2757    000120
# 2758    000050
# 2759    000700
# 2760    003480
# Name: 종목코드, Length: 2761, dtype: object

# %% [markdown]
# ### 자격 관련 항목 뽑기

# %%
import requests
import time
from bs4 import BeautifulSoup as bs

# %%
for c in stock_code:
    print(c)
# Out:
# 448900
# 481070
# 101970
# 462860
# 444530
# 484810
# 098070
# 498390
# 480370
# 031210
# 460870
# 226590
# 393970
# 435570
# 489500
# 479960
# 463480
# 303810
# 475830
# 240550
# 212710
# 064400
# 462980
# 452450
# 482630
# 373160
# 450950
# 096250
# 475460
# 493790
# 478560
# 006220
# 004150
# 007210
# 000400
# 001130
# 001680
# 003550
# 000640
# 003690
# 000970
# 003300
# 004250
# 003030
# 001440
# 001790
# 000070
# 002420
# 000240
# 000950
# 003490
# 001530
# 000100
# 000120
# 000050
# 000700
# 003480

# %%
for idx,c in enumerate(stock_code):
    print(idx,c)
    url ="https://finance.naver.com/item/main.naver"
    payload=dict(code=c)
    r=requests.get(url,params=payload)
#     print(r.status_code)
    print(r.status_code, f"{idx+1}/{len(stock_code)} 작업중", end="\r")
    soup=bs(r.content, 'lxml')
    # 종목명
    stock_name = soup.select_one("dl.blind > dd:nth-child(3)").text[4:]
# Out:
# 0 448900
# 1 48107061 작업중
# 2 10197061 작업중
# 3 46286061 작업중
# 4 44453061 작업중
# 5 48481061 작업중
# 6 09807061 작업중
# 7 49839061 작업중
# 8 48037061 작업중
# 9 03121061 작업중
# 10 46087061 작업중
# 11 22659061 작업중
# 12 39397061 작업중
# 13 43557061 작업중
# 14 48950061 작업중
# 15 47996061 작업중
# 16 46348061 작업중
# 17 30381061 작업중
# 18 47583061 작업중
# 19 24055061 작업중
# 20 21271061 작업중
# 21 06440061 작업중
# 22 46298061 작업중
# 23 45245061 작업중
# 200 24/2761 작업중
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 8
#       6 #     print(r.status_code)
#       7     print(r.status_code, f"{idx+1}/{len(stock_code)} 작업중", end="\r")
# ----> 8     soup=bs(r.content, 'lxml')
#       9     # 종목명
#      10     stock_name = soup.select_one("dl.blind > dd:nth-child(3)").text[4:]
#
# File ~\miniforge3\envs\fintech\Lib\site-packages\bs4\__init__.py:473, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     471 self.builder.initialize_soup(self)
#     472 try:
# --> 473     self._feed()
#     474     success = True
#     475     break
#
# File ~\miniforge3\envs\fintech\Lib\site-packages\bs4\__init__.py:658, in BeautifulSoup._feed(self)
#     655 self.builder.reset()
#     657 if self.markup is not None:
# --> 658     self.builder.feed(self.markup)
#     659 # Close out any unfinished strings and close all the open tags.
#     660 self.endData()
#
# File ~\miniforge3\envs\fintech\Lib\site-packages\bs4\builder\_lxml.py:483, in LXMLTreeBuilder.feed(self, markup)
#     481 try:
#     482     self.parser = self.parser_for(encoding)
# --> 483     self.parser.feed(markup)
#     484     self.parser.close()
#     485 except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#
# File src\\lxml\\parser.pxi:1331, in lxml.etree._FeedParser.feed()
#
# File src\\lxml\\parser.pxi:1451, in lxml.etree._FeedParser.feed()
#
# File src\\lxml\\parsertarget.pxi:161, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src\\lxml\\parsertarget.pxi:156, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src\\lxml\\etree.pyx:351, in lxml.etree._ExceptionContext._raise_if_stored()
#
# File src\\lxml\\saxparser.pxi:524, in lxml.etree._handleSaxEndNoNs()
#
# File src\\lxml\\parsertarget.pxi:99, in lxml.etree._PythonSaxParserTarget._handleSaxEnd()
#
# File ~\miniforge3\envs\fintech\Lib\site-packages\bs4\builder\_lxml.py:412, in LXMLTreeBuilderForXML.end(self, name)
#     409             return inverted_nsmap[namespace]
#     410     return None
# --> 412 def end(self, name: str | bytes) -> None:
#     413     assert self.soup is not None
#     414     assert isinstance(name, str)
#
# KeyboardInterrupt:

# %%
url ="https://finance.naver.com/item/main.naver"
payload=dict(code=44453061)
r=requests.get(url,params=payload)
soup=bs(r.content, 'lxml')
# 종목명
stock_name = soup.select_one("dl.blind > dd:nth-child(3)")
print(soup)
# yester_price = int(soup.select_one("dl.blind > dd:nth-child(6)").text[4:].replace(",", ""))
# Out:
# None

# %%
final_result = []

for idx,c in enumerate(stock_code[2000:]):
    url ="https://finance.naver.com/item/main.naver"
    payload=dict(code=c)
    r=requests.get(url,params=payload)
#     print(r.status_code)
    print(r.status_code, f"{idx+1}/{len(stock_code)} 작업중", end="\r")
    soup=bs(r.content, 'lxml')
    # 종목명
    stock_name = soup.select_one("dl.blind > dd:nth-child(3)").text[4:]
    # 현재가
    today_price = int(soup.select_one("dl.blind > dd:nth-child(5)").text.split(" ")[1].replace(",", ""))
    # 변동금액
    change = soup.select_one("dl.blind > dd:nth-child(5)").text.split(" ")[3:5]
    change = -int(change[1].replace(",", "").replace("\n,,", "")) if change[0] == "하락" else int(change[1].replace(",", "").replace("\n", ""))
    # 변동률
    percent = "".join(soup.select_one("dl.blind > dd:nth-child(5)").text.split(" ")[16:30])
    percent = percent.replace("마이너스", "-").replace("퍼센트", "%").replace("\n", "").replace("플러스", "")
    # 전일가
    yester_price = int(soup.select_one("dl.blind > dd:nth-child(6)").text[4:].replace(",", ""))
    # 고가
    hi = soup.select_one("dl.blind > dd:nth-child(8)").text[3:].replace(",", "")
    # 상한가
    top = soup.select_one("dl.blind > dd:nth-child(9)").text[4:].replace(",", "")
    # 저가
    low = soup.select_one("dl.blind > dd:nth-child(10)").text[3:].replace(",", "")
    # 하한가
    bottom = soup.select_one("dl.blind > dd:nth-child(11)").text[4:].replace(",", "")
    # 거래량
    volume = soup.select_one("dl.blind > dd:nth-child(12)").text[4:].replace(",", "")
    
    result = (c, stock_name, today_price, change, percent, yester_price, hi, top, low, bottom, volume)
    final_result.append(result)
    time.sleep(5)
# Out:
# 200 13/2761 작업중
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 21
#      19 percent = percent.replace("마이너스", "-").replace("퍼센트", "%").replace("\n", "").replace("플러스", "")
#      20 # 전일가
# ---> 21 yester_price = int(soup.select_one("dl.blind > dd:nth-child(6)").text[4:].replace(",", ""))
#      22 # 고가
#      23 hi = soup.select_one("dl.blind > dd:nth-child(8)").text[3:].replace(",", "")
#
# ValueError: invalid literal for int() with base 10: 'АЁ 3760'

# %%
# Out:
# 200 1/2761 작업중
# 021320 처리 중 오류 발생: list index out of range
# 200 2/2761 작업중
# 053060 처리 중 오류 발생: list index out of range
# 200 3/2761 작업중
# 053610 처리 중 오류 발생: list index out of range
# 200 4/2761 작업중
# 052790 처리 중 오류 발생: list index out of range
# 200 5/2761 작업중
# 053450 처리 중 오류 발생: list index out of range
# 200 6/2761 작업중
# 053030 처리 중 오류 발생: list index out of range
# 200 7/2761 작업중
# 052420 처리 중 오류 발생: list index out of range
# 200 8/2761 작업중
# 021240 처리 중 오류 발생: list index out of range
# 200 9/2761 작업중
# 053620 처리 중 오류 발생: list index out of range
# 200 10/2761 작업중
# 052300 처리 중 오류 발생: list index out of range
# 200 11/2761 작업중
# 049520 처리 중 오류 발생: list index out of range
# 200 12/2761 작업중
# 048910 처리 중 오류 발생: list index out of range
# 200 13/2761 작업중
# 051980 처리 중 오류 발생: list index out of range
# 200 14/2761 작업중
# 058650 처리 중 오류 발생: list index out of range
# 200 15/2761 작업중
# 051500 처리 중 오류 발생: list index out of range
# 200 16/2761 작업중
# 049120 처리 중 오류 발생: list index out of range
# 200 17/2761 작업중
# 043360 처리 중 오류 발생: list index out of range
# 200 18/2761 작업중
# 052330 처리 중 오류 발생: list index out of range
# 200 19/2761 작업중
# 052600 처리 중 오류 발생: list index out of range
# 200 20/2761 작업중
# 052020 처리 중 오류 발생: list index out of range
# 200 21/2761 작업중
# 043220 처리 중 오류 발생: list index out of range
# 200 22/2761 작업중
# 051780 처리 중 오류 발생: list index out of range
# 200 23/2761 작업중
# 033790 처리 중 오류 발생: list index out of range
# 200 24/2761 작업중
# 051490 처리 중 오류 발생: list index out of range
# 200 25/2761 작업중
# 038870 처리 중 오류 발생: list index out of range
# 200 26/2761 작업중
# 045660 처리 중 오류 발생: list index out of range
# 200 27/2761 작업중
# 045390 처리 중 오류 발생: list index out of range
# 200 28/2761 작업중
# 050110 처리 중 오류 발생: list index out of range
# 200 29/2761 작업중
# 052260 처리 중 오류 발생: list index out of range
# 200 30/2761 작업중
# 036540 처리 중 오류 발생: list index out of range
# 200 31/2761 작업중
# 051900 처리 중 오류 발생: list index out of range
# 200 32/2761 작업중
# 051910 처리 중 오류 발생: list index out of range
# 200 33/2761 작업중
# 047040 처리 중 오류 발생: list index out of range
# 200 34/2761 작업중
# 047050 처리 중 오류 발생: list index out of range
# 200 35/2761 작업중
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 8
#       5 r = requests.get(url, params=payload)
#       6 print(r.status_code, f"{idx + 1}/{len(stock_code)} 작업중", end="\r")
# ----> 8 soup = bs(r.content, 'lxml')
#       9 blind_tags = soup.select("dl.blind > dd")
#      11 if len(blind_tags) < 12:
#
# File ~\miniforge3\envs\fintech\Lib\site-packages\bs4\__init__.py:462, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     460 rejections = []
#     461 success = False
# --> 462 for (
#     463     self.markup,
#     464     self.original_encoding,
#     465     self.declared_html_encoding,
#     466     self.contains_replacement_characters,
#     467 ) in self.builder.prepare_markup(
#     468     markup, from_encoding, exclude_encodings=exclude_encodings
#     469 ):
#     470     self.reset()
#     471     self.builder.initialize_soup(self)
#
# File ~\miniforge3\envs\fintech\Lib\site-packages\bs4\builder\_lxml.py:280, in LXMLTreeBuilderForXML.prepare_markup(self, markup, user_specified_encoding, document_declared_encoding, exclude_encodings)
#     271     user_encodings.append(document_declared_encoding)
#     273 detector = EncodingDetector(
#     274     markup,
#     275     known_definite_encodings=known_definite_encodings,
#    (...)
#     278     exclude_encodings=exclude_encodings,
#     279 )
# --> 280 for encoding in detector.encodings:
#     281     yield (detector.markup, encoding, document_declared_encoding, False)
#
# File ~\miniforge3\envs\fintech\Lib\site-packages\bs4\dammit.py:634, in EncodingDetector.encodings(self)
#     631 # Use third-party character set detection to guess at the
#     632 # encoding.
#     633 if self.chardet_encoding is None:
# --> 634     self.chardet_encoding = _chardet_dammit(self.markup)
#     635 if self.chardet_encoding is not None and self._usable(
#     636     self.chardet_encoding, tried
#     637 ):
#     638     yield self.chardet_encoding
#
# File ~\miniforge3\envs\fintech\Lib\site-packages\bs4\dammit.py:76, in _chardet_dammit(s)
#      74     return None
#      75 module = chardet_module
# ---> 76 return module.detect(s)["encoding"]
#
# File ~\miniforge3\envs\fintech\Lib\site-packages\charset_normalizer\legacy.py:48, in detect(byte_str, should_rename_legacy, **kwargs)
#      45 if isinstance(byte_str, bytearray):
#      46     byte_str = bytes(byte_str)
# ---> 48 r = from_bytes(byte_str).best()
#      50 encoding = r.encoding if r is not None else None
#      51 language = r.language if r is not None and r.language != "Unknown" else ""
#
# File ~\miniforge3\envs\fintech\Lib\site-packages\charset_normalizer\api.py:313, in from_bytes(sequences, steps, chunk_size, threshold, cp_isolation, cp_exclusion, preemptive_behaviour, explain, language_threshold, enable_fallback)
#     299 for chunk in cut_sequence_chunks(
#     300     sequences,
#     301     encoding_iana,
#    (...)
#     308     decoded_payload,
#     309 ):
#     310     md_chunks.append(chunk)
#     312     md_ratios.append(
# --> 313         mess_ratio(
#     314             chunk,
#     315             threshold,
#     316             explain is True and 1 <= len(cp_isolation) <= 2,
#     317         )
#     318     )
#     320     if md_ratios[-1] >= threshold:
#     321         early_stop_count += 1
#
# File ~\miniforge3\envs\fintech\Lib\site-packages\charset_normalizer\md.py:602, in mess_ratio(decoded_sequence, maximum_threshold, debug)
#     600 for character, index in zip(decoded_sequence + "\n", range(length)):
#     601     for detector in detectors:
# --> 602         if detector.eligible(character):
#     603             detector.feed(character)
#     605     if (
#     606         index > 0 and index % intermediary_mean_mess_ratio_calc == 0
#     607     ) or index == length - 1:
#
# File ~\miniforge3\envs\fintech\Lib\site-packages\charset_normalizer\md.py:118, in TooManyAccentuatedPlugin.eligible(self, character)
#     115     self._character_count: int = 0
#     116     self._accentuated_count: int = 0
# --> 118 def eligible(self, character: str) -> bool:
#     119     return character.isalpha()
#     121 def feed(self, character: str) -> None:
#
# KeyboardInterrupt:

# %%
columns = ["종목코드", "종목명", "현재가", "변동금액", "변동률", "전일가",
           "고가", "상한가", "저가", "하한가", "거래량"  ]    
df = pd.DataFrame(final_result, columns=columns)
df

# %% [markdown]
# # 데이터 수집과 동시에 DB에 저장하기

# %%
def year_month():
    from datetime import datetime
    today=datetime.today()
    return today.year, today.month

# %%
for idx, code in enumerate(stock_code[46]):
    url =f"https://finance.naver.com/item/main.naver?code={code}"
    r = requests.get(url)
    print(r.status_code, f"{idx}/{len(stock_code)-1} 작업중", end="\r")
    soup = bs(r.content, 'lxml')
    # 종목명
    stock_name = soup.select_one("dl.blind > dd:nth-child(3)").text[4:]
    # 현재가
    today_price = int(soup.select_one("dl.blind > dd:nth-child(5)").text.split(" ")[1].replace(",", ""))
    # 변동금액
    change = soup.select_one("dl.blind > dd:nth-child(5)").text.split(" ")[3:5]
    change = -int(change[1].replace(",", "").replace("\n,,", "")) if change[0] == "하락" else int(change[1].replace(",", "").replace("\n", ""))
    # 변동률
    percent = "".join(soup.select_one("dl.blind > dd:nth-child(5)").text.split(" ")[16:30])
    percent = percent.replace("마이너스", "-").replace("퍼센트", "%").replace("\n", "").replace("플러스", "")
    # 전일가
    yester_price = int(soup.select_one("dl.blind > dd:nth-child(6)").text[4:].replace(",", ""))
    # 고가
    hi = soup.select_one("dl.blind > dd:nth-child(8)").text[3:].replace(",", "")
    # 상한가
    top = soup.select_one("dl.blind > dd:nth-child(9)").text[4:].replace(",", "")
    # 저가
    low = soup.select_one("dl.blind > dd:nth-child(10)").text[3:].replace(",", "")
    # 하한가
    bottom = soup.select_one("dl.blind > dd:nth-child(11)").text[4:].replace(",", "")
    # 거래량
    volume = soup.select_one("dl.blind > dd:nth-child(12)").text[4:].replace(",", "")

    result = (code, stock_name, today_price, change, percent, yester_price, hi, top, low, bottom, volume)
    columns = ["종목코드", "종목명", "현재가", "변동금액", "변동률", "전일가",
           "고가", "상한가", "저가", "하한가", "거래량"  ]    
    df = pd.DataFrame([result], columns=columns)
    year, month=year_month()
    # 데이터베이스쿼리창오픈
    conn=dbconnect()
    df.to_sql(f'stock_price_{year}_{month:02d}', con=conn,  if_exists="append", index=False)
    conn.close()
    print(f"{idx+1}/{len(stock_code)} {stock_name}DB 저장 완료", end="\r")
    time.sleep(5)

# %% [markdown]
# # 함수형 프로그래밍으로 코드 변경하기

# %%
def stock_info_get(code):
    url =f"https://finance.naver.com/item/main.naver?code={code}"
    r = requests.get(url)
    print(r.status_code, f"{idx+1}/{len(stock_code)} {code} 작업중", end="\r")
    soup = bs(r.content, 'lxml')
    # 종목명
    stock_name = soup.select_one("dl.blind > dd:nth-child(3)").text[4:]
    # 현재가
    today_price = int(soup.select_one("dl.blind > dd:nth-child(5)").text.split(" ")[1].replace(",", ""))
    # 변동금액
    change = soup.select_one("dl.blind > dd:nth-child(5)").text.split(" ")[3:5]
    change = -int(change[1].replace(",", "").replace("\n,,", "")) if change[0] == "하락" else int(change[1].replace(",", "").replace("\n", ""))
    # 변동률
    percent = "".join(soup.select_one("dl.blind > dd:nth-child(5)").text.split(" ")[16:30])
    percent = percent.replace("마이너스", "-").replace("퍼센트", "%").replace("\n", "").replace("플러스", "")
    # 전일가
    yester_price = int(soup.select_one("dl.blind > dd:nth-child(6)").text[4:].replace(",", ""))
    # 고가
    hi = soup.select_one("dl.blind > dd:nth-child(8)").text[3:].replace(",", "")
    # 상한가
    top = soup.select_one("dl.blind > dd:nth-child(9)").text[4:].replace(",", "")
    # 저가
    low = soup.select_one("dl.blind > dd:nth-child(10)").text[3:].replace(",", "")
    # 하한가
    bottom = soup.select_one("dl.blind > dd:nth-child(11)").text[4:].replace(",", "")
    # 거래량
    volume = soup.select_one("dl.blind > dd:nth-child(12)").text[4:].replace(",", "")

    result = (code, stock_name, today_price, change, percent, yester_price, hi, top, low, bottom, volume)
    columns = ["종목코드", "종목명", "현재가", "변동금액", "변동률", "전일가",
           "고가", "상한가", "저가", "하한가", "거래량"  ]    
    df = pd.DataFrame([result], columns=columns)
    # 오늘기준 연도, 달 출력
    time.sleep(5)
    return df, stock_name

# %%
from dbio import *

# %%
stock_code = stock_codes()
for idx, code in enumerate(stock_code):
    print(f"{idx}/{len(stock_code)-1} {code} 작업중", end="\r")
    df, stock_name = stock_info_get(code)
    to_stock_db(idx, code, stock_name, df)
