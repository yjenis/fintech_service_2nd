# %% [markdown]
# # 셀복사:h1
# ## h2
# ### h3
# * 목록
# * 목록2
#   * 세부목록1
#     * 세부목록의 목록1<br>
#
# 내용적기
# **굵게 만들기**
#
# ### 링크걸기
# [네이버링크](https://www.naver.com)
#
#
# ### 이미지 넣기
# ![고양이](https://www.google.com/imgres?q=%EA%B3%A0%EC%96%91%EC%9D%B4&imgurl=https%3A%2F%2Fflexible.img.hani.co.kr%2Fflexible%2Fnormal%2F970%2F777%2Fimgdb%2Fresize%2F2019%2F0926%2F00501881_20190926.webp&imgrefurl=https%3A%2F%2Fwww.hani.co.kr%2Farti%2Fanimalpeople%2Fcompanion_animal%2F911025.html&docid=lrHZrbfz37smVM&tbnid=5gNnhr6gk-2tyM&vet=12ahUKEwiX2d7ov4OMAxUBZvUHHQZwEcgQM3oECEsQAA..i&w=970&h=777&hcb=2&ved=2ahUKEwiX2d7ov4OMAxUBZvUHHQZwEcgQM3oECEsQAA)

# %% [markdown]
# # 수식넣기

# %% [markdown]
# $$ A \over B  $$
# $$ (A \cap B) $$

# %% [markdown]
# # 표만들기

# %% [markdown]
# | 값 | 의미 | 기본값 |
# |---|:---:|---:|
# | `static` | 유형(기준) 없음 / 배치 불가능 | `static` |
# | `relative` | 요소 자신을 기준으로 배치 |  |
# | `absolute` | 위치 상 부모(조상)요소를 기준으로 배치 |  |
# | `fixed` | 브라우저 창을 기준으로 배치 |  |
# | `sticky` | 스크롤 영역 기준으로 배치 |  |

# %%
print("hello python")
# Out:
# hello python

# %% [markdown]
# # h1
# ## h2
# ### h3
# #### h4
# ##### h5
# ###### h6

# %% [markdown]
# **글자를 굵게 만들기** <br>
# *글자를 이탤릭체로 만들기* <br>
# <b>글자를 굵게 만들기</b> <br>
# <em>글자를 이탤릭체로 만들기</em><br>
# 목록 만들기 \*
# * 목록1
# * 목록2
#   * 목록2의 세부목록1
#     * 목록2의 세부목록1의 세부목록
# [네이버](https://www.naver.com)
#
# ![이미지](https://i.namu.wiki/i/d1A_wD4kuLHmOOFqJdVlOXVt1TWA9NfNt_HA0CS0Y_N0zayUAX8olMuv7odG2FiDLDQZIRBqbPQwBSArXfEJlQ.webp)
#
# ![vladimir-mokry-G-4wX5tZNuE-unsplash.jpg](attachment:vladimir-mokry-G-4wX5tZNuE-unsplash.jpg)
