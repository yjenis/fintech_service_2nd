# %%
from konlpy.tag import Mecab
mecab = Mecab()
print(mecab.morphs(u'영등포구청역에 있는 맛집 좀 알려주세요.'))
# Out:
# ['영등포구청역', '에', '있', '는', '맛집', '좀', '알려', '주', '세요', '.']

# %%
pip install koreanize-matplotlib
# Out:
# Requirement already satisfied: koreanize-matplotlib in /home/fintech/miniforge3/envs/fintech/lib/python3.9/site-packages (0.1.1)
# Requirement already satisfied: matplotlib in /home/fintech/miniforge3/envs/fintech/lib/python3.9/site-packages (from koreanize-matplotlib) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fintech/miniforge3/envs/fintech/lib/python3.9/site-packages (from matplotlib->koreanize-matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/fintech/miniforge3/envs/fintech/lib/python3.9/site-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fintech/miniforge3/envs/fintech/lib/python3.9/site-packages (from matplotlib->koreanize-matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fintech/miniforge3/envs/fintech/lib/python3.9/site-packages (from matplotlib->koreanize-matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /home/fintech/miniforge3/envs/fintech/lib/python3.9/site-packages (from matplotlib->koreanize-matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /home/fintech/miniforge3/envs/fintech/lib/python3.9/site-packages (from matplotlib->koreanize-matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/fintech/miniforge3/envs/fintech/lib/python3.9/site-packages (from matplotlib->koreanize-matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/fintech/miniforge3/envs/fintech/lib/python3.9/site-packages (from matplotlib->koreanize-matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fintech/miniforge3/envs/fintech/lib/python3.9/site-packages (from matplotlib->koreanize-matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/fintech/miniforge3/envs/fintech/lib/python3.9/site-packages (from matplotlib->koreanize-matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /home/fintech/miniforge3/envs/fintech/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->koreanize-matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /home/fintech/miniforge3/envs/fintech/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
train_data=pd.read_csv("https://raw.githubusercontent.com/haram4th/ablearn/main/ratings_train.txt", sep='\t')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        150000 non-null  int64
#  1   document  149995 non-null  object
#  2   label     150000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 3.4+ MB

# %%
test_data=pd.read_csv("")
test_data.head()
